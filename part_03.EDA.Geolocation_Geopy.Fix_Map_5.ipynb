# %% [markdown]
# ## EDA clean AC tpye
# - Just get the name without the plane type

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np
import geopy 
# %matplotlib inline

# %%
df = pd.read_json("data/silver/1920_2024_geopy.json")
df.Ground = df.Ground.astype("Int64") 
df.Date = pd.to_datetime(df.Date)

# %%
df
# Out:
#       Decade                       Date   Time  \
# 0       1950 1969-12-31 23:51:03.888000   2139
# 1       1950 1969-12-31 23:51:04.060800   2055
# 2       1950 1969-12-31 23:51:04.060800   0412
# 3       1950 1969-12-31 23:51:04.752000   0448
# 4       1950 1969-12-31 23:51:05.702400   1144
# ...      ...                        ...    ...
# 5032    1970 1970-01-01 00:03:39.628800   1940
# 5033    1970 1970-01-01 00:03:39.628800  21:30
# 5034    1970 1970-01-01 00:03:39.715200   1656
# 5035    1970 1970-01-01 00:03:40.320000   0345
# 5036    1970 1970-01-01 00:03:40.838400   None
#
#                              Location                   Operator Flight_Num  \
# 0           Belfast, Northern Ireland   British European Airways       None
# 1                Issaquah, Washington          Flying Tiger Line        841
# 2                   Fish Haven, Idaho   Associated Air Transport     1-6-6A
# 3          25 nm off Agrigento, Italy  Military -Royal Air Force          -
# 4             Sinnai, Sardinia, Italy       Linee Aeree Italiane       None
# ...                               ...                        ...        ...
# 5032                  Ust-Kut, Russia                   Aeroflot       None
# 5033                       Kiev, USSR                   Aeroflot       H-36
# 5034  Nnear Yuzhno-Sakhalinsk, Russia                   Aeroflot       None
# 5035           Near Bangkok, Thailand                   EgyptAir        864
# 5036              Near Trujillo, Peru                    Faucett       None
#
#                                              Route  \
# 0                               Northolt - Belfast
# 1                Seattle - Cheyenne - Fort Jackson
# 2                          Boeing Field - Cheyenne
# 3                                             None
# 4                                  Cagliari - Rome
# ...                                            ...
# 5032                             Ust-Kut - Kirensk
# 5033                             Chernivtsi - Kiev
# 5034  Petropavlovsk-Kamchatsky - Yuzhno-Sakhalinsk
# 5035                               Cairo - Bangkok
# 5036                           Trujillo - Tarapoto
#
#                                     Ac_Type   Registration      Cn_Ln  \
# 0                     Vickers Viking 610-1B         G-AJDL        262
# 1                       Douglas C-54B-10-DO         N86574      18350
# 2                              Curtiss C-46         N1648M      22395
# 3     Vickers Valetta Mk1 / Avero Lancaster  VX562 / TX270       None
# 4                              Douglas DC-3         I-LAIL       4308
# ...                                     ...            ...        ...
# 5032                            Yakovlev 40     CCCP-88208    9631349
# 5033                        Antonov AN-24RV     CCCP-46672   47309604
# 5034                        Ilyushin IL-14M     CCCP-61752  147001247
# 5035                      Boeing B-707-366C         SU-AXA      20763
# 5036                     Douglas C-54A-1-DO       OB-R-247       7462
#
#                                            Aboard  \
# 0      {'total': 35, 'passengers': 31, 'crew': 4}
# 1        {'total': 7, 'passengers': 3, 'crew': 4}
# 2      {'total': 40, 'passengers': 37, 'crew': 3}
# 3     {'total': 26, 'passengers': 16, 'crew': 10}
# 4      {'total': 19, 'passengers': 15, 'crew': 4}
# ...                                           ...
# 5032     {'total': 7, 'passengers': 4, 'crew': 3}
# 5033   {'total': 55, 'passengers': 50, 'crew': 5}
# 5034     {'total': 8, 'passengers': 3, 'crew': 5}
# 5035   {'total': 53, 'passengers': 44, 'crew': 9}
# 5036   {'total': 19, 'passengers': 14, 'crew': 5}
#
#                                        Fatalities  Ground  \
# 0      {'total': 27, 'passengers': 24, 'crew': 3}       0
# 1        {'total': 7, 'passengers': 3, 'crew': 4}       0
# 2      {'total': 40, 'passengers': 37, 'crew': 3}       0
# 3     {'total': 26, 'passengers': 16, 'crew': 10}       0
# 4      {'total': 19, 'passengers': 15, 'crew': 4}       0
# ...                                           ...     ...
# 5032     {'total': 7, 'passengers': 4, 'crew': 3}       0
# 5033   {'total': 48, 'passengers': 44, 'crew': 4}       0
# 5034     {'total': 8, 'passengers': 3, 'crew': 5}       0
# 5035   {'total': 53, 'passengers': 44, 'crew': 9}      19
# 5036   {'total': 19, 'passengers': 14, 'crew': 5}       0
#
#                                                 Summary  \
# 0     Crashed into approach lights while attempting ...
# 1     The plane struck a tree on a mountain ridge at...
# 2     The plane crashed into mountains while en rout...
# 3     Both aircraft crashed after a midair collision...
# 4     Crashed 10 miles east of Cagliari in the Sinna...
# ...                                                 ...
# 5032  The cargo plane crashed into trees on takeoff....
# 5033  In heavy fog  the crew continued their descend...
# 5034  The survey fllight deviated from the approach ...
# 5035  The aircraft crashed into an industrial area d...
# 5036  Struck the slope of Mt Pintado located 25 km n...
#
#                                        Country_location
# 0     Belfast, County Antrim, Northern Ireland / Tua...
# 1      Issaquah, King County, Washington, United States
# 2     Fish Haven, Bear Lake County, Idaho, 83287, Un...
# 3                                                Italia
# 4     Sìnnia/Sinnai, Casteddu/Cagliari, Sardigna/Sar...
# ...                                                 ...
# 5032  Усть-Кут, Усть-Кутское городское поселение, Ус...
# 5033  Служба безпеки України, Володимирська вулиця, ...
# 5034                                             Россия
# 5035  Thailand, Banisilan, North Cotabato, Soccsksar...
# 5036                                               Perú
#
# [5032 rows x 15 columns]
