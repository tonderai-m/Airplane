# %% [markdown]
# ## EDA clean AC tpye
# - Just get the name without the plane type

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np
import plotly
# %matplotlib inline

# %%
df = pd.read_json("data/silver/1920_2024_geopy.json")
df2 = pd.read_json("data/silver/1920_2024.json")
df.Ground = df.Ground.astype("Int64")

# %%
df3 = df2[df2.Location.apply(lambda x: isinstance(x,str))]

# %%
df.Date = df3.Date

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5015 entries, 0 to 5036
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Decade                5015 non-null   int64
#  1   Date                  5015 non-null   datetime64[ns]
#  2   Time                  3528 non-null   object
#  3   Location              5015 non-null   object
#  4   Operator              5004 non-null   object
#  5   Flight_Num            1340 non-null   object
#  6   Route                 4269 non-null   object
#  7   Ac_Type               5002 non-null   object
#  8   Registration          4752 non-null   object
#  9   Cn_Ln                 4363 non-null   object
#  10  Aboard                5015 non-null   object
#  11  Fatalities            5015 non-null   object
#  12  Ground                4984 non-null   Int64
#  13  Summary               4964 non-null   object
#  14  Aboard_Total          5015 non-null   int64
# ...

# %%
df.info
# Out:
#       Decade       Date   Time                         Location  \
# 0       1950 1953-01-05   2139        Belfast, Northern Ireland
# 1       1950 1953-01-07   2055             Issaquah, Washington
# 2       1950 1953-01-07   0412                Fish Haven, Idaho
# 3       1950 1953-01-15   0448       25 nm off Agrigento, Italy
# 4       1950 1953-01-26   1144          Sinnai, Sardinia, Italy
# ...      ...        ...    ...                              ...
# 5032    1970 1976-12-17   1940                  Ust-Kut, Russia
# 5033    1970 1976-12-17  21:30                       Kiev, USSR
# 5034    1970 1976-12-18   1656  Nnear Yuzhno-Sakhalinsk, Russia
# 5035    1970 1976-12-25   0345           Near Bangkok, Thailand
# 5036    1970 1976-12-31   None              Near Trujillo, Peru
#
#                        Operator Flight_Num  \
# 0      British European Airways       None
# 1             Flying Tiger Line        841
# 2      Associated Air Transport     1-6-6A
# ...

# %%
df.Date = df.Date.astype(str)

# %%
df.to_json("data/silver/1920_2024_geopy.json")
