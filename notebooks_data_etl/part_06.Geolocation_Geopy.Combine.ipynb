# %%
import pandas as pd
import ast

# %%
df = pd.read_json("data/silver/1920_2024_geopy.json")
df_2 = pd.read_csv("data/bad_data/cleaned_bad_data/cleaned_global_data.csv")

# %%
df[:2]
# Out:
#    Decade       Date  Time                   Location  \
# 0    1950 1953-01-05  2139  Belfast, Northern Ireland
# 1    1950 1953-01-07  2055       Issaquah, Washington
#
#                    Operator Flight_Num                              Route  \
# 0  British European Airways       None                 Northolt - Belfast
# 1         Flying Tiger Line        841  Seattle - Cheyenne - Fort Jackson
#
#                  Ac_Type Registration  Cn_Ln  \
# 0  Vickers Viking 610-1B       G-AJDL    262
# 1    Douglas C-54B-10-DO       N86574  18350
#
#                                        Aboard  \
# 0  {'total': 35, 'passengers': 31, 'crew': 4}
# 1    {'total': 7, 'passengers': 3, 'crew': 4}
#
#                                    Fatalities  Ground  \
# 0  {'total': 27, 'passengers': 24, 'crew': 3}     0.0
# 1    {'total': 7, 'passengers': 3, 'crew': 4}     0.0
#
#                                              Summary  Aboard_Total  \
# ...

# %%
df[df.Country_location.apply(lambda x: isinstance(x,str))][:2]
# Out:
#     Decade       Date  Time                                      Location  \
# 37    1950 1953-06-16  None           Mount Phou-Lassy, French Indo-China
# 40    1950 1953-07-12  0841  Pacific Ocean, 325 miles east of Wake Island
#
#                 Operator Flight_Num                             Route  \
# 37            Aigle Azur       None                Vientiane - Saigon
# 40  Transocean Air Lines        512  Wake Island - Honolulu - Oakland
#
#           Ac_Type Registration      Cn_Ln  \
# 37   Douglas DC-3       F-BEST      19100
# 40  Douglas DC-6A       N90806  42901/153
#
#                                         Aboard  \
# 37  {'total': 34, 'passengers': 31, 'crew': 3}
# 40  {'total': 58, 'passengers': 50, 'crew': 8}
#
#                                     Fatalities  Ground  \
# 37  {'total': 34, 'passengers': 31, 'crew': 3}     0.0
# 40  {'total': 58, 'passengers': 50, 'crew': 8}     0.0
#
#                                               Summary  Aboard_Total  \
# ...

# %%
df[df.Country_location.apply(lambda x: isinstance(x,str))].shape
# Out:
# (97, 18)

# %%
df_2[:1]
# Out:
#    Unnamed: 0.1  Unnamed: 0  Decade        Date Time  \
# 0             0          37    1950  1953-06-16  NaN
#
#                               Location    Operator Flight_Num  \
# 0  Mount Phou-Lassy, French Indo-China  Aigle Azur        NaN
#
#                 Route       Ac_Type Registration  Cn_Ln  \
# 0  Vientiane - Saigon  Douglas DC-3       F-BEST  19100
#
#                                        Aboard  \
# 0  {'total': 34, 'passengers': 31, 'crew': 3}
#
#                                    Fatalities  Ground  \
# 0  {'total': 34, 'passengers': 31, 'crew': 3}     0.0
#
#                                              Summary  Aboard_Total  \
# 0  Crashed after on-board fire.  Possibly shot down.            34
#
#    Fatalities_Total Operator_vs_Military  \
# 0                34           Aigle Azur
#
#                                     Country_location
# 0  {'place_id': 237996895, 'licence': 'Data © Ope...

# %%
df_2 = df_2[df_2.columns[2:]]
df_2[:2]
# Out:
#    Decade        Date  Time                                      Location  \
# 0    1950  1953-06-16   NaN           Mount Phou-Lassy, French Indo-China
# 1    1950  1953-07-12  0841  Pacific Ocean, 325 miles east of Wake Island
#
#                Operator Flight_Num                             Route  \
# 0            Aigle Azur        NaN                Vientiane - Saigon
# 1  Transocean Air Lines        512  Wake Island - Honolulu - Oakland
#
#          Ac_Type Registration      Cn_Ln  \
# 0   Douglas DC-3       F-BEST      19100
# 1  Douglas DC-6A       N90806  42901/153
#
#                                        Aboard  \
# 0  {'total': 34, 'passengers': 31, 'crew': 3}
# 1  {'total': 58, 'passengers': 50, 'crew': 8}
#
#                                    Fatalities  Ground  \
# 0  {'total': 34, 'passengers': 31, 'crew': 3}     0.0
# 1  {'total': 58, 'passengers': 50, 'crew': 8}     0.0
#
#                                              Summary  Aboard_Total  \
# ...

# %%
df[df.Country_location.apply(lambda x: isinstance(x,str))].iloc[:,3:5]
# Out:
#                                               Location  \
# 37                 Mount Phou-Lassy, French Indo-China
# 40        Pacific Ocean, 325 miles east of Wake Island
# 45                                     Off Irish coast
# 112                     Black Sea, Gulf of Karkinitsky
# 113                       Near Eaeka, French Cameroons
# ...                                                ...
# 4455                       Atlantic Ocean, off Bermuda
# 4473  Sibuyan Sea, off the Philippine island of Elalat
# 4570                   Midway Island Naval Air Station
# 4653                                   Off Wake Island
# 4871                 Centeral Afghanistan\nAfghanistan
#
#                                     Operator
# 37                                Aigle Azur
# 40                      Transocean Air Lines
# 45                 Military - U.S. Air Force
# 112                                 Aeroflot
# 113                               Air France
# ...

# %%
df_2.iloc[:,3:5]
# Out:
#                                             Location  \
# 0                Mount Phou-Lassy, French Indo-China
# 1       Pacific Ocean, 325 miles east of Wake Island
# 2                                    Off Irish coast
# 3                     Black Sea, Gulf of Karkinitsky
# 4                       Near Eaeka, French Cameroons
# ..                                               ...
# 92                       Atlantic Ocean, off Bermuda
# 93  Sibuyan Sea, off the Philippine island of Elalat
# 94                   Midway Island Naval Air Station
# 95                                   Off Wake Island
# 96                 Centeral Afghanistan\nAfghanistan
#
#                                   Operator
# 0                               Aigle Azur
# 1                     Transocean Air Lines
# 2                Military - U.S. Air Force
# 3                                 Aeroflot
# 4                               Air France
# ..                                     ...
# ...

# %%
sum(df[df.Country_location.apply(lambda x: isinstance(x,str))].iloc[:,3:5].values == df_2.iloc[:,3:5].values)
# Out:
# array([97, 97])

# %%
k = df.loc[df['Country_location'].apply(lambda x: isinstance(x, str))]
k[(k["Location"] !=  "175 miles off the Egyptian coast") & (k["Location"] != "Djiring, French Indo-China")].shape
# Out:
# (95, 18)

# %%
df_2[df_2['Country_location'].apply(lambda x: isinstance(x,str))].shape
# Out:
# (95, 18)

# %%
a = k[(k["Location"] !=  "175 miles off the Egyptian coast") & (k["Location"] != "Djiring, French Indo-China")].index

# %%
a
# Out:
# Index([  37,   40,   45,  112,  113,  128,  169,  227,  289,  414,  421,  441,
#         490,  531,  566,  618,  669,  697,  708,  762,  954,  960,  995, 1085,
#        1088, 1092, 1171, 1200, 1313, 1368, 1402, 1403, 1484, 1555, 1644, 1674,
#        1724, 1726, 1762, 1779, 1845, 1890, 1942, 2021, 2067, 2147, 2202, 2222,
#        2255, 2327, 2364, 2405, 2465, 2484, 2498, 2520, 2525, 2564, 2566, 2615,
#        2625, 2631, 2697, 2721, 2799, 2830, 2895, 2914, 3066, 3164, 3177, 3242,
#        3253, 3422, 3424, 3530, 3774, 3881, 3924, 3972, 4043, 4080, 4124, 4128,
#        4210, 4217, 4226, 4340, 4400, 4416, 4455, 4473, 4570, 4653, 4871],
#       dtype='int64')

# %%
df_2[df_2['Country_location'].apply(lambda x: isinstance(x, str))]['Country_location'].apply(ast.literal_eval).values[0]
# Out:
# {'place_id': 237996895,
#  'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#  'osm_type': 'node',
#  'osm_id': 116056557,
#  'lat': '19.8887438',
#  'lon': '102.135898',
#  'class': 'place',
#  'type': 'city',
#  'place_rank': 16,
#  'importance': 0.4701938145413271,
#  'addresstype': 'city',
#  'name': 'Luang Prabang',
#  'display_name': 'Luang Prabang, Luang Prabang District, Luang Prabang, 10000, Laos',
#  'boundingbox': ['19.7287438', '20.0487438', '101.9758980', '102.2958980']}

# %%
df.loc[a, "Country_location"] = df_2[df_2['Country_location'].apply(lambda x: isinstance(x, str))]['Country_location'].apply(ast.literal_eval).values

# %%
df.loc[a]
# Out:
#       Decade       Date     Time  \
# 37      1950 1953-06-16     None
# 40      1950 1953-07-12     0841
# 45      1950 1953-08-05     None
# 112     1940 1947-06-21     None
# 113     1940 1947-07-01     None
# ...      ...        ...      ...
# 4455    1940 1949-01-17  c 13:40
# 4473    1940 1949-05-07    16:00
# 4570    1960 1961-01-22     0304
# 4653    1970 1977-06-21     2230
# 4871    1980 1989-09-21     None
#
#                                               Location  \
# 37                 Mount Phou-Lassy, French Indo-China
# 40        Pacific Ocean, 325 miles east of Wake Island
# 45                                     Off Irish coast
# 112                     Black Sea, Gulf of Karkinitsky
# 113                       Near Eaeka, French Cameroons
# ...                                                ...
# 4455                       Atlantic Ocean, off Bermuda
# 4473  Sibuyan Sea, off the Philippine island of Elalat
# 4570                   Midway Island Naval Air Station
# ...

# %%
df["Date"] = df["Date"].astype(str)

# %%
df.to_json("data/silver/1920_2024_geopy_fixed.json")
