# %% [markdown]
# ### Exploring fatalities and crashes across time
# - Objective is to find operators with the highest number of crashes
# - Select top 5 and observe across decade

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from wordcloud import WordCloud
from collections import Counter

# %%
df = pd.read_json("data/silver/1920_2024.json")
df.Date = pd.to_datetime(df.Date)
stop_words = set(stopwords.words("english"))

# %%
df_1 = df.dropna(axis=0,how="any",subset=["Summary"])
df_1[:2]
# Out:
#    Decade       Date  Time                   Location  \
# 0    1950 1953-01-05  2139  Belfast, Northern Ireland
# 1    1950 1953-01-07  2055       Issaquah, Washington
#
#                    Operator Flight_Num                              Route  \
# 0  British European Airways       None                 Northolt - Belfast
# 1         Flying Tiger Line        841  Seattle - Cheyenne - Fort Jackson
#
#                  Ac_Type Registration  Cn_Ln  \
# 0  Vickers Viking 610-1B       G-AJDL    262
# 1    Douglas C-54B-10-DO       N86574  18350
#
#                                        Aboard  \
# 0  {'total': 35, 'passengers': 31, 'crew': 4}
# 1    {'total': 7, 'passengers': 3, 'crew': 4}
#
#                                    Fatalities  Ground  \
# 0  {'total': 27, 'passengers': 24, 'crew': 3}     0.0
# 1    {'total': 7, 'passengers': 3, 'crew': 4}     0.0
#
#                                              Summary  Aboard_Total  \
# 0  Crashed into approach lights while attempting ...            35
# 1  The plane struck a tree on a mountain ridge at...             7
#
#    Fatalities_Total      Operator_vs_Military
# 0                27  British European Airways
# 1                 7         Flying Tiger Line

# %%
df_1.shape
# Out:
# (4969, 17)

# %%
df_1["Words"] = df_1.Summary.apply(lambda x : x.split(" "))
# Out:
# /var/folders/sr/32z6khr97xs2g11w52pbkzww0000gn/T/ipykernel_64723/3916041444.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1["Words"] = df_1.Summary.apply(lambda x : x.split(" "))

# %%
additional_stop_words = {"plot","crash","plane","fllight","flight","crashed" ,
                         "miles"," ", "pilot","aircraft","crew","cargo", "airport",
                         "approach","fly", "cause"}

# %%
stop_words = stop_words | additional_stop_words

# %%
stop_words = [i for i in stop_words if i not in ["off",'']]

# %%
lemmatizer = WordNetLemmatizer()

def add_stop_words(stop_words,x):
    [stop_words.update(i) for i in x]
    return stop_words

def to_lammetize(x):
    return [lemmatizer.lemmatize(j.lower(),  pos='v') for j in x ]

def remove_stop_word(x):
    return [i.lower() for i in x if i.lower() not in stop_words and i != ""]

# %%
df_1["Words"] = df_1["Words"].apply(to_lammetize)
# Out:
# /var/folders/sr/32z6khr97xs2g11w52pbkzww0000gn/T/ipykernel_64723/3868780852.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1["Words"] = df_1["Words"].apply(to_lammetize)

# %%
df_1["Words"] = df_1["Words"].apply(remove_stop_word)
# Out:
# /var/folders/sr/32z6khr97xs2g11w52pbkzww0000gn/T/ipykernel_64723/1338964306.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1["Words"] = df_1["Words"].apply(remove_stop_word)

# %%
df_1.Decade.max(), df_1.Decade.min()
# Out:
# (2020, 1900)

# %%
np.linspace(df_1.Decade.max(), df_1.Decade.min(),4)
# Out:
# array([2020., 1980., 1940., 1900.])

# %%
df_1
# Out:
#       Decade       Date   Time                         Location  \
# 0       1950 1953-01-05   2139        Belfast, Northern Ireland
# 1       1950 1953-01-07   2055             Issaquah, Washington
# 2       1950 1953-01-07   0412                Fish Haven, Idaho
# 3       1950 1953-01-15   0448       25 nm off Agrigento, Italy
# 4       1950 1953-01-26   1144          Sinnai, Sardinia, Italy
# ...      ...        ...    ...                              ...
# 5032    1970 1976-12-17   1940                  Ust-Kut, Russia
# 5033    1970 1976-12-17  21:30                       Kiev, USSR
# 5034    1970 1976-12-18   1656  Nnear Yuzhno-Sakhalinsk, Russia
# 5035    1970 1976-12-25   0345           Near Bangkok, Thailand
# 5036    1970 1976-12-31   None              Near Trujillo, Peru
#
#                        Operator Flight_Num  \
# 0      British European Airways       None
# 1             Flying Tiger Line        841
# 2      Associated Air Transport     1-6-6A
# 3     Military -Royal Air Force          -
# 4          Linee Aeree Italiane       None
# ...                         ...        ...
# 5032                   Aeroflot       None
# 5033                   Aeroflot       H-36
# 5034                   Aeroflot       None
# 5035                   EgyptAir        864
# 5036                    Faucett       None
#
#                                              Route  \
# 0                               Northolt - Belfast
# 1                Seattle - Cheyenne - Fort Jackson
# 2                          Boeing Field - Cheyenne
# 3                                             None
# 4                                  Cagliari - Rome
# ...                                            ...
# 5032                             Ust-Kut - Kirensk
# 5033                             Chernivtsi - Kiev
# 5034  Petropavlovsk-Kamchatsky - Yuzhno-Sakhalinsk
# 5035                               Cairo - Bangkok
# 5036                           Trujillo - Tarapoto
#
#                                     Ac_Type   Registration      Cn_Ln  \
# 0                     Vickers Viking 610-1B         G-AJDL        262
# 1                       Douglas C-54B-10-DO         N86574      18350
# 2                              Curtiss C-46         N1648M      22395
# 3     Vickers Valetta Mk1 / Avero Lancaster  VX562 / TX270       None
# 4                              Douglas DC-3         I-LAIL       4308
# ...                                     ...            ...        ...
# 5032                            Yakovlev 40     CCCP-88208    9631349
# 5033                        Antonov AN-24RV     CCCP-46672   47309604
# 5034                        Ilyushin IL-14M     CCCP-61752  147001247
# 5035                      Boeing B-707-366C         SU-AXA      20763
# 5036                     Douglas C-54A-1-DO       OB-R-247       7462
#
#                                            Aboard  \
# 0      {'total': 35, 'passengers': 31, 'crew': 4}
# 1        {'total': 7, 'passengers': 3, 'crew': 4}
# 2      {'total': 40, 'passengers': 37, 'crew': 3}
# 3     {'total': 26, 'passengers': 16, 'crew': 10}
# 4      {'total': 19, 'passengers': 15, 'crew': 4}
# ...                                           ...
# 5032     {'total': 7, 'passengers': 4, 'crew': 3}
# 5033   {'total': 55, 'passengers': 50, 'crew': 5}
# 5034     {'total': 8, 'passengers': 3, 'crew': 5}
# 5035   {'total': 53, 'passengers': 44, 'crew': 9}
# 5036   {'total': 19, 'passengers': 14, 'crew': 5}
#
#                                        Fatalities  Ground  \
# 0      {'total': 27, 'passengers': 24, 'crew': 3}     0.0
# 1        {'total': 7, 'passengers': 3, 'crew': 4}     0.0
# 2      {'total': 40, 'passengers': 37, 'crew': 3}     0.0
# 3     {'total': 26, 'passengers': 16, 'crew': 10}     0.0
# 4      {'total': 19, 'passengers': 15, 'crew': 4}     0.0
# ...                                           ...     ...
# 5032     {'total': 7, 'passengers': 4, 'crew': 3}     0.0
# 5033   {'total': 48, 'passengers': 44, 'crew': 4}     0.0
# 5034     {'total': 8, 'passengers': 3, 'crew': 5}     0.0
# 5035   {'total': 53, 'passengers': 44, 'crew': 9}    19.0
# 5036   {'total': 19, 'passengers': 14, 'crew': 5}     0.0
#
#                                                 Summary  Aboard_Total  \
# 0     Crashed into approach lights while attempting ...            35
# 1     The plane struck a tree on a mountain ridge at...             7
# 2     The plane crashed into mountains while en rout...            40
# 3     Both aircraft crashed after a midair collision...            26
# 4     Crashed 10 miles east of Cagliari in the Sinna...            19
# ...                                                 ...           ...
# 5032  The cargo plane crashed into trees on takeoff....             7
# 5033  In heavy fog  the crew continued their descend...            55
# 5034  The survey fllight deviated from the approach ...             8
# 5035  The aircraft crashed into an industrial area d...            53
# 5036  Struck the slope of Mt Pintado located 25 km n...            19
#
#       Fatalities_Total      Operator_vs_Military  \
# 0                   27  British European Airways
# 1                    7         Flying Tiger Line
# 2                   40  Associated Air Transport
# 3                   26                  Military
# 4                   19      Linee Aeree Italiane
# ...                ...                       ...
# 5032                 7                  Aeroflot
# 5033                48                  Aeroflot
# 5034                 8                  Aeroflot
# 5035                53                  EgyptAir
# 5036                19                   Faucett
#
#                                                   Words
# 0     [light, attempt, land., error, judgement, part...
# 1     [strike, tree, mountain, ridge, elevation, 1,6...
# 2     [mountains, en, route., upon, enter, area, tur...
# 3     [midair, collision, approximately, 1,500, ft.,...
# 4     [10, east, cagliari, sinnai, mountains, wing, ...
# ...                                                 ...
# 5032  [tree, takeoff., deviation, preparation, error...
# 5033  [heavy, fog, continue, descend, decision, heig...
# 5034        [survey, deviate, pattern, mount, ostraya.]
# 5035  [industrial, area, land, attempt., lack, altit...
# 5036  [strike, slope, mt, pintado, locate, 25, km, n...
#
# [4969 rows x 18 columns]

# %%
df_1["Words"][df_1.Decade <= 1940].values
# Out:
# array([list(['solimoes', 'river,', 'extension', 'amazon', 'river.']),
#        list(['mountain', 'low', 'overcast.']),
#        list(['divert', 'washington', 'millville', 'heavy', 'traffic', 'washington', 'area.', 'near', 'fuel', 'exhaustion', 'force', 'carry', 'emergency', 'landing.', 'maneuver', 'find', 'suitable', 'location', 'heavy', 'snow,', 'strike', 'tree', 'crashed.', 'failure', 'weather', 'bureau', 'anticipate', 'minimum', 'condition', 'north', 'south', 'washington.', 'failure', 'caa', 'transmit', 'plan', 'millville', 'sufficient', 'time', 'alert', 'station', 'arrival', 'flight.']),
#        ..., list(['mountain', 'en', 'route.']),
#        list(['wing', 'fail', 'takeoff.']),
#        list(['burn', 'attempt', 'emergency', 'landing.'])], dtype=object)

# %%
def plot_word_cloud(dfValues):
    width = 12
    height = 12
    plt.figure(figsize=(width, height))
    #text = 'all your base are belong to us all of your base base base'
    wc = WordCloud().generate(" ".join([ i for j in dfValues for i in j]))
    plt.imshow(wc)
    # wordcloud = WordCloud(font_path='/Library/Fonts/Gotham-Bold.otf',width=1800,height=1400).generate(str(hr1_filter))
    # plt.imshow(wordcloud)
    plt.axis("off")
# plt.show()
def word_count(dfValues):
    return Counter([i for j in dfValues for i in j ])

# %%
plot_word_cloud(df_1["Words"][df_1.Decade <= 1940].values)

# %%
word_count(df_1["Words"][df_1.Decade <= 1940].values)
# Out:
# Counter({'land': 199,
#          'attempt': 180,
#          'engine': 152,
#          'take': 140,
#          'off': 137,
#          'strike': 106,
#          'poor': 106,
#          'weather': 101,
#          'en': 101,
#          'lose': 100,
#          'failure': 99,
#          'altitude': 96,
#          'mountain': 93,
#          'control': 86,
#          'hit': 85,
#          'low': 84,
#          'grind': 83,
#          'make': 80,
#          'wing': 69,
#          'due': 68,
#          'stall': 68,
#          'mail': 67,
#          'crashed.': 66,
#          'shortly': 65,
#          'fuel': 63,
#          'fire': 63,
#          'condition': 55,
#          'route.': 55,
#          'name': 55,
#          'tree': 54,
#          'fog': 54,
#          'one': 52,
#          'leave': 50,
#          'emergency': 48,
#          'two': 48,
#          'kill': 48,
#          'route': 47,
#          'near': 46,
#          'feet': 46,
#          'conditions.': 46,
#          'shoot': 46,
#          'ft.': 45,
#          'off.': 44,
#          'go': 44,
#          'encounter': 43,
#          'air': 43,
#          'airport.': 42,
#          'fog.': 42,
#          'result': 41,
#          'heavy': 40,
#          'flight.': 40,
#          'takeoff': 40,
#          'unknown': 40,
#          'turn': 40,
#          'aircraft.': 38,
#          'runway': 38,
#          'power': 38,
#          'force': 37,
#          'break': 37,
#          'fail': 37,
#          'radio': 37,
#          'burn': 36,
#          'loss': 36,
#          'find': 35,
#          'follow': 35,
#          'sea': 35,
#          'right': 34,
#          'short': 34,
#          'wreckage': 33,
#          'disappear': 33,
#          'killed.': 32,
#          'error.': 32,
#          'catch': 32,
#          'area': 32,
#          'captain': 31,
#          'south': 30,
#          'no.': 30,
#          'land.': 30,
#          'engines': 30,
#          'landing.': 29,
#          'run': 29,
#          'course': 29,
#          'ice': 29,
#          'hill': 29,
#          'try': 28,
#          'visibility.': 28,
#          'field': 28,
#          'first': 28,
#          'mt.': 27,
#          'flames.': 27,
#          'ground.': 27,
#          'burst': 27,
#          'descend': 27,
#          'high': 26,
#          'water': 26,
#          'severe': 26,
#          'slope': 25,
#          'km': 25,
#          'fire.': 25,
#          'error': 25,
#          'accident': 25,
#          'ditch': 24,
#          'mountains': 24,
#          'weather.': 24,
#          'maintain': 24,
#          'strong': 24,
#          'return': 24,
#          'line': 24,
#          'flame': 24,
#          'field.': 23,
#          'contact': 23,
#          'time': 22,
#          'become': 22,
#          'minutes': 22,
#          'runway.': 22,
#          'part': 22,
#          'instrument': 22,
#          'explode': 22,
#          'visibility': 21,
#          'takeoff.': 20,
#          'height': 20,
#          'adverse': 20,
#          'experience': 20,
#          'sea.': 20,
#          'failure.': 20,
#          'report': 20,
#          'climb': 20,
#          'north': 19,
#          'clear': 19,
#          'found.': 19,
#          'wind': 19,
#          'decide': 19,
#          '3': 19,
#          'collision': 19,
#          'without': 18,
#          'british': 18,
#          'possible': 18,
#          'turbulence': 18,
#          'snow': 18,
#          'collide': 18,
#          'midair': 18,
#          'storm.': 18,
#          '2': 17,
#          'contribute': 17,
#          'never': 17,
#          'locate': 17,
#          'top': 17,
#          'aboard': 17,
#          'reason': 17,
#          'burned.': 17,
#          'wooded': 17,
#          'terrain': 17,
#          'back': 17,
#          'prescribe': 17,
#          '50': 17,
#          'divert': 16,
#          'carry': 16,
#          'ocean': 16,
#          'west': 16,
#          'lead': 16,
#          'river': 16,
#          'icing.': 16,
#          'last': 16,
#          'runway,': 16,
#          'possibly': 16,
#          'thunderstorm': 16,
#          'mountain.': 16,
#          'dive': 16,
#          'occur': 16,
#          'avoid': 16,
#          'unknown.': 16,
#          'snowstorm.': 16,
#          'structural': 16,
#          'passengers': 16,
#          'circumstances.': 16,
#          'plan': 15,
#          'action': 15,
#          'may': 15,
#          'mountainous': 15,
#          'speed': 15,
#          'enter': 15,
#          'passenger': 15,
#          'come': 15,
#          'later': 15,
#          'port': 15,
#          'suffer': 15,
#          'cloud': 15,
#          'night': 15,
#          'military': 15,
#          'engine.': 14,
#          'position': 14,
#          'range': 14,
#          'safe': 14,
#          'reduce': 14,
#          'explosion': 14,
#          'island': 14,
#          'airplane': 14,
#          'fog,': 14,
#          'altitude.': 14,
#          'plane.': 14,
#          'failed.': 14,
#          'circle': 14,
#          'rain': 14,
#          'area.': 13,
#          'factor': 13,
#          'airport,': 13,
#          'de': 13,
#          '10': 13,
#          'san': 13,
#          'new': 13,
#          '1': 13,
#          'continue': 13,
#          'cruise': 13,
#          'improper': 13,
#          'unable': 13,
#          '15': 13,
#          'side': 13,
#          'bank': 13,
#          'off,': 13,
#          'test': 13,
#          'japanese': 13,
#          'maneuver': 12,
#          'later.': 12,
#          'approach.': 12,
#          'coast': 12,
#          'island.': 12,
#          'tail': 12,
#          'use': 12,
#          'determined.': 12,
#          'build': 12,
#          'several': 12,
#          'aircraft,': 12,
#          'pilot,': 12,
#          'boat': 12,
#          'sink': 12,
#          'alternate': 12,
#          'conditions,': 12,
#          'train': 12,
#          'see': 12,
#          'german': 12,
#          'flight,': 12,
#          'english': 12,
#          'three': 12,
#          'open': 12,
#          'airship': 12,
#          'gain': 11,
#          'rise': 11,
#          'east': 11,
#          'nose': 11,
#          'visual': 11,
#          'close': 11,
#          'head': 11,
#          'descent': 11,
#          'navigational': 11,
#          'ship': 11,
#          'tank': 11,
#          'end': 11,
#          'separate': 11,
#          'terrain.': 11,
#          '20': 11,
#          'in-flight': 11,
#          'reasons.': 11,
#          'feet.': 11,
#          'lake': 11,
#          'thunderstorm.': 11,
#          'bay': 11,
#          'atlantic': 11,
#          'proper': 11,
#          'storm': 11,
#          'river.': 10,
#          'crew.': 10,
#          'allow': 10,
#          'final': 10,
#          'remain': 10,
#          'start': 10,
#          'could': 10,
#          'decision': 10,
#          'know': 10,
#          'undetermined.': 10,
#          'propeller': 10,
#          'level': 10,
#          'feet,': 10,
#          'miss': 10,
#          'second': 10,
#          'execute': 10,
#          'cabin': 10,
#          'land,': 10,
#          'northeast': 10,
#          'die': 10,
#          'establish': 10,
#          'point': 10,
#          'overcast': 10,
#          '500': 10,
#          'blow': 10,
#          'bad': 10,
#          'drop': 10,
#          'pass': 10,
#          'four': 10,
#          'northwest': 9,
#          'prior': 9,
#          'wing.': 9,
#          'mt': 9,
#          'either': 9,
#          'lack': 9,
#          'peak': 9,
#          'begin': 9,
#          'destination': 9,
#          'winds.': 9,
#          '4': 9,
#          'small': 9,
#          'initial': 9,
#          'insufficient': 9,
#          '5': 9,
#          'fuselage': 9,
#          'lightning': 9,
#          'lower': 9,
#          'dense': 9,
#          '300': 9,
#          'perform': 9,
#          'fell': 9,
#          'foggy': 9,
#          'sufficient': 8,
#          'able': 8,
#          'determine': 8,
#          'navigation': 8,
#          'altitude,': 8,
#          'overrun': 8,
#          'load': 8,
#          'among': 8,
#          '30': 8,
#          'overshoot': 8,
#          '100': 8,
#          'visibility,': 8,
#          '40': 8,
#          'dc-3': 8,
#          'takeoff,': 8,
#          'ridge': 8,
#          '8': 8,
#          'landing,': 8,
#          'procedure': 8,
#          'roll': 8,
#          'stop': 8,
#          'design': 8,
#          'ocean.': 8,
#          'procedures': 8,
#          'full': 8,
#          'operate': 8,
#          'house': 8,
#          'cockpit': 8,
#          'render': 8,
#          'smoke': 8,
#          'get': 8,
#          'mast': 8,
#          'seaplane': 8,
#          'spin': 8,
#          'complete': 8,
#          'french': 8,
#          'night,': 8,
#          'penetrate': 8,
#          'ever': 8,
#          'deviate': 8,
#          'u.s.': 8,
#          'plunge': 8,
#          '60': 8,
#          'approach,': 8,
#          'vertical': 8,
#          'supply': 8,
#          'airliner': 8,
#          'injured.': 8,
#          'believe': 7,
#          'elevator': 7,
#          'survived.': 7,
#          '12': 7,
#          'wrong': 7,
#          'mountain,': 7,
#          'problems': 7,
#          'york': 7,
#          'rescue': 7,
#          'accident.': 7,
#          'message': 7,
#          'seat': 7,
#          'probably': 7,
#          'inadvertent': 7,
#          'along': 7,
#          'cover': 7,
#          'likely': 7,
#          'mountainside': 7,
#          'fighter.': 7,
#          'fighter': 7,
#          'bomber': 7,
#          'apparently': 7,
#          'parachute': 7,
#          'southwest': 7,
#          'trace': 7,
#          'fighters.': 7,
#          'anti-aircraft': 7,
#          'ignite': 7,
#          'hold': 7,
#          'another': 7,
#          'towards': 7,
#          'route,': 7,
#          'failed,': 7,
#          'impact.': 7,
#          'burbank': 7,
#          'pilot.': 7,
#          'vfr': 7,
#          'surface': 7,
#          'rear': 7,
#          'five': 7,
#          'survive': 7,
#          'immediately': 7,
#          'salt': 7,
#          'ft.,': 6,
#          'take-off': 6,
#          '150': 6,
#          'separation': 6,
#          'board': 6,
#          '4,000': 6,
#          'control,': 6,
#          'third': 6,
#          'private': 6,
#          'bay.': 6,
#          'veer': 6,
#          'faulty': 6,
#          'leg': 6,
#          'destination.': 6,
#          'crash.': 6,
#          'feather': 6,
#          'black': 6,
#          'carburetor': 6,
#          'beyond': 6,
#          'andes': 6,
#          'weather,': 6,
#          'pull': 6,
#          'next': 6,
#          'occupants': 6,
#          'us': 6,
#          'vent': 6,
#          'heater': 6,
#          'john': 6,
#          'proceed': 6,
#          "pilot's": 6,
#          'abort': 6,
#          'light': 6,
#          'adequate': 6,
#          'summit': 6,
#          'control.': 6,
#          'position.': 6,
#          'hillside': 6,
#          'lightning.': 6,
#          'depart': 6,
#          'dangerously': 6,
#          'obscure': 6,
#          'sea,': 6,
#          '.': 6,
#          'would': 6,
#          'roof': 6,
#          'static': 6,
#          'source': 6,
#          'bear': 6,
#          'cut': 6,
#          'sank.': 6,
#          'american': 6,
#          'attitude': 6,
#          'company': 6,
#          'channel': 6,
#          'body': 6,
#          'actress': 6,
#          'hill.': 6,
#          'observe': 6,
#          'tear': 6,
#          '3,000': 6,
#          'commercial': 6,
#          'army': 6,
#          'la': 6,
#          '1,000': 6,
#          'impact': 6,
#          'up.': 6,
#          'well': 6,
#          'discharge': 6,
#          'judgment': 6,
#          'violent': 6,
#          'wave': 6,
#          'onto': 6,
#          'wire': 6,
#          'circumstances': 6,
#          'overcast.': 5,
#          'minimum': 5,
#          'transmit': 5,
#          'paris': 5,
#          'operation': 5,
#          'sabotage': 5,
#          'command': 5,
#          'change': 5,
#          'realize': 5,
#          'attempt.': 5,
#          'discover': 5,
#          'identify': 5,
#          'engines.': 5,
#          'spiral': 5,
#          'gust': 5,
#          'suddenly': 5,
#          'prevent': 5,
#          'clearance': 5,
#          "aircraft's": 5,
#          'inadequate': 5,
#          'apply': 5,
#          'years': 5,
#          'bounce': 5,
#          'steep': 5,
#          'almost': 5,
#          'properly': 5,
#          'abandon': 5,
#          '2,000': 5,
#          'mountains.': 5,
#          'fire,': 5,
#          'require': 5,
#          'instead': 5,
#          'loose': 5,
#          'center': 5,
#          'signal': 5,
#          'trouble': 5,
#          'inability': 5,
#          'house.': 5,
#          'mile': 5,
#          'southeast': 5,
#          'fuel.': 5,
#          'go-around': 5,
#          'cylinder': 5,
#          'maneuver.': 5,
#          'rio': 5,
#          'rapidly': 5,
#          'extremely': 5,
#          'excess': 5,
#          'turn.': 5,
#          '14': 5,
#          'ally': 5,
#          'around': 5,
#          'intend': 5,
#          'bail': 5,
#          'broke-up': 5,
#          'turbulence.': 5,
#          'structure': 5,
#          'hill,': 5,
#          'mountains,': 5,
#          'rough': 5,
#          'bomb': 5,
#          'outer': 5,
#          'malfunction': 5,
#          'send': 5,
#          'witness': 5,
#          'dc-3.': 5,
#          'tell': 5,
#          'set': 5,
#          'long': 5,
#          'engineer': 5,
#          'ridge,': 5,
#          'soldier': 5,
#          'height,': 5,
#          'approximately': 5,
#          'field,': 5,
#          'drag': 5,
#          'available': 5,
#          'gulf': 5,
#          'nm': 5,
#          'include': 5,
#          'rain.': 5,
#          'city': 5,
#          'attack': 5,
#          'rudder': 5,
#          'tip': 5,
#          'horizontal': 5,
#          'oil': 5,
#          'mid-air': 5,
#          'darkness': 5,
#          'mediterranean': 5,
#          'front': 5,
#          'chimney': 5,
#          'also': 5,
#          'postal': 5,
#          'days': 5,
#          "plane's": 5,
#          'le': 5,
#          'bourget': 5,
#          'hydrogen': 5,
#          'alert': 4,
#          'station': 4,
#          'least': 4,
#          'airways': 4,
#          'plane,': 4,
#          'heavily': 4,
#          'airborne': 4,
#          'remove': 4,
#          'lock': 4,
#          'condtions.': 4,
#          'trees.': 4,
#          'conduct': 4,
#          'standard': 4,
#          'atc': 4,
#          'way': 4,
#          'official': 4,
#          'choose': 4,
#          'hours': 4,
#          'pan': 4,
#          'blame': 4,
#          'six': 4,
#          'excessive': 4,
#          'fatigue': 4,
#          'touch': 4,
#          '"star': 4,
#          'operator': 4,
#          'continuation': 4,
#          'jump': 4,
#          'mechanic': 4,
#          'transfer': 4,
#          'inadvertently': 4,
#          'gasoline': 4,
#          'occurred.': 4,
#          'ifr': 4,
#          'francisco': 4,
#          'speed,': 4,
#          'stray': 4,
#          'course,': 4,
#          'santa': 4,
#          'drift': 4,
#          'months': 4,
#          'fall': 4,
#          'prepare': 4,
#          'destroy': 4,
#          'elk': 4,
#          'deviation': 4,
#          '11,000': 4,
#          'disintegrate': 4,
#          'higher': 4,
#          'exercise': 4,
#          'distress': 4,
#          'effect': 4,
#          'erupt': 4,
#          'airfield': 4,
#          'ten': 4,
#          'soon': 4,
#          'starboard': 4,
#          'evidence': 4,
#          'gear': 4,
#          'sound': 4,
#          'school': 4,
#          'snowstorm': 4,
#          'cleveland': 4,
#          '70': 4,
#          'sharp': 4,
#          'degree': 4,
#          'cartwheel': 4,
#          'snowstorm,': 4,
#          'proximity': 4,
#          'large': 4,
#          'place': 4,
#          'navy': 4,
#          'president': 4,
#          'england': 4,
#          'war': 4,
#          'rupture': 4,
#          'officer': 4,
#          'lt.': 4,
#          'raf': 4,
#          'water.': 4,
#          'reach': 4,
#          'obtain': 4,
#          'husband': 4,
#          'wide': 4,
#          'involve': 4,
#          'state': 4,
#          'ground,': 4,
#          'despite': 4,
#          'mexico': 4,
#          'trees,': 4,
#          'month': 4,
#          '32': 4,
#          'cash': 4,
#          'coast,': 4,
#          'ask': 4,
#          '200': 4,
#          'thunderstorms': 4,
#          'spatial': 4,
#          'bring': 4,
#          'whether': 4,
#          'swerve': 4,
#          'increase': 4,
#          'pitch': 4,
#          'accident,': 4,
#          'clouds,': 4,
#          'debris': 4,
#          'surround': 4,
#          'immediate': 4,
#          'unite': 4,
#          'las': 4,
#          'him.': 4,
#          'royal': 4,
#          'forward': 4,
#          'von': 4,
#          'exploded.': 4,
#          'dead': 4,
#          'save': 4,
#          'downdraft': 4,
#          'aboard.': 4,
#          '"city': 4,
#          'section': 4,
#          '700': 4,
#          'motor': 4,
#          'damage': 4,
#          'float': 4,
#          'canyon,': 4,
#          'conditons.': 4,
#          'deliver': 4,
#          'accidental': 4,
#          'condition,': 4,
#          'schedule': 4,
#          'abrupt': 4,
#          'attribute': 4,
#          'direct': 4,
#          'consider': 4,
#          'grove': 4,
#          'carbon': 4,
#          'river,': 3,
#          'washington': 3,
#          'exhaustion': 3,
#          'suitable': 3,
#          'caa': 3,
#          'swedish': 3,
#          'ils': 3,
#          'safety': 3,
#          'airway.': 3,
#          'range,': 3,
#          'foot': 3,
#          '9': 3,
#          'remote': 3,
#          'release': 3,
#          'iceland': 3,
#          'invert': 3,
#          'rainstorm.': 3,
#          'inaugural': 3,
#          'later,': 3,
#          'star': 3,
#          'help': 3,
#          'many': 3,
#          'passengers.': 3,
#          'charter': 3,
#          'flow': 3,
#          'spark': 3,
#          'think': 3,
#          'disappeared.': 3,
#          'single': 3,
#          'knoll': 3,
#          'nose-down': 3,
#          'co-pilot': 3,
#          'process': 3,
#          'overflow': 3,
#          'slip': 3,
#          'intake': 3,
#          'flaw': 3,
#          'summit,': 3,
#          'extreme': 3,
#          'ii.': 3,
#          'board.': 3,
#          'incorrect': 3,
#          'path.': 3,
#          'maria': 3,
#          'ceiling': 3,
#          'far': 3,
#          'worsen': 3,
#          'commit': 3,
#          'fast.': 3,
#          'buffet': 3,
#          '4,500': 3,
#          'airlines': 3,
#          'necessary': 3,
#          'wellington': 3,
#          'heat': 3,
#          'formation.': 3,
#          'time,': 3,
#          'shut': 3,
#          'undetermined': 3,
#          'origin': 3,
#          'compartment': 3,
#          'electrical': 3,
#          'regain': 3,
#          'search': 3,
#          'failure,': 3,
#          'starvation.': 3,
#          'flap': 3,
#          'survivor.': 3,
#          'airspeed': 3,
#          '800': 3,
#          'minimums': 3,
#          'elevation': 3,
#          'unusual': 3,
#          'newhall': 3,
#          'clouds.': 3,
#          'inclement': 3,
#          'base': 3,
#          'pick': 3,
#          '11': 3,
#          'fuel,': 3,
#          'lunghwa': 3,
#          'neighborhood': 3,
#          'accumulation': 3,
#          'starvation': 3,
#          'little': 3,
#          'onboard': 3,
#          'normandy': 3,
#          'invasion.': 3,
#          'hole': 3,
#          'directly': 3,
#          'hours,': 3,
#          'time.': 3,
#          'happen': 3,
#          'anchor': 3,
#          "captain's": 3,
#          'handle': 3,
#          'clipper."': 3,
#          'lieutenant': 3,
#          'kennedy': 3,
#          'kennedy,': 3,
#          'world': 3,
#          'guide': 3,
#          'attemping': 3,
#          'trans-atlantic': 3,
#          'slop': 3,
#          'drowned.': 3,
#          'weaken': 3,
#          "company's": 3,
#          'france.': 3,
#          '40,': 3,
#          'home': 3,
#          'unsuccessful': 3,
#          'channel.': 3,
#          'normal': 3,
#          'clipper.': 3,
#          'personnel': 3,
#          'dispatch': 3,
#          'thunderstorms.': 3,
#          'unfavorable': 3,
#          '7,000': 3,
#          '45': 3,
#          'main': 3,
#          'wheel': 3,
#          'again.': 3,
#          'left,': 3,
#          'houses.': 3,
#          'corn': 3,
#          'safely.': 3,
#          'collision.': 3,
#          'william': 3,
#          'smith': 3,
#          'hour': 3,
#          'newark.': 3,
#          'exit': 3,
#          'car': 3,
#          'fort': 3,
#          'city.': 3,
#          "crew's": 3,
#          'execution': 3,
#          'tower': 3,
#          'lost,': 3,
#          'turn,': 3,
#          'twenty': 3,
#          'disorientation': 3,
#          'civil': 3,
#          'check': 3,
#          'function': 3,
#          'absence': 3,
#          'hillside.': 3,
#          'move': 3,
#          'skill': 3,
#          'exact': 3,
#          'border.': 3,
#          'wings.': 3,
#          'recover': 3,
#          'plant': 3,
#          'government': 3,
#          'sight': 3,
#          'limit': 3,
#          'technique': 3,
#          'western': 3,
#          'clip': 3,
#          'bottom': 3,
#          'blind': 3,
#          'hundred': 3,
#          'slow': 3,
#          'spot': 3,
#          'flip': 3,
#          'obstruction': 3,
#          'stalled,': 3,
#          'duke': 3,
#          'canyon': 3,
#          'safely': 3,
#          'dangerous': 3,
#          'overfly': 3,
#          'pull-up': 3,
#          'seas.': 3,
#          'dutch': 3,
#          'bind': 3,
#          'm.': 3,
#          'offshore.': 3,
#          'men': 3,
#          'farm': 3,
#          'sudden': 3,
#          'harbor': 3,
#          'stabilizer': 3,
#          'develop': 3,
#          'mechanical': 3,
#          'stall.': 3,
#          'seven': 3,
#          'since': 3,
#          'lost.': 3,
#          'leak': 3,
#          'quit': 3,
#          'order': 3,
#          'sightsee': 3,
#          '400': 3,
#          'apple': 3,
#          'delivery': 3,
#          'gale': 3,
#          'upon': 3,
#          'antenna': 3,
#          'blizzard.': 3,
#          'old': 3,
#          'yards': 3,
#          'detach': 3,
#          'day': 3,
#          'collapse': 3,
#          'london': 3,
#          'beach': 3,
#          'blade': 3,
#          'telephone': 3,
#          'call': 3,
#          'mount': 3,
#          'out.': 3,
#          'necessitate': 3,
#          'aviator': 3,
#          'local': 3,
#          'definitely': 3,
#          'reception': 3,
#          'moor': 3,
#          'shore': 3,
#          'affect': 3,
#          'gravity': 3,
#          '-': 3,
#          'chief': 3,
#          'power.': 3,
#          'uncontrollable': 3,
#          'departure': 3,
#          'number': 3,
#          'c.': 3,
#          'rest': 3,
#          'channel,': 3,
#          'ocean,': 3,
#          'engine,': 3,
#          'tanks.': 3,
#          '6': 3,
#          'cross': 3,
#          'dioxide': 3,
#          'group': 3,
#          'avro': 3,
#          'millville': 2,
#          'traffic': 2,
#          'location': 2,
#          'snow,': 2,
#          'anticipate': 2,
#          'washington.': 2,
#          'arrival': 2,
#          'pacific': 2,
#          '2,500': 2,
#          'erroneous': 2,
#          'moments': 2,
#          'week': 2,
#          'airborne,': 2,
#          'twelve': 2,
#          'spencer': 2,
#          'none': 2,
#          'condition.': 2,
#          '41,': 2,
#          'boy': 2,
#          'contamination.': 2,
#          'el': 2,
#          'designate': 2,
#          'although': 2,
#          '25': 2,
#          'bury': 2,
#          'cerro': 2,
#          'del': 2,
#          'hand': 2,
#          'pattern': 2,
#          'keep': 2,
#          'lookout': 2,
#          'traffic.': 2,
#          'vancouver': 2,
#          'area,': 2,
#          'jose.': 2,
#          'act': 2,
#          'discontinue': 2,
#          ...})

# %%
plot_word_cloud(df_1["Words"][(df_1.Decade > 1940) & (df_1.Decade <= 1980)].values)

# %%
word_count(df_1["Words"][(df_1.Decade > 1940) & (df_1.Decade <= 1980)].values)
# Out:
# Counter({'land': 508,
#          'engine': 413,
#          'take': 395,
#          'off': 362,
#          'failure': 345,
#          'strike': 329,
#          'attempt': 326,
#          'runway': 320,
#          'control': 312,
#          'altitude': 243,
#          'weather': 229,
#          'lose': 228,
#          'mountain': 212,
#          'make': 205,
#          'due': 203,
#          'leave': 201,
#          'loss': 187,
#          'right': 185,
#          'en': 182,
#          'result': 178,
#          'grind': 177,
#          'descend': 175,
#          'shortly': 175,
#          'no.': 174,
#          'short': 171,
#          'poor': 166,
#          'wing': 160,
#          'takeoff': 160,
#          'hit': 160,
#          'fire': 160,
#          'ft.': 159,
#          'approach.': 147,
#          'fail': 144,
#          'air': 141,
#          'emergency': 138,
#          'crashed.': 136,
#          'fuel': 135,
#          'runway.': 134,
#          'conditions.': 133,
#          'condition': 132,
#          'one': 131,
#          'two': 131,
#          'error.': 129,
#          'stall': 127,
#          'break': 125,
#          'follow': 121,
#          'airport.': 121,
#          'kill': 119,
#          'low': 118,
#          'power': 118,
#          'takeoff.': 117,
#          'tree': 115,
#          'descent': 114,
#          'turn': 114,
#          'high': 114,
#          'route.': 113,
#          'fire.': 110,
#          'continue': 108,
#          'feet': 108,
#          '2': 105,
#          'minutes': 105,
#          'lead': 103,
#          'improper': 102,
#          'captain': 101,
#          'off.': 100,
#          'vfr': 100,
#          'climb': 99,
#          'go': 98,
#          'aircraft.': 97,
#          'heavy': 96,
#          'km': 95,
#          'killed.': 92,
#          'force': 91,
#          'route': 90,
#          'instrument': 88,
#          'use': 87,
#          'visual': 87,
#          '3': 82,
#          'area': 79,
#          'severe': 79,
#          'final': 78,
#          'return': 78,
#          'try': 76,
#          'lack': 76,
#          'maintain': 76,
#          'gear': 76,
#          'accident': 75,
#          'land.': 74,
#          'catch': 74,
#          'speed': 74,
#          'report': 74,
#          'airplane': 73,
#          'could': 72,
#          'shoot': 72,
#          'mt.': 70,
#          'engines': 69,
#          'ground.': 69,
#          'slope': 68,
#          'enter': 67,
#          'find': 67,
#          'minimum': 67,
#          'sea': 66,
#          'near': 66,
#          'ifr': 66,
#          'collide': 66,
#          'experience': 65,
#          'altitude.': 64,
#          'time': 64,
#          'contribute': 64,
#          'landing.': 64,
#          'engine.': 64,
#          'propeller': 63,
#          'fog': 63,
#          'unknown.': 62,
#          'system': 62,
#          'aboard': 61,
#          '1': 61,
#          'terrain': 61,
#          'fatigue': 60,
#          'adverse': 60,
#          'error': 59,
#          'rain': 59,
#          'height': 59,
#          'course': 59,
#          'name': 58,
#          'failure.': 58,
#          'plan': 58,
#          'without': 58,
#          'midair': 57,
#          'bank': 57,
#          'locate': 57,
#          'weather.': 56,
#          'become': 56,
#          'contact': 56,
#          'possible': 55,
#          'decision': 55,
#          'part': 54,
#          'turbulence': 54,
#          'collision': 54,
#          'in-flight': 54,
#          'helicopter': 54,
#          'fog.': 53,
#          'hill': 53,
#          'run': 53,
#          'prescribe': 53,
#          'inadequate': 53,
#          '4': 53,
#          'runway,': 53,
#          'visibility': 52,
#          'steep': 52,
#          'mountain.': 52,
#          'ice': 51,
#          'flight.': 51,
#          'ditch': 51,
#          'radio': 51,
#          'second': 51,
#          'passenger': 51,
#          'light': 50,
#          'miss': 50,
#          'water': 50,
#          'explode': 50,
#          'burst': 49,
#          'encounter': 49,
#          'clear': 49,
#          'flames.': 49,
#          'three': 48,
#          'warn': 48,
#          'wreckage': 48,
#          'carry': 47,
#          'factor': 46,
#          'procedures': 46,
#          "aircraft's": 46,
#          'position': 46,
#          'elevator': 45,
#          'may': 45,
#          'come': 45,
#          'reason': 45,
#          'initiate': 45,
#          'burn': 45,
#          '10': 44,
#          'north': 44,
#          'airport,': 44,
#          'flap': 44,
#          'divert': 44,
#          'main': 44,
#          'safe': 43,
#          'night': 43,
#          'nose': 43,
#          'navigational': 43,
#          'go-around': 43,
#          'malfunction': 43,
#          'approach,': 43,
#          'ils': 43,
#          'bomb': 42,
#          'rate': 42,
#          'cabin': 42,
#          'atc': 42,
#          'sea.': 41,
#          'end': 41,
#          'off,': 41,
#          'pitch': 41,
#          'terrain.': 41,
#          'reach': 40,
#          'back': 40,
#          'ocean': 40,
#          'start': 40,
#          'roll': 40,
#          'approximately': 39,
#          'separation': 39,
#          'field': 39,
#          "crew's": 39,
#          'military': 39,
#          'mountains': 38,
#          'east': 38,
#          'wrong': 38,
#          'first': 38,
#          'cloud': 38,
#          'structural': 38,
#          'snow': 38,
#          'dive': 38,
#          'tail': 38,
#          'feather': 38,
#          'overrun': 37,
#          'passengers': 37,
#          'takeoff,': 37,
#          'load': 37,
#          'unknown': 37,
#          'feet.': 36,
#          'maintenance': 36,
#          'area.': 36,
#          'procedures.': 36,
#          'crew.': 36,
#          'excessive': 35,
#          'execute': 35,
#          'thunderstorm': 35,
#          'reference': 35,
#          'train': 35,
#          'line': 35,
#          'separate': 35,
#          'see': 35,
#          'action': 34,
#          'occur': 34,
#          'begin': 34,
#          'san': 34,
#          'four': 34,
#          'mountainous': 34,
#          'cruise': 34,
#          'damage': 34,
#          'decide': 34,
#          'explosion': 34,
#          'impact': 33,
#          'several': 33,
#          'premature': 33,
#          "captain's": 33,
#          'wind': 33,
#          'insufficient': 33,
#          'electrical': 33,
#          'flame': 32,
#          'place': 32,
#          'set': 32,
#          'monitor': 32,
#          'level': 32,
#          'navigation': 32,
#          'airliner': 32,
#          'south': 32,
#          'lake': 32,
#          'unable': 31,
#          '5': 31,
#          'detonation': 31,
#          'attitude': 31,
#          'abort': 31,
#          'avoid': 31,
#          'side': 31,
#          'cockpit': 31,
#          '20': 31,
#          'sink': 31,
#          "pilot's": 30,
#          'center': 30,
#          'jet': 30,
#          'base': 30,
#          'head': 30,
#          'disappear': 30,
#          'never': 30,
#          'properly': 30,
#          'explosive': 30,
#          '30': 29,
#          'remain': 29,
#          'proper': 29,
#          'accident.': 29,
#          'rudder': 29,
#          'fuselage': 29,
#          'conditions,': 29,
#          'rotor': 29,
#          'aircraft,': 28,
#          'fighter': 28,
#          'house': 28,
#          'new': 28,
#          'thrust': 28,
#          'traffic': 28,
#          'incorrect': 28,
#          'design': 28,
#          'rear': 28,
#          'know': 27,
#          'burned.': 27,
#          'control.': 27,
#          'starboard': 27,
#          'wooded': 27,
#          'able': 27,
#          'along': 27,
#          'undetermined': 27,
#          'pass': 27,
#          'shut': 27,
#          'another': 27,
#          'give': 27,
#          'maneuver': 27,
#          'destroy': 26,
#          'stop': 26,
#          'u.s.': 26,
#          'believe': 26,
#          'instead': 26,
#          'no.1': 26,
#          '15': 26,
#          'tank': 26,
#          'procedure': 26,
#          'members': 26,
#          'crash.': 26,
#          'degrees': 26,
#          'hydraulic': 26,
#          'visibility.': 26,
#          'last': 25,
#          'message': 25,
#          'northeast': 25,
#          'position.': 25,
#          'normal': 25,
#          'suffer': 25,
#          'deviate': 25,
#          'failed.': 25,
#          'critical': 25,
#          'descent.': 25,
#          'slide': 25,
#          'complete': 25,
#          'state': 25,
#          'ocean.': 25,
#          'close': 25,
#          'engines.': 25,
#          'reduce': 25,
#          'hold': 25,
#          'limit': 24,
#          'sufficient': 24,
#          'water.': 24,
#          'collision.': 24,
#          'immediately': 24,
#          'tower': 24,
#          'soon': 24,
#          'radar': 24,
#          'observe': 24,
#          'overshoot': 24,
#          'reverse': 24,
#          'cover': 24,
#          'blade': 24,
#          'peak': 24,
#          'altimeter': 23,
#          'operate': 23,
#          'port': 23,
#          'thunderstorm.': 23,
#          'touch': 23,
#          'allow': 23,
#          'flight,': 23,
#          'undetermined.': 23,
#          'lift': 23,
#          'go-around.': 23,
#          'onto': 23,
#          '.': 23,
#          'gain': 23,
#          'la': 23,
#          'determine': 23,
#          'prior': 23,
#          'west': 23,
#          'full': 22,
#          'beyond': 22,
#          '6': 22,
#          'path': 22,
#          'possibly': 22,
#          'base.': 22,
#          'icing.': 22,
#          'improperly': 22,
#          'third': 22,
#          'penetrate': 22,
#          'fell': 22,
#          'device': 22,
#          'jungle': 22,
#          'found.': 21,
#          'drop': 21,
#          'strong': 21,
#          'probable': 21,
#          'initial': 21,
#          'airspeed': 21,
#          'altitude,': 21,
#          '200': 21,
#          'also': 21,
#          'uncontrollable': 21,
#          'field.': 21,
#          'system.': 21,
#          'open': 21,
#          'change': 21,
#          'engine,': 21,
#          'spin': 21,
#          'windshear.': 21,
#          '1,000': 21,
#          'door': 21,
#          'lock': 21,
#          'de': 21,
#          'meter': 21,
#          'plane.': 21,
#          'turbulence.': 21,
#          'get': 21,
#          'judgement': 20,
#          'wing.': 20,
#          'atlantic': 20,
#          'disorientation': 20,
#          'river': 20,
#          'smoke': 20,
#          'suddenly': 20,
#          'build': 20,
#          'clearance': 20,
#          'northwest': 20,
#          'mile': 20,
#          'command': 20,
#          'plunge': 20,
#          'mt': 20,
#          'pilot-in-command': 20,
#          'pilot.': 19,
#          'deviation': 19,
#          'upon': 19,
#          'later.': 19,
#          'although': 19,
#          'require': 19,
#          'vertical': 19,
#          'deteriorate': 19,
#          '100': 19,
#          '300': 19,
#          'city': 19,
#          'include': 19,
#          'trim': 19,
#          'horizontal': 19,
#          '8': 19,
#          'forward': 19,
#          'prepare': 19,
#          'effect': 19,
#          '40': 19,
#          'well': 19,
#          'rise': 19,
#          'attempt.': 19,
#          'information': 18,
#          'small': 18,
#          'crack': 18,
#          'thunderstorms': 18,
#          'island': 18,
#          'nm': 18,
#          'drift': 18,
#          'glide': 18,
#          'wheel': 18,
#          'correct': 18,
#          'stabilizer': 18,
#          'faulty': 18,
#          'cross': 18,
#          'pressure': 18,
#          'fatigue.': 18,
#          '"clipper': 18,
#          'despite': 18,
#          'pull': 18,
#          'point': 18,
#          'mountains.': 18,
#          'feet,': 18,
#          'ft.,': 18,
#          'ridge': 17,
#          'trees.': 17,
#          'surface': 17,
#          'still': 17,
#          'lower': 17,
#          'section': 17,
#          'spatial': 17,
#          'departure': 17,
#          'rest': 17,
#          'fuel.': 17,
#          'reasons.': 17,
#          'eventually': 17,
#          'later': 17,
#          'bay': 17,
#          'top': 17,
#          'fog,': 17,
#          'team': 17,
#          'degree': 17,
#          'cessna': 17,
#          'either': 17,
#          'controller': 17,
#          'dc-9': 17,
#          'apply': 17,
#          'disintegrate': 17,
#          'distance': 17,
#          'procedural': 17,
#          'procedure.': 16,
#          '50': 16,
#          'circle': 16,
#          'bolt': 16,
#          '500': 16,
#          'would': 16,
#          'officer': 16,
#          'attribute': 16,
#          '18': 16,
#          'turn,': 16,
#          'mechanical': 16,
#          'increase': 16,
#          'angle': 16,
#          'oil': 16,
#          'course.': 16,
#          'fl': 16,
#          'blow': 16,
#          'fracture': 16,
#          'delay': 16,
#          'subsequent': 16,
#          'undershoot': 16,
#          'available': 16,
#          'seat': 16,
#          'errors': 16,
#          'route,': 16,
#          'prevent': 16,
#          'lightning': 16,
#          'power.': 16,
#          'adequate': 16,
#          'number': 16,
#          'storm.': 16,
#          'pattern': 16,
#          'cause.': 15,
#          'hear': 15,
#          'pilot,': 15,
#          'bounce': 15,
#          'recover': 15,
#          'co-pilot': 15,
#          'detect': 15,
#          'total': 15,
#          'overload': 15,
#          'exceed': 15,
#          'provide': 15,
#          'aileron': 15,
#          'aft': 15,
#          'engineer': 15,
#          'bad': 15,
#          'recovery.': 15,
#          'range': 15,
#          'plane,': 15,
#          'die': 15,
#          'days': 15,
#          'mount': 15,
#          'shallow': 15,
#          'rain.': 15,
#          'almost': 15,
#          'veer': 15,
#          'mid-air': 15,
#          'past': 15,
#          '7': 14,
#          'type': 14,
#          'night,': 14,
#          'tip': 14,
#          'down.': 14,
#          'night.': 14,
#          'towards': 14,
#          'overloaded.': 14,
#          'international': 14,
#          'perform': 14,
#          'ft': 14,
#          'however,': 14,
#          'vor': 14,
#          'marginal': 14,
#          'schedule': 14,
#          'safely': 14,
#          'safely.': 14,
#          'sudden': 14,
#          'st.': 14,
#          'people': 14,
#          'southwest': 14,
#          '12': 14,
#          'hours': 14,
#          'rain,': 14,
#          'visibility,': 14,
#          'recovery': 14,
#          'brake': 14,
#          'accident,': 14,
#          'cash': 14,
#          'establish': 13,
#          'inadvertent': 13,
#          'inability': 13,
#          'trace': 13,
#          'order': 13,
#          'apart': 13,
#          'away': 13,
#          'southeast': 13,
#          'controls.': 13,
#          'refuel': 13,
#          'no.2': 13,
#          'depart': 13,
#          'up.': 13,
#          'throttle': 13,
#          'evasive': 13,
#          'aboard.': 13,
#          'speed.': 13,
#          '9': 13,
#          'outer': 13,
#          'attain': 13,
#          'approve': 13,
#          'river.': 13,
#          'transport': 13,
#          'appear': 13,
#          'determined.': 13,
#          'salt': 13,
#          'surface-to-air': 13,
#          'mountain,': 13,
#          'meteorological': 13,
#          'five': 13,
#          'threshold': 13,
#          'switch': 13,
#          'retract': 13,
#          'unite': 13,
#          'operation.': 13,
#          'develop': 13,
#          'elevation': 12,
#          '1,500': 12,
#          'storm': 12,
#          'violent': 12,
#          'associate': 12,
#          'tear': 12,
#          'wake': 12,
#          'island.': 12,
#          'francisco': 12,
#          'forest': 12,
#          'hand': 12,
#          'think': 12,
#          'cable': 12,
#          'practice': 12,
#          'landing,': 12,
#          'problem': 12,
#          'shift': 12,
#          'invert': 12,
#          'dense': 12,
#          'front': 12,
#          'jam': 12,
#          'rebel': 12,
#          'test': 12,
#          'six': 12,
#          'misjudge': 12,
#          'los': 12,
#          'safety': 12,
#          'rescue': 12,
#          'edge': 12,
#          'missile.': 12,
#          'santa': 12,
#          'yards': 12,
#          'threshold.': 12,
#          'park': 12,
#          'instruments.': 12,
#          'station': 12,
#          'service': 12,
#          'eject': 12,
#          'ground,': 12,
#          'prop': 12,
#          'cabin.': 12,
#          'earth': 12,
#          'request': 12,
#          'vibration': 12,
#          'track': 12,
#          'generator': 12,
#          'faa': 12,
#          'turbulence,': 11,
#          'evidence': 11,
#          'maximum': 11,
#          'indicate': 11,
#          'company': 11,
#          'preparation': 11,
#          'abandon': 11,
#          'bring': 11,
#          'airborne': 11,
#          '&': 11,
#          'mountainside': 11,
#          'witness': 11,
#          '60': 11,
#          'uncontrolled': 11,
#          'minima': 11,
#          'artificial': 11,
#          'copilot': 11,
#          'show': 11,
#          'land,': 11,
#          'sea,': 11,
#          'exercise': 11,
#          'snow.': 11,
#          'navy': 11,
#          'check': 11,
#          'soviet': 11,
#          'spiral': 11,
#          '5,000': 11,
#          'clearance.': 11,
#          'survive': 11,
#          '2,000': 11,
#          'clouds.': 11,
#          'within': 11,
#          'yaw': 11,
#          '727': 11,
#          'realize': 11,
#          'fuselage.': 11,
#          'trees,': 11,
#          'trouble': 11,
#          'overspeeding': 11,
#          'operation': 11,
#          'inadvertently': 11,
#          'instal': 11,
#          'receive': 11,
#          'extend': 11,
#          'years': 11,
#          'el': 11,
#          'long': 11,
#          '25': 11,
#          'parachute': 11,
#          'ever': 10,
#          'loose': 10,
#          'metal': 10,
#          'outboard': 10,
#          'seven': 10,
#          'body': 10,
#          'airborne,': 10,
#          '1.5': 10,
#          'fire,': 10,
#          'obscure': 10,
#          'climb,': 10,
#          'path.': 10,
#          'publish': 10,
#          'downdraft': 10,
#          ',': 10,
#          'clip': 10,
#          'probably': 10,
#          '400': 10,
#          'time.': 10,
#          'exist': 10,
#          'keep': 10,
#          'domestic': 10,
#          'leak': 10,
#          'starvation.': 10,
#          'turbine': 10,
#          'rupture': 10,
#          'tokyo': 10,
#          'weather,': 10,
#          '35': 10,
#          'dc-3': 10,
#          'downdrafts': 10,
#          'lost.': 10,
#          'attitude.': 10,
#          'house.': 10,
#          'rio': 10,
#          'put': 10,
#          'rapid': 10,
#          'combination': 10,
#          'gravity': 10,
#          'tire': 10,
#          'indication': 10,
#          'equipment.': 10,
#          'cylinder': 10,
#          'supply': 10,
#          'authorize': 10,
#          'trouble.': 10,
#          '150': 10,
#          'airfield.': 10,
#          'propeller.': 10,
#          '3,000': 10,
#          'less': 10,
#          'hill.': 10,
#          'proceed': 10,
#          'ignite': 10,
#          'incapacitation': 10,
#          'piper': 10,
#          'attack': 10,
#          'hard': 10,
#          'touchdown': 10,
#          'hour': 10,
#          'conduct': 10,
#          'ignition': 10,
#          'minima.': 10,
#          'eight': 10,
#          'pan': 10,
#          'extremely': 9,
#          'produce': 9,
#          'weight': 9,
#          'prevail': 9,
#          'rather': 9,
#          'higher': 9,
#          'judgment': 9,
#          'winds.': 9,
#          'weaken': 9,
#          'bear': 9,
#          'illusion': 9,
#          'turn.': 9,
#          '13': 9,
#          'it.': 9,
#          '"the': 9,
#          'among': 9,
#          'municipal': 9,
#          'half': 9,
#          'unsafe': 9,
#          'attemping': 9,
#          'propellers': 9,
#          'hijacker': 9,
#          'detonate': 9,
#          '90': 9,
#          'pacific': 9,
#          'collapse': 9,
#          'inform': 9,
#          'directional': 9,
#          'transmit': 9,
#          'hijack': 9,
#          'hold.': 9,
#          'stalled,': 9,
#          '6,000': 9,
#          'induce': 9,
#          'single': 9,
#          'spread': 9,
#          'throw': 9,
#          'board': 9,
#          'likely': 9,
#          'retraction': 9,
#          'mission': 9,
#          'compass': 9,
#          'destination': 9,
#          'bind': 9,
#          'arm': 9,
#          'way': 9,
#          'decompression': 9,
#          'airway': 9,
#          'extreme': 9,
#          'detach': 9,
#          'pattern.': 9,
#          'desert': 9,
#          'drag': 9,
#          'planning.': 9,
#          'raise': 9,
#          'activate': 9,
#          'crashed,': 9,
#          'later,': 9,
#          'las': 9,
#          'home': 9,
#          'late': 9,
#          'inoperative': 9,
#          '1,200': 9,
#          'airlines': 9,
#          'slop': 9,
#          '45': 9,
#          'pump': 9,
#          'minute': 9,
#          'cincinnati': 9,
#          'obstruct': 9,
#          'permit': 9,
#          'assign': 9,
#          'charter': 9,
#          'latch': 9,
#          'klm': 9,
#          'regain': 8,
#          'reveal': 8,
#          'distress': 8,
#          'occupants': 8,
#          'elect': 8,
#          'circumstances': 8,
#          'personnel': 8,
#          'accumulation': 8,
#          'inspection': 8,
#          'lightning.': 8,
#          'application': 8,
#          'aviation': 8,
#          'russian': 8,
#          'align': 8,
#          'assembly.': 8,
#          'remove': 8,
#          'bay.': 8,
#          'up,': 8,
#          'american': 8,
#          'destination.': 8,
#          'down,': 8,
#          'slow': 8,
#          'sank.': 8,
#          'village': 8,
#          'incorrectly': 8,
#          'debris': 8,
#          'terminal': 8,
#          'afghan': 8,
#          'zero': 8,
#          'mistakenly': 8,
#          'stall.': 8,
#          'autopilot': 8,
#          'transfer': 8,
#          'baggage': 8,
#          "flightcrew's": 8,
#          'escape': 8,
#          'imc': 8,
#          'compartment': 8,
#          'shear': 8,
#          'cerro': 8,
#          'valve': 8,
#          'attitude,': 8,
#          'restrict': 8,
#          'recognize': 8,
#          'mediterranean': 8,
#          'airfield': 8,
#          'performance': 8,
#          'aid': 8,
#          'japan': 8,
#          'old': 8,
#          'pin': 8,
#          'timely': 8,
#          'travel': 8,
#          'sight': 8,
#          'fact': 8,
#          'hundred': 8,
#          'denver': 8,
#          'civilian': 8,
#          'survived.': 8,
#          'windshear': 8,
#          '3,500': 8,
#          'moderate': 8,
#          'station.': 8,
#          'ceiling': 8,
#          '7,000': 8,
#          'ten': 8,
#          'left,': 8,
#          'tell': 8,
#          'vicinity': 8,
#          'affect': 8,
#          'overheat': 8,
#          'unit': 8,
#          'apparently': 8,
#          'time,': 8,
#          'circuit': 8,
#          'systems': 8,
#          'member': 8,
#          'direction': 8,
#          'blades': 8,
#          'restart': 8,
#          'situation': 8,
#          '32': 8,
#          'move': 8,
#          'heavily': 8,
#          'localizer': 8,
#          'supervision': 8,
#          'erroneous': 8,
#          'no.4': 8,
#          'stage': 8,
#          'discontinue': 8,
#          '-': 8,
#          'enough': 8,
#          'disintegration': 8,
#          'around': 8,
#          'bay,': 8,
#          'western': 8,
#          'accidents': 8,
#          'sharp': 8,
#          'viscount': 8,
#          'finally': 7,
#          'gulf': 7,
#          'overcast': 7,
#          'flat': 7,
#          'official': 7,
#          'drive': 7,
#          'spar': 7,
#          'vibrations': 7,
#          'necessitate': 7,
#          'french': 7,
#          'circumstances.': 7,
#          'take-off': 7,
#          'ravine': 7,
#          'scatter': 7,
#          'snowstorm': 7,
#          'helicopters': 7,
#          'stag': 7,
#          '80': 7,
#          'involve': 7,
#          'apparent': 7,
#          'nearly': 7,
#          'spoiler': 7,
#          'passenger.': 7,
#          'activity': 7,
#          'next': 7,
#          'day': 7,
#          'coast': 7,
#          'leg': 7,
#          'pole': 7,
#          'fort': 7,
#          'enemy': 7,
#          'asymmetrical': 7,
#          'intend': 7,
#          'belly': 7,
#          'handle': 7,
#          'proximity': 7,
#          'freeze': 7,
#          'work': 7,
#          'assume': 7,
#          'activity.': 7,
#          ...})

# %%
plot_word_cloud(df_1["Words"][(df_1.Decade > 1980)].values)

# %%
word_count(df_1["Words"][ (df_1.Decade > 1980)].values)
# Out:
# Counter({'land': 420,
#          'take': 380,
#          'off': 356,
#          'runway': 325,
#          'engine': 300,
#          'failure': 293,
#          'attempt': 277,
#          'control': 225,
#          'accident': 184,
#          'lose': 180,
#          'airport.': 168,
#          'make': 167,
#          'altitude': 160,
#          'weather': 160,
#          'leave': 154,
#          'result': 152,
#          'strike': 151,
#          'poor': 145,
#          'helicopter': 143,
#          'minutes': 140,
#          'report': 139,
#          'shortly': 138,
#          'two': 135,
#          'right': 123,
#          'one': 121,
#          'air': 116,
#          'short': 115,
#          'loss': 114,
#          'due': 112,
#          'ft.': 111,
#          'fire': 109,
#          'emergency': 105,
#          'heavy': 105,
#          'en': 104,
#          'stall': 103,
#          'hit': 101,
#          'grind': 101,
#          'fuel': 99,
#          'runway.': 99,
#          'fail': 97,
#          'contribute': 96,
#          'kill': 96,
#          'feet': 94,
#          'takeoff': 94,
#          'carry': 92,
#          'low': 90,
#          'maintain': 88,
#          'condition': 88,
#          'follow': 88,
#          'go': 88,
#          'turn': 88,
#          'break': 87,
#          'captain': 85,
#          'impact': 85,
#          'return': 84,
#          'time': 83,
#          'lead': 83,
#          'mountain': 82,
#          'area': 82,
#          'airplane': 81,
#          'instrument': 81,
#          'second': 78,
#          "pilot's": 77,
#          'descend': 76,
#          'near': 75,
#          'killed.': 74,
#          'terrain': 73,
#          'high': 72,
#          'crashed.': 72,
#          'power': 72,
#          'continue': 70,
#          'passengers': 70,
#          'descent': 68,
#          'wing': 68,
#          'contact': 68,
#          'three': 67,
#          'lack': 67,
#          'warn': 65,
#          'factor': 65,
#          'rain': 64,
#          'route': 64,
#          'try': 64,
#          'military': 64,
#          'accident.': 61,
#          'speed': 61,
#          '2': 61,
#          'off.': 61,
#          'climb': 61,
#          'conditions.': 60,
#          'passenger': 60,
#          'catch': 60,
#          'decision': 59,
#          'system': 59,
#          'visual': 58,
#          'burst': 58,
#          'international': 58,
#          'runway,': 58,
#          'come': 57,
#          'ice': 57,
#          'approach,': 57,
#          'aircraft.': 56,
#          'use': 56,
#          'terrain.': 56,
#          'final': 55,
#          'km': 55,
#          'inadequate': 55,
#          'first': 54,
#          'nose': 54,
#          'airport,': 54,
#          'ground.': 53,
#          'tree': 53,
#          'aboard': 53,
#          'no.': 52,
#          'flames.': 52,
#          'fire.': 52,
#          'experience': 51,
#          'engines': 51,
#          'fog': 51,
#          'force': 49,
#          'flight.': 49,
#          'find': 49,
#          'include': 48,
#          'sea': 47,
#          'takeoff.': 47,
#          '3': 47,
#          'end': 47,
#          'side': 47,
#          'gear': 47,
#          'land.': 46,
#          'field': 46,
#          'overrun': 46,
#          'procedures': 46,
#          'landing.': 46,
#          'visibility': 46,
#          'miss': 45,
#          'off,': 45,
#          'pitch': 45,
#          'without': 45,
#          'run': 44,
#          'shoot': 44,
#          'error.': 44,
#          'stop': 43,
#          'collide': 43,
#          'train': 43,
#          'bank': 43,
#          'wind': 42,
#          'enter': 42,
#          'approach.': 42,
#          'water': 42,
#          'crash.': 41,
#          'wreckage': 41,
#          'roll': 41,
#          'position': 41,
#          'mountainous': 41,
#          'rest': 41,
#          'atc': 40,
#          '1': 40,
#          'plane,': 40,
#          'wooded': 39,
#          'also': 39,
#          'maintenance': 39,
#          'could': 38,
#          'weather.': 38,
#          'plan': 38,
#          'night': 38,
#          'radar': 38,
#          'minimum': 37,
#          'back': 37,
#          'onto': 37,
#          'collision': 36,
#          'hill': 36,
#          'abort': 36,
#          'light': 36,
#          'transport': 36,
#          'route.': 35,
#          'divert': 35,
#          'improper': 35,
#          'begin': 35,
#          'explode': 35,
#          'dive': 34,
#          'four': 34,
#          'cockpit': 34,
#          'another': 34,
#          'reach': 34,
#          'rudder': 34,
#          'members': 34,
#          'operate': 34,
#          'airspeed': 34,
#          'north': 34,
#          '5': 33,
#          'prior': 33,
#          'thrust': 33,
#          'reduce': 32,
#          'steep': 32,
#          'become': 32,
#          'correct': 32,
#          'cloud': 32,
#          "crew's": 32,
#          'plane.': 32,
#          'unable': 31,
#          '10': 31,
#          'radio': 31,
#          'fog.': 31,
#          '20': 31,
#          '6': 31,
#          'failure.': 31,
#          'initiate': 31,
#          'burn': 31,
#          'mt.': 30,
#          'area.': 30,
#          'house': 30,
#          'subsequent': 30,
#          'sea.': 30,
#          'perform': 30,
#          'soon': 30,
#          'traffic': 30,
#          'decide': 30,
#          'mile': 30,
#          'airliner': 30,
#          'hold': 29,
#          'conditions,': 29,
#          'disappear': 29,
#          'clearance': 29,
#          'among': 29,
#          'tail': 29,
#          'problem': 29,
#          'flight,': 29,
#          'problems': 28,
#          'vfr': 28,
#          'clear': 28,
#          "captain's": 28,
#          '30': 28,
#          'monitor': 28,
#          'height': 28,
#          'strong': 28,
#          "aircraft's": 28,
#          'charter': 28,
#          'malfunction': 27,
#          'able': 27,
#          '15': 27,
#          'tower': 27,
#          "plane's": 27,
#          'meteorological': 27,
#          'part': 27,
#          'flame': 27,
#          'veer': 27,
#          'altitude.': 26,
#          'likely': 26,
#          'several': 26,
#          'action': 26,
#          'south': 26,
#          'adequate': 26,
#          'oil': 26,
#          'destroy': 26,
#          'mountain.': 26,
#          'fatigue': 26,
#          'propeller': 25,
#          'field.': 25,
#          'say': 25,
#          'gain': 25,
#          'allow': 25,
#          'in-flight': 25,
#          'go-around': 25,
#          'encounter': 25,
#          'ocean': 25,
#          'severe': 25,
#          'land,': 25,
#          'along': 25,
#          'line': 25,
#          'increase': 25,
#          '4': 25,
#          'touch': 25,
#          'show': 25,
#          'officer': 24,
#          'properly': 24,
#          'circle': 24,
#          'people': 24,
#          'way': 24,
#          'rate': 24,
#          'attitude': 24,
#          'occur': 24,
#          'flap': 24,
#          'approximately': 24,
#          'require': 24,
#          'go-around.': 24,
#          'change': 24,
#          'cabin': 24,
#          'jet': 24,
#          'ditch': 23,
#          'weight': 23,
#          'altitude,': 23,
#          'level': 23,
#          'center': 23,
#          'later': 23,
#          'die': 23,
#          'mountains': 23,
#          'copilot': 23,
#          'determine': 23,
#          'locate': 23,
#          'head': 23,
#          'rain.': 23,
#          'aircraft,': 23,
#          'skid': 23,
#          'feet,': 23,
#          'meter': 23,
#          'trim': 23,
#          'declare': 22,
#          'place': 22,
#          'safe': 22,
#          'suffer': 22,
#          'may': 22,
#          'control.': 22,
#          'would': 22,
#          'limit': 22,
#          'witness': 22,
#          'takeoff,': 21,
#          'engine.': 21,
#          'past': 21,
#          'appear': 21,
#          'national': 21,
#          'aviation': 21,
#          'conduct': 21,
#          'standard': 21,
#          'indicate': 21,
#          'load': 21,
#          'company': 21,
#          'electrical': 20,
#          'open': 20,
#          'proper': 20,
#          'route,': 20,
#          'lower': 20,
#          'adverse': 20,
#          'receive': 20,
#          'execute': 20,
#          '12': 20,
#          "airplane's": 20,
#          'main': 20,
#          'top': 20,
#          'lake': 20,
#          'system.': 20,
#          'residential': 20,
#          'request': 20,
#          'remote': 20,
#          'see': 20,
#          'avoid': 20,
#          'establish': 20,
#          'snow': 19,
#          'five': 19,
#          'cruise': 19,
#          'give': 19,
#          'tell': 19,
#          'inadvertent': 19,
#          'ft.,': 19,
#          'towards': 19,
#          '8': 19,
#          'days': 19,
#          'possible': 19,
#          'last': 19,
#          'departure': 19,
#          'crew.': 19,
#          'depart': 19,
#          'management': 19,
#          'angle': 19,
#          'maneuver': 19,
#          'build': 19,
#          'around': 19,
#          'throttle': 19,
#          'landing,': 19,
#          'autopilot': 19,
#          'russian': 19,
#          'state': 19,
#          'forest': 19,
#          'medical': 19,
#          'bad': 18,
#          'instead': 18,
#          'elevator': 18,
#          'island': 18,
#          'separate': 18,
#          'damage': 18,
#          'visibility.': 18,
#          'spatial': 18,
#          'dense': 18,
#          'west': 18,
#          'de': 18,
#          'ground,': 18,
#          'failed.': 18,
#          'start': 18,
#          'disintegrate': 18,
#          'sightsee': 18,
#          'however,': 18,
#          'excessive': 18,
#          'river': 18,
#          'water.': 18,
#          'east': 18,
#          'southwest': 17,
#          'pattern': 17,
#          'number': 17,
#          'destination': 17,
#          'maximum': 17,
#          'set': 17,
#          'relate': 17,
#          'reference': 17,
#          'pull': 17,
#          'co-pilot': 17,
#          'full': 17,
#          'cover': 17,
#          'eventually': 17,
#          'incorrect': 17,
#          'survive': 17,
#          'slide': 17,
#          'performance': 17,
#          'schedule': 17,
#          'wrong': 17,
#          'safety': 17,
#          'procedure': 17,
#          'rotor': 17,
#          "pilots'": 17,
#          'six': 17,
#          'perimeter': 17,
#          'extend': 16,
#          '500': 16,
#          'outside': 16,
#          'tank': 16,
#          'fell': 16,
#          'remain': 16,
#          '35': 16,
#          'injuries.': 16,
#          'observe': 16,
#          'minute': 16,
#          'seven': 16,
#          'forward': 16,
#          'dark': 16,
#          'overshoot': 16,
#          'feet.': 16,
#          'error': 16,
#          'course': 16,
#          'brake': 16,
#          'insufficient': 16,
#          'aft': 16,
#          'addition,': 16,
#          'pilot,': 16,
#          'probable': 16,
#          'small': 16,
#          'investigation': 16,
#          'injured.': 16,
#          'ambulance': 16,
#          'destroyed.': 16,
#          'burned.': 15,
#          'stall.': 15,
#          'suddenly': 15,
#          'close': 15,
#          'probably': 15,
#          'never': 15,
#          'fl': 15,
#          'rebel': 15,
#          'rise': 15,
#          'clip': 15,
#          'procedures.': 15,
#          'fuselage': 15,
#          'controller': 15,
#          'provide': 15,
#          'awareness': 15,
#          'almost': 15,
#          'design': 15,
#          'pressure': 15,
#          'river.': 15,
#          'overloaded.': 15,
#          'within': 15,
#          'beyond': 15,
#          'midair': 15,
#          '18': 15,
#          'apply': 15,
#          'mechanical': 14,
#          'mount': 14,
#          '50': 14,
#          'inform': 14,
#          'pass': 14,
#          'faa': 14,
#          'trees.': 14,
#          'ils': 14,
#          'missile': 14,
#          'apparently': 14,
#          'taxi': 14,
#          'errors': 14,
#          'alert': 14,
#          'operational': 14,
#          'inappropriate': 14,
#          'detect': 14,
#          'elevation': 14,
#          'manual': 14,
#          'impact.': 14,
#          'weather,': 14,
#          'publish': 14,
#          'separation': 14,
#          'up.': 14,
#          'timely': 14,
#          'fence': 14,
#          'sound': 14,
#          'input': 14,
#          'call': 14,
#          'take-off': 14,
#          'cross': 14,
#          '40': 14,
#          'normal': 13,
#          'new': 13,
#          'realize': 13,
#          'situation': 13,
#          'vertical': 13,
#          'immediately': 13,
#          'happen': 13,
#          '11': 13,
#          'jungle': 13,
#          '7': 13,
#          'double': 13,
#          'work': 13,
#          'mountainside': 13,
#          'personnel': 13,
#          'believe': 13,
#          'attitude,': 13,
#          'uncontrolled': 13,
#          'program': 13,
#          'combination': 13,
#          'ensure': 13,
#          'hijack': 13,
#          'prevent': 13,
#          'aboard.': 13,
#          '25': 13,
#          'safely': 13,
#          'debris': 13,
#          'thunderstorms': 13,
#          'despite': 12,
#          'mountain,': 12,
#          'el': 12,
#          'go-around,': 12,
#          'reason': 12,
#          'crew,': 12,
#          'exceed': 12,
#          'airborne': 12,
#          'path': 12,
#          'respond': 12,
#          'prepare': 12,
#          'coordination': 12,
#          'explosion': 12,
#          'float': 12,
#          'nearby': 12,
#          'engine,': 12,
#          'descent.': 12,
#          'possibly': 12,
#          'unknown': 12,
#          'know': 12,
#          'u.s.': 12,
#          'adequately': 12,
#          'situational': 12,
#          'area,': 12,
#          'develop': 12,
#          'shift': 12,
#          'overload': 12,
#          'smoke': 12,
#          'icing.': 12,
#          'nm': 12,
#          'third': 12,
#          'blow': 12,
#          'left,': 12,
#          'test': 12,
#          'fracture': 12,
#          'up,': 12,
#          'twin': 12,
#          'recovery': 12,
#          'recover': 12,
#          'southeast': 12,
#          'operations': 12,
#          'associate': 12,
#          'rapidly': 12,
#          'french': 12,
#          'auto': 12,
#          'later.': 12,
#          'alarm': 12,
#          'put': 11,
#          'little': 11,
#          'lift': 11,
#          'check': 11,
#          'unita': 11,
#          'rebels.': 11,
#          'order': 11,
#          'switch': 11,
#          'away': 11,
#          'seat': 11,
#          'half': 11,
#          'ridge': 11,
#          'down.': 11,
#          'were:': 11,
#          'fog,': 11,
#          'terrain,': 11,
#          'available': 11,
#          'pilot.': 11,
#          'turbulence': 11,
#          'disorientation': 11,
#          'direction': 11,
#          'contamination': 11,
#          'response': 11,
#          'federal': 11,
#          'coast': 11,
#          'northwest': 11,
#          'reverse': 11,
#          'tire': 11,
#          'night,': 11,
#          'helicopter,': 11,
#          'get': 11,
#          'select': 11,
#          'primary': 11,
#          'winds.': 11,
#          'flightcrew': 11,
#          'complete': 11,
#          'invert': 11,
#          'service': 11,
#          'stick': 11,
#          'mission': 11,
#          'read': 11,
#          'piece': 11,
#          'passengers.': 11,
#          'bring': 11,
#          'hour': 11,
#          'general': 11,
#          'bind': 11,
#          'trouble': 11,
#          'reveal': 11,
#          'board': 11,
#          'ferry': 11,
#          '100': 11,
#          'time.': 11,
#          'cliff': 11,
#          'problems.': 11,
#          'across': 11,
#          'sea,': 11,
#          'critical': 11,
#          'base': 11,
#          'shut': 10,
#          'feather': 10,
#          'san': 10,
#          'structural': 10,
#          'gravity': 10,
#          'subsequently': 10,
#          'premature': 10,
#          'thunderstorm': 10,
#          'years': 10,
#          'rain,': 10,
#          'remove': 10,
#          'command': 10,
#          'freeze': 10,
#          'inspection': 10,
#          'blade': 10,
#          'hard': 10,
#          'stalled,': 10,
#          'field,': 10,
#          'pilot-in-command': 10,
#          'systems': 10,
#          'delay': 10,
#          'hillside': 10,
#          'horizontal': 10,
#          'stabilizer': 10,
#          'system,': 10,
#          'handle': 10,
#          'late': 10,
#          'drop': 10,
#          'surround': 10,
#          'base.': 10,
#          'sudden': 10,
#          'disconnect': 10,
#          'degree': 10,
#          'airbus': 10,
#          'undetermined': 10,
#          'proximity': 10,
#          '1.5': 10,
#          'supply': 10,
#          'st.': 10,
#          'procedures,': 10,
#          'slow': 10,
#          'fan': 10,
#          'shallow': 10,
#          "flightcrew's": 10,
#          'cessna': 10,
#          'river,': 10,
#          'navigation': 10,
#          'issue': 10,
#          'site': 10,
#          'technical': 10,
#          'lightning': 10,
#          'data': 10,
#          'rear': 9,
#          'ifr': 9,
#          'atc.': 9,
#          'wide': 9,
#          '200': 9,
#          'even': 9,
#          'push': 9,
#          'park': 9,
#          'section': 9,
#          'forces.': 9,
#          'destination.': 9,
#          'problem.': 9,
#          'hear': 9,
#          'correctly': 9,
#          'glide': 9,
#          'slope': 9,
#          'indications': 9,
#          'los': 9,
#          'operation': 9,
#          'region': 9,
#          'airlines': 9,
#          'airplane.': 9,
#          'sink': 9,
#          'servo': 9,
#          'point': 9,
#          '14': 9,
#          '150': 9,
#          'send': 9,
#          'scatter': 9,
#          'hours': 9,
#          'tour': 9,
#          '2,000': 9,
#          'inadvertently': 9,
#          'rotation': 9,
#          'team': 9,
#          '9': 9,
#          'threshold': 9,
#          'airfield': 9,
#          'non-precision': 9,
#          'aerodynamic': 9,
#          'long': 9,
#          'atlantic': 9,
#          'unite': 9,
#          'ocean.': 9,
#          'crack': 9,
#          'speed.': 9,
#          'activate': 9,
#          'identify': 9,
#          'speed,': 9,
#          'captain’s': 9,
#          'saw': 9,
#          'survived.': 9,
#          'airspeed,': 9,
#          'spin': 9,
#          'leak': 9,
#          'less': 9,
#          'information': 9,
#          'adjacent': 9,
#          'northeast': 9,
#          'storm': 9,
#          'distance': 9,
#          'body': 9,
#          'embankment': 9,
#          'plunge': 9,
#          'upon': 9,
#          'hydraulic': 9,
#          'construction': 9,
#          'advise': 9,
#          'rather': 8,
#          'although': 8,
#          'idle': 8,
#          'mode': 8,
#          'bird': 8,
#          'type': 8,
#          '400': 8,
#          'large': 8,
#          'aid': 8,
#          'message': 8,
#          'undershoot': 8,
#          'right.': 8,
#          'struggle': 8,
#          'false': 8,
#          'equipment': 8,
#          'procedural': 8,
#          'disorient': 8,
#          'eight': 8,
#          'surface-to-air': 8,
#          'front': 8,
#          'standards': 8,
#          'oversight': 8,
#          'wheel': 8,
#          'uncommanded': 8,
#          'jam': 8,
#          'clouds.': 8,
#          'recognize': 8,
#          'descent,': 8,
#          'hill.': 8,
#          'thunderstorms.': 8,
#          'twenty': 8,
#          'deteriorate': 8,
#          'clouds,': 8,
#          'edge': 8,
#          'surface': 8,
#          'trees,': 8,
#          '1,500': 8,
#          'rescue': 8,
#          'engines.': 8,
#          'support': 8,
#          'nose-down': 8,
#          'extreme': 8,
#          'crash,': 8,
#          'comply': 8,
#          'navigational': 8,
#          'initial': 8,
#          'building.': 8,
#          'either': 8,
#          'american': 8,
#          'turbine': 8,
#          'bounce': 8,
#          'resource': 8,
#          'captain,': 8,
#          '60': 8,
#          'attempt,': 8,
#          "faa's": 8,
#          'alternate': 8,
#          'highway': 8,
#          'windshear.': 8,
#          'town': 8,
#          'distress': 8,
#          'control,': 8,
#          '1,000': 8,
#          'troop': 8,
#          'recorder': 8,
#          'spiral': 8,
#          'balance': 8,
#          'range': 8,
#          'nut': 8,
#          'steer': 8,
#          'configuration': 8,
#          '600': 8,
#          'certify': 8,
#          'patient': 8,
#          'farm': 8,
#          'track': 8,
#          'touchdown': 8,
#          'la': 8,
#          'adhere': 8,
#          'rule': 8,
#          'forest.': 8,
#          'western': 8,
#          "controller's": 8,
#          'rainstorm.': 7,
#          'equip': 7,
#          'many': 7,
#          'controllers': 7,
#          'de-ice': 7,
#          'fast': 7,
#          'truck': 7,
#          'turbulence.': 7,
#          'vor': 7,
#          'faulty': 7,
#          'wire': 7,
#          'bolt': 7,
#          'port': 7,
#          'helicopters': 7,
#          'distract': 7,
#          'reasons.': 7,
#          'wait': 7,
#          'person': 7,
#          'eastern': 7,
#          'effect': 7,
#          'course.': 7,
#          'missile.': 7,
#          'gulf': 7,
#          'exercise': 7,
#          'southern': 7,
#          'others': 7,
#          'previous': 7,
#          "helicopter's": 7,
#          'blades': 7,
#          'apart': 7,
#          'boeing': 7,
#          'name': 7,
#          'police': 7,
#          'lost.': 7,
#          'deice': 7,
#          'act': 7,
#          'proceed': 7,
#          'private': 7,
#          'road': 7,
#          'fall': 7,
#          'good': 7,
#          'sight': 7,
#          'windshear': 7,
#          'computer': 7,
#          'actual': 7,
#          'collapse': 7,
#          'minima': 7,
#          'deviation': 7,
#          'deficiencies': 7,
#          'slightly': 7,
#          'mda': 7,
#          'touch-and-go': 7,
#          'operator': 7,
#          'artificial': 7,
#          "officer's": 7,
#          'far': 7,
#          'direct': 7,
#          'ask': 7,
#          '180': 7,
#          'wall': 7,
#          'knots.': 7,
#          'rig': 7,
#          'clearance.': 7,
#          'moments': 7,
#          'preflight': 7,
#          'record': 7,
#          'stage': 7,
#          'after,': 7,
#          'still': 7,
#          'pilot’s': 7,
#          'avoidance': 7,
#          '13': 7,
#          'trouble.': 7,
#          'mountains.': 7,
#          'power,': 7,
#          'soldier': 7,
#          'effectively': 7,
#          'manage': 7,
#          'accident,': 7,
#          'city': 7,
#          'engineer': 7,
#          'regional': 7,
#          'right,': 7,
#          'application': 7,
#          'pick': 7,
#          'degrees.': 7,
#          'absence': 7,
#          'toward': 7,
#          'manually': 7,
#          'radar.': 7,
#          'ignore': 7,
#          'heavily': 7,
#          '16': 7,
#          '90': 7,
#          'deliberately': 7,
#          'knot': 7,
#          '300': 7,
#          'flow': 7,
#          'lock': 7,
#          'attendant': 7,
#          'fence,': 7,
#          '19': 7,
#          'lease': 7,
#          'angle-of-attack': 7,
#          'guard': 7,
#          'plane’s': 7,
#          'officials': 7,
#          'board.': 7,
#          'jetliner': 7,
#          '22': 7,
#          'relief': 7,
#          'group': 7,
#          ',': 7,
#          'kilometers': 7,
#          'visibility,': 6,
#          'communicate': 6,
#          'emergency.': 6,
#          'blame': 6,
#          'different': 6,
#          'situation.': 6,
#          '5,000': 6,
#          'factor.': 6,
#          'rice': 6,
#          'helicopter.': 6,
#          'suck': 6,
#          '3,000': 6,
#          'point.': 6,
#          'death': 6,
#          'serious': 6,
#          'instructions': 6,
#          'intercept': 6,
#          'gpws': 6,
#          '4,000': 6,
#          'storm.': 6,
#          'survivor': 6,
#          'position.': 6,
#          '31': 6,
#          'opposite': 6,
#          'understand': 6,
#          'concrete': 6,
#          'accidentally': 6,
#          'tower,': 6,
#          'warning.': 6,
#          'abandon': 6,
#          'rapid': 6,
#          'reverser': 6,
#          'arrest': 6,
#          'ignite': 6,
#          'well': 6,
#          'approve': 6,
#          'foot': 6,
#          'found.': 6,
#          'path.': 6,
#          '800': 6,
#          'commercial': 6,
#          'vehicles.': 6,
#          'hundred': 6,
#          'deploy': 6,
#          'significant': 6,
#          'improperly': 6,
#          'turn.': 6,
#          ...})
