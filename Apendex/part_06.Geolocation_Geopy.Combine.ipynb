# %%
import pandas as pd
import matplotlib.pyplot as plt 
from IPython.display import display
# import tabulate
# %matplotlib inline

# %%
df = pd.read_json("data/silver/1920_2024_geopy.json")
df_country_codes = pd.read_json("data/country_codes.json")

# %%
df[df.Country_location.apply(lambda x: isinstance(x,str))].to_csv("data/bad_data/unknown_country_location.csv")
df_country_codes[df_country_codes.name_geopy.apply(lambda x: isinstance(x,str))].to_csv("data/bad_data/unknown_country_codes.csv")

# %%
df_country_codes[:4]
# Out:
#             name alpha-2 alpha-3  country-code     iso_3166-2  region  \
# 0    Afghanistan      AF     AFG             4  ISO 3166-2:AF    Asia
# 1  Åland Islands      AX     ALA           248  ISO 3166-2:AX  Europe
# 2        Albania      AL     ALB             8  ISO 3166-2:AL  Europe
# 3        Algeria      DZ     DZA            12  ISO 3166-2:DZ  Africa
#
#         sub-region intermediate-region  region-code  sub-region-code  \
# 0    Southern Asia                None        142.0             34.0
# 1  Northern Europe                None        150.0            154.0
# 2  Southern Europe                None        150.0             39.0
# 3  Northern Africa                None          2.0             15.0
#
#    intermediate-region-code                                         name_geopy
# 0                       NaN  {'place_id': 220100631, 'licence': 'Data © Ope...
# 1                       NaN  {'place_id': 180167715, 'licence': 'Data © Ope...
# 2                       NaN  {'place_id': 83081284, 'licence': 'Data © Open...
# 3                       NaN  {'place_id': 77146891, 'licence': 'Data © Open...

# %%
df_ = df[df.Country_location.apply(lambda x: isinstance(x,dict))]
df_country_codes_ = df_country_codes[df_country_codes.name_geopy.apply(lambda x: isinstance(x,dict))]

# %%
df_country_codes_["name_geopy"][0]
# Out:
# {'place_id': 220100631,
#  'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#  'osm_type': 'relation',
#  'osm_id': 303427,
#  'lat': '33.7680065',
#  'lon': '66.2385139',
#  'class': 'boundary',
#  'type': 'administrative',
#  'place_rank': 4,
#  'importance': 0.7470274828,
#  'addresstype': 'country',
#  'name': 'Afghanistan',
#  'display_name': 'Afghanistan',
#  'boundingbox': ['29.3772926', '38.4910682', '60.5176034', '74.8898620']}

# %%
df_["Country_location"][0]
# Out:
# {'place_id': 372303099,
#  'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#  'osm_type': 'way',
#  'osm_id': 1219767831,
#  'lat': '54.596391',
#  'lon': '-5.9301829',
#  'class': 'place',
#  'type': 'city',
#  'place_rank': 16,
#  'importance': 0.6500238354,
#  'addresstype': 'city',
#  'name': 'Belfast',
#  'display_name': 'Belfast, County Antrim, Northern Ireland, United Kingdom',
#  'boundingbox': ['54.5306104', '54.6594247', '-6.0454798', '-5.8076879']}

# %%
def unpack_locations(x,a=-2):
    "Check if is numeric or alpha numeric"
    return ",".join([i for i in x['display_name'].split(",") if i.strip().isnumeric()==False][a:]).strip()

def get_country_codes(df):
    df["Country_Geopy"] = df.name_geopy.apply(unpack_locations)
    return df

# def unpack_locations_part(x):
#     return ",".join([i for i in x['display_name'].split(",") if i.strip().isnumeric()==False][-1:]).strip()

# %%
df_country_codes_["Country_Geopy"] = df_country_codes_.name_geopy.apply(unpack_locations)
df_country_codes_ = df_country_codes_.set_index("Country_Geopy")
# Out:
# /var/folders/sr/32z6khr97xs2g11w52pbkzww0000gn/T/ipykernel_64845/3496400615.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_country_codes_["Country_Geopy"] = df_country_codes_.name_geopy.apply(unpack_locations)

# %%
df_["Country_Geopy"] = df_.Country_location.apply(unpack_locations)
# Out:
# /var/folders/sr/32z6khr97xs2g11w52pbkzww0000gn/T/ipykernel_64845/416814173.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_["Country_Geopy"] = df_.Country_location.apply(unpack_locations)

# %%
df_country_codes_[:3]
# Out:
#                                  name alpha-2 alpha-3  country-code  \
# Country_Geopy
# Afghanistan               Afghanistan      AF     AFG             4
# Åland Islands, Finland  Åland Islands      AX     ALA           248
# Albania                       Albania      AL     ALB             8
#
#                            iso_3166-2  region       sub-region  \
# Country_Geopy
# Afghanistan             ISO 3166-2:AF    Asia    Southern Asia
# Åland Islands, Finland  ISO 3166-2:AX  Europe  Northern Europe
# Albania                 ISO 3166-2:AL  Europe  Southern Europe
#
#                        intermediate-region  region-code  sub-region-code  \
# Country_Geopy
# Afghanistan                           None        142.0             34.0
# Åland Islands, Finland                None        150.0            154.0
# Albania                               None        150.0             39.0
#
#                         intermediate-region-code  \
# Country_Geopy
# Afghanistan                                  NaN
# Åland Islands, Finland                       NaN
# Albania                                      NaN
#
#                                                                name_geopy
# Country_Geopy
# Afghanistan             {'place_id': 220100631, 'licence': 'Data © Ope...
# Åland Islands, Finland  {'place_id': 180167715, 'licence': 'Data © Ope...
# Albania                 {'place_id': 83081284, 'licence': 'Data © Open...

# %%
df_[:2]
# Out:
#    Decade       Date  Time                   Location  \
# 0    1950 1953-01-05  2139  Belfast, Northern Ireland
# 1    1950 1953-01-07  2055       Issaquah, Washington
#
#                    Operator Flight_Num                              Route  \
# 0  British European Airways       None                 Northolt - Belfast
# 1         Flying Tiger Line        841  Seattle - Cheyenne - Fort Jackson
#
#                  Ac_Type Registration  Cn_Ln  \
# 0  Vickers Viking 610-1B       G-AJDL    262
# 1    Douglas C-54B-10-DO       N86574  18350
#
#                                        Aboard  \
# 0  {'total': 35, 'passengers': 31, 'crew': 4}
# 1    {'total': 7, 'passengers': 3, 'crew': 4}
#
#                                    Fatalities  Ground  \
# 0  {'total': 27, 'passengers': 24, 'crew': 3}     0.0
# 1    {'total': 7, 'passengers': 3, 'crew': 4}     0.0
#
#                                              Summary  Aboard_Total  \
# 0  Crashed into approach lights while attempting ...            35
# 1  The plane struck a tree on a mountain ridge at...             7
#
#    Fatalities_Total      Operator_vs_Military  \
# 0                27  British European Airways
# 1                 7         Flying Tiger Line
#
#                                     Country_location  \
# 0  {'place_id': 372303099, 'licence': 'Data © Ope...
# 1  {'place_id': 383391892, 'licence': 'Data © Ope...
#
#                       Country_Geopy
# 0  Northern Ireland, United Kingdom
# 1         Washington, United States

# %%
# 'This country match >>> Holy See >>> Texas, United States', red flag here Holy See is being tide to Texas so drop 
# This list comprehension checks if the name is in the index if it's not in there we list it to check sanity 
[f"This country match >>> {i} >>> {df_country_codes_["name"][df_country_codes_["name"] == i].index[0]}" for i in df_country_codes_["name"] if i not in df_country_codes_["name"][df_country_codes_["name"] == i].index[0]]
# Out:
# ['This country match >>> Bolivia (Plurinational State of) >>> Bolivia',
#  'This country match >>> Bonaire, Sint Eustatius and Saba >>> Caribbean Netherlands, Netherlands',
#  'This country match >>> Brunei Darussalam >>> Brunei',
#  'This country match >>> Cabo Verde >>> Cape Verde',
#  'This country match >>> Congo, Democratic Republic of the >>> Democratic Republic of the Congo',
#  'This country match >>> Curaçao >>> Curacao, Netherlands',
#  'This country match >>> Falkland Islands (Malvinas) >>> Falkland Islands',
#  'This country match >>> French Southern Territories >>> French Southern and Antarctic Lands, France',
#  'This country match >>> Holy See >>> Texas, United States',
#  'This country match >>> Iran (Islamic Republic of) >>> Iran',
#  "This country match >>> Korea (Democratic People's Republic of) >>> Gangwon State, South Korea",
#  'This country match >>> Korea, Republic of >>> Gangwon State, South Korea',
#  "This country match >>> Lao People's Democratic Republic >>> Laos",
#  'This country match >>> Macao >>> Macau, China',
#  'This country match >>> Micronesia (Federated States of) >>> Federated States of Micronesia',
#  'This country match >>> Moldova, Republic of >>> MD-2004, Moldova',
#  'This country match >>> Palestine, State of >>> New York, United States',
#  'This country match >>> Russian Federation >>> Russia',
#  'This country match >>> Saint Martin (French part) >>> Saint Martin (France), France',
#  'This country match >>> Sao Tome and Principe >>> São Tomé and Príncipe',
#  'This country match >>> Syrian Arab Republic >>> Syria',
#  'This country match >>> Taiwan, Province of China >>> Anhui, China',
#  'This country match >>> Tanzania, United Republic of >>> Tanzania',
#  'This country match >>> Timor-Leste >>> East Timor',
#  'This country match >>> United Kingdom of Great Britain and Northern Ireland >>> United Kingdom',
#  'This country match >>> United States of America >>> United States',
#  'This country match >>> Venezuela (Bolivarian Republic of) >>> Venezuela',
#  'This country match >>> Viet Nam >>> Vietnam',
#  'This country match >>> Virgin Islands (British) >>> British Virgin Islands',
#  'This country match >>> Virgin Islands (U.S.) >>> United States Virgin Islands, United States',
#  'This country match >>> Western Sahara >>> Dakhla-Oued Ed-Dahab, Morocco']

# %%
df_country_codes_
# Out:
#                                             name alpha-2 alpha-3  \
# Country_Geopy
# Afghanistan                          Afghanistan      AF     AFG
# Åland Islands, Finland             Åland Islands      AX     ALA
# Albania                                  Albania      AL     ALB
# Algeria                                  Algeria      DZ     DZA
# American Samoa, United States     American Samoa      AS     ASM
# ...                                          ...     ...     ...
# Wallis and Futuna, France      Wallis and Futuna      WF     WLF
# Dakhla-Oued Ed-Dahab, Morocco     Western Sahara      EH     ESH
# Yemen                                      Yemen      YE     YEM
# Zambia                                    Zambia      ZM     ZMB
# Zimbabwe                                Zimbabwe      ZW     ZWE
#
#                                country-code     iso_3166-2   region  \
# Country_Geopy
# Afghanistan                               4  ISO 3166-2:AF     Asia
# Åland Islands, Finland                  248  ISO 3166-2:AX   Europe
# Albania                                   8  ISO 3166-2:AL   Europe
# Algeria                                  12  ISO 3166-2:DZ   Africa
# American Samoa, United States            16  ISO 3166-2:AS  Oceania
# ...                                     ...            ...      ...
# Wallis and Futuna, France               876  ISO 3166-2:WF  Oceania
# Dakhla-Oued Ed-Dahab, Morocco           732  ISO 3166-2:EH   Africa
# Yemen                                   887  ISO 3166-2:YE     Asia
# Zambia                                  894  ISO 3166-2:ZM   Africa
# Zimbabwe                                716  ISO 3166-2:ZW   Africa
#
#                                        sub-region intermediate-region  \
# Country_Geopy
# Afghanistan                         Southern Asia                None
# Åland Islands, Finland            Northern Europe                None
# Albania                           Southern Europe                None
# Algeria                           Northern Africa                None
# American Samoa, United States           Polynesia                None
# ...                                           ...                 ...
# Wallis and Futuna, France               Polynesia                None
# Dakhla-Oued Ed-Dahab, Morocco     Northern Africa                None
# Yemen                                Western Asia                None
# Zambia                         Sub-Saharan Africa      Eastern Africa
# Zimbabwe                       Sub-Saharan Africa      Eastern Africa
#
#                                region-code  sub-region-code  \
# Country_Geopy
# Afghanistan                          142.0             34.0
# Åland Islands, Finland               150.0            154.0
# Albania                              150.0             39.0
# Algeria                                2.0             15.0
# American Samoa, United States          9.0             61.0
# ...                                    ...              ...
# Wallis and Futuna, France              9.0             61.0
# Dakhla-Oued Ed-Dahab, Morocco          2.0             15.0
# Yemen                                142.0            145.0
# Zambia                                 2.0            202.0
# Zimbabwe                               2.0            202.0
#
#                                intermediate-region-code  \
# Country_Geopy
# Afghanistan                                         NaN
# Åland Islands, Finland                              NaN
# Albania                                             NaN
# Algeria                                             NaN
# American Samoa, United States                       NaN
# ...                                                 ...
# Wallis and Futuna, France                           NaN
# Dakhla-Oued Ed-Dahab, Morocco                       NaN
# Yemen                                               NaN
# Zambia                                             14.0
# Zimbabwe                                           14.0
#
#                                                                       name_geopy
# Country_Geopy
# Afghanistan                    {'place_id': 220100631, 'licence': 'Data © Ope...
# Åland Islands, Finland         {'place_id': 180167715, 'licence': 'Data © Ope...
# Albania                        {'place_id': 83081284, 'licence': 'Data © Open...
# Algeria                        {'place_id': 77146891, 'licence': 'Data © Open...
# American Samoa, United States  {'place_id': 32805879, 'licence': 'Data © Open...
# ...                                                                          ...
# Wallis and Futuna, France      {'place_id': 33145748, 'licence': 'Data © Open...
# Dakhla-Oued Ed-Dahab, Morocco  {'place_id': 288513039, 'licence': 'Data © Ope...
# Yemen                          {'place_id': 69324426, 'licence': 'Data © Open...
# Zambia                         {'place_id': 65568484, 'licence': 'Data © Open...
# Zimbabwe                       {'place_id': 60730405, 'licence': 'Data © Open...
#
# [248 rows x 12 columns]

# %%
# Geopy is tagging 
df_country_codes_.loc[["New York, United States","Texas, United States"]]
# Out:
#                                         name alpha-2 alpha-3  country-code  \
# Country_Geopy
# New York, United States  Palestine, State of      PS     PSE           275
# Texas, United States                Holy See      VA     VAT           336
#
#                             iso_3166-2  region       sub-region  \
# Country_Geopy
# New York, United States  ISO 3166-2:PS    Asia     Western Asia
# Texas, United States     ISO 3166-2:VA  Europe  Southern Europe
#
#                         intermediate-region  region-code  sub-region-code  \
# Country_Geopy
# New York, United States                None        142.0            145.0
# Texas, United States                   None        150.0             39.0
#
#                          intermediate-region-code  \
# Country_Geopy
# New York, United States                       NaN
# Texas, United States                          NaN
#
#                                                                 name_geopy
# Country_Geopy
# New York, United States  {'place_id': 6507300, 'licence': 'Data © OpenS...
# Texas, United States     {'place_id': 293797351, 'licence': 'Data © Ope...

# %%
df_country_codes_updated = df_country_codes_.drop(["Texas, United States","New York, United States"] )

# %%
def get_code(x):
    try:
        return df_country_codes_updated.loc[x]["alpha-3"]
    except:
        return float("nan")

# %%
df_["Code"] = df_.Country_Geopy.apply(get_code)
# Out:
# /var/folders/sr/32z6khr97xs2g11w52pbkzww0000gn/T/ipykernel_64845/3812215558.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_["Code"] = df_.Country_Geopy.apply(get_code)

# %%
df_["Code"].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 4918 entries, 0 to 5036
# Series name: Code
# Non-Null Count  Dtype
# --------------  -----
# 1532 non-null   object
# dtypes: object(1)
# memory usage: 205.9+ KB

# %%
good_code_column = df_[df_.Code.apply(lambda x: not isinstance(x,float))]
missing_code = df_[df_.Code.apply(lambda x: isinstance(x,float))]
good_code_column[:2]
# Out:
#     Decade       Date  Time                    Location  \
# 3     1950 1953-01-15  0448  25 nm off Agrigento, Italy
# 12    1950 1953-03-14  None            Kalasahar, India
#
#                      Operator Flight_Num          Route  \
# 3   Military -Royal Air Force          -           None
# 12             Orient Airways       None  Delhi - Dacca
#
#                                   Ac_Type   Registration Cn_Ln  \
# 3   Vickers Valetta Mk1 / Avero Lancaster  VX562 / TX270  None
# 12                       Convair CV-240-7         AP-AEG   082
#
#                                          Aboard  \
# 3   {'total': 26, 'passengers': 16, 'crew': 10}
# 12   {'total': 16, 'passengers': 11, 'crew': 5}
#
#                                      Fatalities  Ground  \
# 3   {'total': 26, 'passengers': 16, 'crew': 10}     0.0
# 12   {'total': 16, 'passengers': 11, 'crew': 5}     0.0
#
#                                               Summary  Aboard_Total  \
# 3   Both aircraft crashed after a midair collision...            26
# 12  Crashed into a mountain while en route in seve...            16
#
#     Fatalities_Total Operator_vs_Military  \
# 3                 26             Military
# 12                16       Orient Airways
#
#                                      Country_location Country_Geopy Code
# 3   {'place_id': 100666283, 'licence': 'Data © Ope...         Italy  ITA
# 12  {'place_id': 246884012, 'licence': 'Data © Ope...         India  IND

# %%
# All the missing data from USA we have 50 different states which checks out 
len({i for i in missing_code.Country_Geopy if "United States" in i})
# Out:
# 50

# %%
missing_code.columns
# Out:
# Index(['Decade', 'Date', 'Time', 'Location', 'Operator', 'Flight_Num', 'Route',
#        'Ac_Type', 'Registration', 'Cn_Ln', 'Aboard', 'Fatalities', 'Ground',
#        'Summary', 'Aboard_Total', 'Fatalities_Total', 'Operator_vs_Military',
#        'Country_location', 'Country_Geopy', 'Code'],
#       dtype='object')

# %%
def check_country_geopy_match(s):
    return lambda x : s in x

def get_missing_df(df, s):
    return df[df.Country_Geopy.apply(check_country_geopy_match(s))]

# %%
df_country_codes_updated
# Out:
#                                             name alpha-2 alpha-3  \
# Country_Geopy
# Afghanistan                          Afghanistan      AF     AFG
# Åland Islands, Finland             Åland Islands      AX     ALA
# Albania                                  Albania      AL     ALB
# Algeria                                  Algeria      DZ     DZA
# American Samoa, United States     American Samoa      AS     ASM
# ...                                          ...     ...     ...
# Wallis and Futuna, France      Wallis and Futuna      WF     WLF
# Dakhla-Oued Ed-Dahab, Morocco     Western Sahara      EH     ESH
# Yemen                                      Yemen      YE     YEM
# Zambia                                    Zambia      ZM     ZMB
# Zimbabwe                                Zimbabwe      ZW     ZWE
#
#                                country-code     iso_3166-2   region  \
# Country_Geopy
# Afghanistan                               4  ISO 3166-2:AF     Asia
# Åland Islands, Finland                  248  ISO 3166-2:AX   Europe
# Albania                                   8  ISO 3166-2:AL   Europe
# Algeria                                  12  ISO 3166-2:DZ   Africa
# American Samoa, United States            16  ISO 3166-2:AS  Oceania
# ...                                     ...            ...      ...
# Wallis and Futuna, France               876  ISO 3166-2:WF  Oceania
# Dakhla-Oued Ed-Dahab, Morocco           732  ISO 3166-2:EH   Africa
# Yemen                                   887  ISO 3166-2:YE     Asia
# Zambia                                  894  ISO 3166-2:ZM   Africa
# Zimbabwe                                716  ISO 3166-2:ZW   Africa
#
#                                        sub-region intermediate-region  \
# Country_Geopy
# Afghanistan                         Southern Asia                None
# Åland Islands, Finland            Northern Europe                None
# Albania                           Southern Europe                None
# Algeria                           Northern Africa                None
# American Samoa, United States           Polynesia                None
# ...                                           ...                 ...
# Wallis and Futuna, France               Polynesia                None
# Dakhla-Oued Ed-Dahab, Morocco     Northern Africa                None
# Yemen                                Western Asia                None
# Zambia                         Sub-Saharan Africa      Eastern Africa
# Zimbabwe                       Sub-Saharan Africa      Eastern Africa
#
#                                region-code  sub-region-code  \
# Country_Geopy
# Afghanistan                          142.0             34.0
# Åland Islands, Finland               150.0            154.0
# Albania                              150.0             39.0
# Algeria                                2.0             15.0
# American Samoa, United States          9.0             61.0
# ...                                    ...              ...
# Wallis and Futuna, France              9.0             61.0
# Dakhla-Oued Ed-Dahab, Morocco          2.0             15.0
# Yemen                                142.0            145.0
# Zambia                                 2.0            202.0
# Zimbabwe                               2.0            202.0
#
#                                intermediate-region-code  \
# Country_Geopy
# Afghanistan                                         NaN
# Åland Islands, Finland                              NaN
# Albania                                             NaN
# Algeria                                             NaN
# American Samoa, United States                       NaN
# ...                                                 ...
# Wallis and Futuna, France                           NaN
# Dakhla-Oued Ed-Dahab, Morocco                       NaN
# Yemen                                               NaN
# Zambia                                             14.0
# Zimbabwe                                           14.0
#
#                                                                       name_geopy
# Country_Geopy
# Afghanistan                    {'place_id': 220100631, 'licence': 'Data © Ope...
# Åland Islands, Finland         {'place_id': 180167715, 'licence': 'Data © Ope...
# Albania                        {'place_id': 83081284, 'licence': 'Data © Open...
# Algeria                        {'place_id': 77146891, 'licence': 'Data © Open...
# American Samoa, United States  {'place_id': 32805879, 'licence': 'Data © Open...
# ...                                                                          ...
# Wallis and Futuna, France      {'place_id': 33145748, 'licence': 'Data © Open...
# Dakhla-Oued Ed-Dahab, Morocco  {'place_id': 288513039, 'licence': 'Data © Ope...
# Yemen                          {'place_id': 69324426, 'licence': 'Data © Open...
# Zambia                         {'place_id': 65568484, 'licence': 'Data © Open...
# Zimbabwe                       {'place_id': 60730405, 'licence': 'Data © Open...
#
# [246 rows x 12 columns]

# %%
print(get_missing_df(missing_code, "United States")[["Location","Country_Geopy","Operator"]].to_string())
# 4974                                           Burbank, California            California, United States                                                  Flying Tiger Line
# 4981                                             Anchorage, Alaska                Alaska, United States                                                        Winship Air
# 4989                                          Van Nuys, California            California, United States                                                    Mercer Airlines
# 4993                                          Southeastern Bolivia           Connecticut, United States                                                      TAM (Bolivia)
# 4995                                               Igiugig, Alaska                Alaska, United States                                     Kodiak Western Alaska Airlines
# 4997                                             Ketchikan, Alaska                Alaska, United States                                                    Alaska Airlines
# 5016                                            Hawk Inlet, Alaska                Alaska, United States                                       Temsco Helicopter - Air Taxi
# 5021                                         Near Alpena, Michigan              Michigan, United States                                          Military - U.S. Air Force
# 5031                                          Cape May, New Jersey            New Jersey, United States                                             Atlantic City Airlines

# %%
missing_code["Country_Geop_3"] = missing_code.Country_location.apply(unpack_locations_part)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 missing_code["Country_Geop_3"] = missing_code.Country_location.apply(unpack_locations_part)
#
# NameError: name 'unpack_locations_part' is not defined

# %%
missing_code["Code_2"] = missing_code.Country_Geopy.apply(get_code)
# Out:
# /var/folders/sr/32z6khr97xs2g11w52pbkzww0000gn/T/ipykernel_64296/2062250936.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   missing_code["Code_2"] = missing_code.Country_Geopy.apply(get_code)

# %%
missing_code
# Out:
#       Decade       Date   Time                   Location  \
# 0       1950 1953-01-05   2139  Belfast, Northern Ireland
# 1       1950 1953-01-07   2055       Issaquah, Washington
# 2       1950 1953-01-07   0412          Fish Haven, Idaho
# 4       1950 1953-01-26   1144    Sinnai, Sardinia, Italy
# 5       1950 1953-02-02   0530   Off Newfoundland, Canada
# ...      ...        ...    ...                        ...
# 5029    1970 1976-11-23   0945             Kozani, Greece
# 5030    1970 1976-11-28   1856             Moscow, Russia
# 5031    1970 1976-12-12   2326       Cape May, New Jersey
# 5032    1970 1976-12-17   1940            Ust-Kut, Russia
# 5033    1970 1976-12-17  21:30                 Kiev, USSR
#
#                                        Operator Flight_Num  \
# 0                      British European Airways       None
# 1                             Flying Tiger Line        841
# 2                      Associated Air Transport     1-6-6A
# 4                          Linee Aeree Italiane       None
# 5     Lancashire Aircraft Corporation (Skyways)       None
# ...                                         ...        ...
# 5029                            Olympic Airways       None
# 5030                                   Aeroflot       2415
# 5031                     Atlantic City Airlines        977
# 5032                                   Aeroflot       None
# 5033                                   Aeroflot       H-36
#
#                                   Route  \
# 0                    Northolt - Belfast
# 1     Seattle - Cheyenne - Fort Jackson
# 2               Boeing Field - Cheyenne
# 4                       Cagliari - Rome
# 5                Lajes, Azores - Gander
# ...                                 ...
# 5029                    Athens - Larisa
# 5030                 Moscow - Leningrad
# 5031            Atlantic City - Cap May
# 5032                  Ust-Kut - Kirensk
# 5033                  Chernivtsi - Kiev
#
#                                        Ac_Type Registration     Cn_Ln  ...  \
# 0                        Vickers Viking 610-1B       G-AJDL       262  ...
# 1                          Douglas C-54B-10-DO       N86574     18350  ...
# 2                                 Curtiss C-46       N1648M     22395  ...
# 4                                 Douglas DC-3       I-LAIL      4308  ...
# 5                              Avro 685 York 1       G-AHFA      1304  ...
# ...                                        ...          ...       ...  ...
# 5029                           NAMC YS-11A-500       SX-BBR      2156  ...
# 5030                           Tupolev TU-104B   CCCP-42471    021204  ...
# 5031  de Havilland Canada DHC-6 Twin Otter 300       N101AC       262  ...
# 5032                               Yakovlev 40   CCCP-88208   9631349  ...
# 5033                           Antonov AN-24RV   CCCP-46672  47309604  ...
#
#      Ground                                            Summary  Aboard_Total  \
# 0       0.0  Crashed into approach lights while attempting ...            35
# 1       0.0  The plane struck a tree on a mountain ridge at...             7
# 2       0.0  The plane crashed into mountains while en rout...            40
# 4       0.0  Crashed 10 miles east of Cagliari in the Sinna...            19
# 5       0.0  Last know coordinates 46' 15" N, 46'31"W, over...            39
# ...     ...                                                ...           ...
# 5029    0.0  The airliner crashed into mountainous terrain ...            50
# 5030    0.0  After taking off an artificial horizon failure...            73
# 5031    0.0  The plane crashed short of the runway in rain....            10
# 5032    0.0  The cargo plane crashed into trees on takeoff....             7
# 5033    0.0  In heavy fog  the crew continued their descend...            55
#
#      Fatalities_Total                       Operator_vs_Military  \
# 0                  27                   British European Airways
# 1                   7                          Flying Tiger Line
# 2                  40                   Associated Air Transport
# 4                  19                       Linee Aeree Italiane
# 5                  39  Lancashire Aircraft Corporation (Skyways)
# ...               ...                                        ...
# 5029               50                            Olympic Airways
# 5030               73                                   Aeroflot
# 5031                3                     Atlantic City Airlines
# 5032                7                                   Aeroflot
# 5033               48                                   Aeroflot
#
#                                        Country_location  \
# 0     {'place_id': 372303099, 'licence': 'Data © Ope...
# 1     {'place_id': 383391892, 'licence': 'Data © Ope...
# 2     {'place_id': 315821592, 'licence': 'Data © Ope...
# 4     {'place_id': 78523394, 'licence': 'Data © Open...
# 5     {'place_id': 278097010, 'licence': 'Data © Ope...
# ...                                                 ...
# 5029  {'place_id': 83092758, 'licence': 'Data © Open...
# 5030  {'place_id': 386169025, 'licence': 'Data © Ope...
# 5031  {'place_id': 1881913, 'licence': 'Data © OpenS...
# 5032  {'place_id': 224774650, 'licence': 'Data © Ope...
# 5033  {'place_id': 202588741, 'licence': 'Data © Ope...
#
#                           Country_Geopy Code  Country_Geop_3 Code_2
# 0      Northern Ireland, United Kingdom  NaN  United Kingdom    NaN
# 1             Washington, United States  NaN   United States    NaN
# 2                  Idaho, United States  NaN   United States    NaN
# 4                       Sardinia, Italy  NaN           Italy    NaN
# 5     Newfoundland and Labrador, Canada  NaN          Canada    NaN
# ...                                 ...  ...             ...    ...
# 5029                     501 00, Greece  NaN          Greece    NaN
# 5030   Central Federal District, Russia  NaN          Russia    NaN
# 5031          New Jersey, United States  NaN   United States    NaN
# 5032  Siberian Federal District, Russia  NaN          Russia    NaN
# 5033                      Kyiv, Ukraine  NaN         Ukraine    NaN
#
# [3386 rows x 22 columns]

# %%
def get_code_2(x):
    try:
        return df_country_codes_updated.loc[x]["alpha-3"]
    except:
        return float("nan")

# %%
df_country_codes_["Country_Geopy_"] = df_country_codes_.name_geopy.apply(unpack_locations_part)

# %%
df_country_codes_
# Out:
#                                             name alpha-2 alpha-3  \
# Country_Geopy
# Afghanistan                          Afghanistan      AF     AFG
# Åland Islands, Finland             Åland Islands      AX     ALA
# Albania                                  Albania      AL     ALB
# Algeria                                  Algeria      DZ     DZA
# American Samoa, United States     American Samoa      AS     ASM
# ...                                          ...     ...     ...
# Wallis and Futuna, France      Wallis and Futuna      WF     WLF
# Dakhla-Oued Ed-Dahab, Morocco     Western Sahara      EH     ESH
# Yemen                                      Yemen      YE     YEM
# Zambia                                    Zambia      ZM     ZMB
# Zimbabwe                                Zimbabwe      ZW     ZWE
#
#                                country-code     iso_3166-2   region  \
# Country_Geopy
# Afghanistan                               4  ISO 3166-2:AF     Asia
# Åland Islands, Finland                  248  ISO 3166-2:AX   Europe
# Albania                                   8  ISO 3166-2:AL   Europe
# Algeria                                  12  ISO 3166-2:DZ   Africa
# American Samoa, United States            16  ISO 3166-2:AS  Oceania
# ...                                     ...            ...      ...
# Wallis and Futuna, France               876  ISO 3166-2:WF  Oceania
# Dakhla-Oued Ed-Dahab, Morocco           732  ISO 3166-2:EH   Africa
# Yemen                                   887  ISO 3166-2:YE     Asia
# Zambia                                  894  ISO 3166-2:ZM   Africa
# Zimbabwe                                716  ISO 3166-2:ZW   Africa
#
#                                        sub-region intermediate-region  \
# Country_Geopy
# Afghanistan                         Southern Asia                None
# Åland Islands, Finland            Northern Europe                None
# Albania                           Southern Europe                None
# Algeria                           Northern Africa                None
# American Samoa, United States           Polynesia                None
# ...                                           ...                 ...
# Wallis and Futuna, France               Polynesia                None
# Dakhla-Oued Ed-Dahab, Morocco     Northern Africa                None
# Yemen                                Western Asia                None
# Zambia                         Sub-Saharan Africa      Eastern Africa
# Zimbabwe                       Sub-Saharan Africa      Eastern Africa
#
#                                region-code  sub-region-code  \
# Country_Geopy
# Afghanistan                          142.0             34.0
# Åland Islands, Finland               150.0            154.0
# Albania                              150.0             39.0
# Algeria                                2.0             15.0
# American Samoa, United States          9.0             61.0
# ...                                    ...              ...
# Wallis and Futuna, France              9.0             61.0
# Dakhla-Oued Ed-Dahab, Morocco          2.0             15.0
# Yemen                                142.0            145.0
# Zambia                                 2.0            202.0
# Zimbabwe                               2.0            202.0
#
#                                intermediate-region-code  \
# Country_Geopy
# Afghanistan                                         NaN
# Åland Islands, Finland                              NaN
# Albania                                             NaN
# Algeria                                             NaN
# American Samoa, United States                       NaN
# ...                                                 ...
# Wallis and Futuna, France                           NaN
# Dakhla-Oued Ed-Dahab, Morocco                       NaN
# Yemen                                               NaN
# Zambia                                             14.0
# Zimbabwe                                           14.0
#
#                                                                       name_geopy  \
# Country_Geopy
# Afghanistan                    {'place_id': 220100631, 'licence': 'Data © Ope...
# Åland Islands, Finland         {'place_id': 180167715, 'licence': 'Data © Ope...
# Albania                        {'place_id': 83081284, 'licence': 'Data © Open...
# Algeria                        {'place_id': 77146891, 'licence': 'Data © Open...
# American Samoa, United States  {'place_id': 32805879, 'licence': 'Data © Open...
# ...                                                                          ...
# Wallis and Futuna, France      {'place_id': 33145748, 'licence': 'Data © Open...
# Dakhla-Oued Ed-Dahab, Morocco  {'place_id': 288513039, 'licence': 'Data © Ope...
# Yemen                          {'place_id': 69324426, 'licence': 'Data © Open...
# Zambia                         {'place_id': 65568484, 'licence': 'Data © Open...
# Zimbabwe                       {'place_id': 60730405, 'licence': 'Data © Open...
#
#                               Country_Geopy_
# Country_Geopy
# Afghanistan                      Afghanistan
# Åland Islands, Finland               Finland
# Albania                              Albania
# Algeria                              Algeria
# American Samoa, United States  United States
# ...                                      ...
# Wallis and Futuna, France             France
# Dakhla-Oued Ed-Dahab, Morocco        Morocco
# Yemen                                  Yemen
# Zambia                                Zambia
# Zimbabwe                            Zimbabwe
#
# [248 rows x 13 columns]

# %%
df_country_codes_
# Out:
#                                             name alpha-2 alpha-3  \
# Country_Geopy
# Afghanistan                          Afghanistan      AF     AFG
# Åland Islands, Finland             Åland Islands      AX     ALA
# Albania                                  Albania      AL     ALB
# Algeria                                  Algeria      DZ     DZA
# American Samoa, United States     American Samoa      AS     ASM
# ...                                          ...     ...     ...
# Wallis and Futuna, France      Wallis and Futuna      WF     WLF
# Dakhla-Oued Ed-Dahab, Morocco     Western Sahara      EH     ESH
# Yemen                                      Yemen      YE     YEM
# Zambia                                    Zambia      ZM     ZMB
# Zimbabwe                                Zimbabwe      ZW     ZWE
#
#                                country-code     iso_3166-2   region  \
# Country_Geopy
# Afghanistan                               4  ISO 3166-2:AF     Asia
# Åland Islands, Finland                  248  ISO 3166-2:AX   Europe
# Albania                                   8  ISO 3166-2:AL   Europe
# Algeria                                  12  ISO 3166-2:DZ   Africa
# American Samoa, United States            16  ISO 3166-2:AS  Oceania
# ...                                     ...            ...      ...
# Wallis and Futuna, France               876  ISO 3166-2:WF  Oceania
# Dakhla-Oued Ed-Dahab, Morocco           732  ISO 3166-2:EH   Africa
# Yemen                                   887  ISO 3166-2:YE     Asia
# Zambia                                  894  ISO 3166-2:ZM   Africa
# Zimbabwe                                716  ISO 3166-2:ZW   Africa
#
#                                        sub-region intermediate-region  \
# Country_Geopy
# Afghanistan                         Southern Asia                None
# Åland Islands, Finland            Northern Europe                None
# Albania                           Southern Europe                None
# Algeria                           Northern Africa                None
# American Samoa, United States           Polynesia                None
# ...                                           ...                 ...
# Wallis and Futuna, France               Polynesia                None
# Dakhla-Oued Ed-Dahab, Morocco     Northern Africa                None
# Yemen                                Western Asia                None
# Zambia                         Sub-Saharan Africa      Eastern Africa
# Zimbabwe                       Sub-Saharan Africa      Eastern Africa
#
#                                region-code  sub-region-code  \
# Country_Geopy
# Afghanistan                          142.0             34.0
# Åland Islands, Finland               150.0            154.0
# Albania                              150.0             39.0
# Algeria                                2.0             15.0
# American Samoa, United States          9.0             61.0
# ...                                    ...              ...
# Wallis and Futuna, France              9.0             61.0
# Dakhla-Oued Ed-Dahab, Morocco          2.0             15.0
# Yemen                                142.0            145.0
# Zambia                                 2.0            202.0
# Zimbabwe                               2.0            202.0
#
#                                intermediate-region-code  \
# Country_Geopy
# Afghanistan                                         NaN
# Åland Islands, Finland                              NaN
# Albania                                             NaN
# Algeria                                             NaN
# American Samoa, United States                       NaN
# ...                                                 ...
# Wallis and Futuna, France                           NaN
# Dakhla-Oued Ed-Dahab, Morocco                       NaN
# Yemen                                               NaN
# Zambia                                             14.0
# Zimbabwe                                           14.0
#
#                                                                       name_geopy  \
# Country_Geopy
# Afghanistan                    {'place_id': 220100631, 'licence': 'Data © Ope...
# Åland Islands, Finland         {'place_id': 180167715, 'licence': 'Data © Ope...
# Albania                        {'place_id': 83081284, 'licence': 'Data © Open...
# Algeria                        {'place_id': 77146891, 'licence': 'Data © Open...
# American Samoa, United States  {'place_id': 32805879, 'licence': 'Data © Open...
# ...                                                                          ...
# Wallis and Futuna, France      {'place_id': 33145748, 'licence': 'Data © Open...
# Dakhla-Oued Ed-Dahab, Morocco  {'place_id': 288513039, 'licence': 'Data © Ope...
# Yemen                          {'place_id': 69324426, 'licence': 'Data © Open...
# Zambia                         {'place_id': 65568484, 'licence': 'Data © Open...
# Zimbabwe                       {'place_id': 60730405, 'licence': 'Data © Open...
#
#                               Country_Geopy_
# Country_Geopy
# Afghanistan                      Afghanistan
# Åland Islands, Finland               Finland
# Albania                              Albania
# Algeria                              Algeria
# American Samoa, United States  United States
# ...                                      ...
# Wallis and Futuna, France             France
# Dakhla-Oued Ed-Dahab, Morocco        Morocco
# Yemen                                  Yemen
# Zambia                                Zambia
# Zimbabwe                            Zimbabwe
#
# [248 rows x 13 columns]

# %%
# import json
# import pandas as pd
# import plotly.express as px

# with open("data/geojson-counties-fips.json", "r") as f:
#     counties = json.load(f)

# import pandas as pd
# df = pd.read_csv("data/fips-unemp-16.csv",
#                    dtype={"fips": str})

# fig = px.choropleth(df, geojson=counties, locations='fips', color='unemp',
#                            color_continuous_scale="viridis",
#                            range_color=(0, 12),
#                         #    scope="usa",
#                            labels={'unemp':'unemployment rate'}
#                           )
# fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
# fig.show()

# %%
# import plotly.express as px

# # Sample data: a list of dictionaries
# # Each dictionary represents a point with a latitude, longitude, and some value.
# data = [
#     {"lat": 34.0522, "lon": -118.2437, "value": 10},  # Los Angeles
#     {"lat": 40.7128, "lon": -74.0060, "value": 20},  # New York
#     {"lat": 37.7749, "lon": -122.4194, "value": 30},  # San Francisco
# ]

# # Convert the list of dictionaries to a DataFrame
# import pandas as pd
# df = pd.DataFrame(data)

# # Plot using scatter_geo
# fig = px.scatter_geo(df,
#                      lat="lat",
#                      lon="lon",
#                      size="value",  # Adjust the size of each point based on the "value"
#                      )

# # Show the figure
# fig.show()

# %%
# import plotly.express as px

# fig = px.choropleth(locations=["Northern Ireland, United Kingdom"], color=[1,2,3],)
# fig.show()

# %%
# import plotly.express as px

# # Assuming 'df' is your DataFrame with 'lat' and 'lon' columns
# px.set_mapbox_access_token('your_mapbox_access_token_here')

# fig = px.density_mapbox(df, lat='lat', lon='lon', z='value', radius=10,
#                         center=dict(lat=0, lon=180), zoom=0,
#                         mapbox_style="stamen-terrain")

# fig.show()

# %%
# import plotly.express as px
# import pandas as pd

# df = pd.read_csv("location_coordinate.csv")

# fig = px.scatter_geo(df,lat='lat',lon='long', hover_name="id")
# fig.update_layout(title = 'World map', title_x=0.5)
# fig.show()

# %%
# df.Date = df.Date.astype(str)

# %%
# df.to_json("data/silver/1920_2024_geopy.json")
