# %% [markdown]
# ### Exploring fatalities and crashes across time
# - Objective is to find operators with the highest number of crashes
# - Select top 5 and observe across decade

# %%
import pandas as pd
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
df = pd.read_csv("data/ready_for_plotting/data_plot_map.csv")
df.Date = pd.to_datetime(df.Date)

# %%
df[df.Fatalities_Total > 100][:5]
# Out:
#      Decade       Date   Time                      Location  \
# 38     1950 1953-06-18   1634   Tachikawa AFB, Tokyo, Japan
# 199    1990 1990-10-02   0915              Guangzhou, China
# 249    1980 1984-10-11  05:40             Near Omsk, Russia
# 258    1980 1984-12-23   1415       Near Kranoyarsk, Russia
# 271    1980 1985-02-19   0927  Near Durango, Vizcaya, Spain
#
#                                       Operator Flight_Num  \
# 38                   Military - U.S. Air Force        NaN
# 199  China Southern Airlines / Xiamen Airlines     ?/8301
# 249                                   Aeroflot       3352
# 258                                   Aeroflot       3519
# 271                            Iberia Airlines        610
#
#                        Route                              Ac_Type  \
# 38   Tachikawa AB - Kimpo AB        Douglas C-124A Globemaster II
# 199      Guangzhou - Shanghi  Boeing B-737-247 / Boeing B-757-21B
# 249         Krasnodar - Omsk                      Tupolev TU-154B
# 258    Krasnoyarsk - Irkutsk                    Tupolev TU-154B-2
# 271          Madrid - Bilbao                     Boeing B-727-256
#
#       Registration                   Cn_Ln  \
# 38         51-137A                   43471
# 199  B-2812/B-2510  24758/282 / 23189/1072
# 249     CCCP-85243                     243
# 258     CCCP-85338                     338
# 271         EC-DDU              21777/1487
#
#                                             Aboard  \
# 38    {'total': 129, 'passengers': 122, 'crew': 7}
# 199  {'total': 226, 'passengers': 205, 'crew': 21}
# 249   {'total': 179, 'passengers': 170, 'crew': 9}
# 258   {'total': 111, 'passengers': 104, 'crew': 7}
# 271   {'total': 148, 'passengers': 141, 'crew': 7}
#
#                                        Fatalities  Ground  \
# 38   {'total': 129, 'passengers': 122, 'crew': 7}     0.0
# 199  {'total': 128, 'passengers': 121, 'crew': 7}     0.0
# 249  {'total': 174, 'passengers': 169, 'crew': 5}     4.0
# 258  {'total': 110, 'passengers': 103, 'crew': 7}     0.0
# 271  {'total': 148, 'passengers': 141, 'crew': 7}     0.0
#
#                                                Summary  Aboard_Total  \
# 38   Crashed shortly after taking off from Tachikaw...           129
# 199  Shortly after taking off a hijacker entered th...           226
# 249  While landing, the crew noticed something on t...           179
# 258  The aircraft crashed while attempting an emerg...           111
# 271  The aircraft crashed into an antenna on Mt. Oi...           148
#
#      Fatalities_Total                       Operator_vs_Military  \
# 38                129                                   Military
# 199               128  China Southern Airlines / Xiamen Airlines
# 249               174                                   Aeroflot
# 258               110                                   Aeroflot
# 271               148                            Iberia Airlines
#
#                                       Country_location Code  \
# 38   {'place_id': 258971419, 'licence': 'Data © Ope...  JPN
# 199  {'place_id': 236617514, 'licence': 'Data © Ope...  CHN
# 249  {'place_id': 173174605, 'licence': 'Data © Ope...  RUS
# 258  {'place_id': 173174605, 'licence': 'Data © Ope...  RUS
# 271  {'place_id': 288220776, 'licence': 'Data © Ope...  ESP
#
#                  Country_Geopy
# 38                       Japan
# 199  Guangdong Province, China
# 249                     Russia
# 258                     Russia
# 271                      Spain

# %%
df.Operator_vs_Military.value_counts()[:10].plot(kind="bar")
pass

# %%
df3 = df[df.Operator_vs_Military.apply(lambda x : x in df.Operator_vs_Military.value_counts()[:5].index)]

# %%
df3[df3.Operator == 'United Air Lines'].groupby(["Decade"])["Fatalities_Total"].sum()
# Out:
# Decade
# 1930     87
# 1940    201
# 1950    230
# 1960    186
# 1970     56
# 1980    124
# 1990     26
# 2000    109
# Name: Fatalities_Total, dtype: int64

# %%
df
# Out:
#       Decade       Date   Time                         Location  \
# 0       1950 1953-01-05   2139        Belfast, Northern Ireland
# 1       1950 1953-01-07   2055             Issaquah, Washington
# 2       1950 1953-01-07   0412                Fish Haven, Idaho
# 3       1950 1953-01-15   0448       25 nm off Agrigento, Italy
# 4       1950 1953-01-26   1144          Sinnai, Sardinia, Italy
# ...      ...        ...    ...                              ...
# 5008    1970 1976-12-17   1940                  Ust-Kut, Russia
# 5009    1970 1976-12-17  21:30                       Kiev, USSR
# 5010    1970 1976-12-18   1656  Nnear Yuzhno-Sakhalinsk, Russia
# 5011    1970 1976-12-25   0345           Near Bangkok, Thailand
# 5012    1970 1976-12-31    NaN              Near Trujillo, Peru
#
#                        Operator Flight_Num  \
# 0      British European Airways        NaN
# 1             Flying Tiger Line        841
# 2      Associated Air Transport     1-6-6A
# 3     Military -Royal Air Force          -
# 4          Linee Aeree Italiane        NaN
# ...                         ...        ...
# 5008                   Aeroflot        NaN
# 5009                   Aeroflot       H-36
# 5010                   Aeroflot        NaN
# 5011                   EgyptAir        864
# 5012                    Faucett        NaN
#
#                                              Route  \
# 0                               Northolt - Belfast
# 1                Seattle - Cheyenne - Fort Jackson
# 2                          Boeing Field - Cheyenne
# 3                                              NaN
# 4                                  Cagliari - Rome
# ...                                            ...
# 5008                             Ust-Kut - Kirensk
# 5009                             Chernivtsi - Kiev
# 5010  Petropavlovsk-Kamchatsky - Yuzhno-Sakhalinsk
# 5011                               Cairo - Bangkok
# 5012                           Trujillo - Tarapoto
#
#                                     Ac_Type   Registration      Cn_Ln  \
# 0                     Vickers Viking 610-1B         G-AJDL        262
# 1                       Douglas C-54B-10-DO         N86574      18350
# 2                              Curtiss C-46         N1648M      22395
# 3     Vickers Valetta Mk1 / Avero Lancaster  VX562 / TX270        NaN
# 4                              Douglas DC-3         I-LAIL       4308
# ...                                     ...            ...        ...
# 5008                            Yakovlev 40     CCCP-88208    9631349
# 5009                        Antonov AN-24RV     CCCP-46672   47309604
# 5010                        Ilyushin IL-14M     CCCP-61752  147001247
# 5011                      Boeing B-707-366C         SU-AXA      20763
# 5012                     Douglas C-54A-1-DO       OB-R-247       7462
#
#                                            Aboard  \
# 0      {'total': 35, 'passengers': 31, 'crew': 4}
# 1        {'total': 7, 'passengers': 3, 'crew': 4}
# 2      {'total': 40, 'passengers': 37, 'crew': 3}
# 3     {'total': 26, 'passengers': 16, 'crew': 10}
# 4      {'total': 19, 'passengers': 15, 'crew': 4}
# ...                                           ...
# 5008     {'total': 7, 'passengers': 4, 'crew': 3}
# 5009   {'total': 55, 'passengers': 50, 'crew': 5}
# 5010     {'total': 8, 'passengers': 3, 'crew': 5}
# 5011   {'total': 53, 'passengers': 44, 'crew': 9}
# 5012   {'total': 19, 'passengers': 14, 'crew': 5}
#
#                                        Fatalities  Ground  \
# 0      {'total': 27, 'passengers': 24, 'crew': 3}     0.0
# 1        {'total': 7, 'passengers': 3, 'crew': 4}     0.0
# 2      {'total': 40, 'passengers': 37, 'crew': 3}     0.0
# 3     {'total': 26, 'passengers': 16, 'crew': 10}     0.0
# 4      {'total': 19, 'passengers': 15, 'crew': 4}     0.0
# ...                                           ...     ...
# 5008     {'total': 7, 'passengers': 4, 'crew': 3}     0.0
# 5009   {'total': 48, 'passengers': 44, 'crew': 4}     0.0
# 5010     {'total': 8, 'passengers': 3, 'crew': 5}     0.0
# 5011   {'total': 53, 'passengers': 44, 'crew': 9}    19.0
# 5012   {'total': 19, 'passengers': 14, 'crew': 5}     0.0
#
#                                                 Summary  Aboard_Total  \
# 0     Crashed into approach lights while attempting ...            35
# 1     The plane struck a tree on a mountain ridge at...             7
# 2     The plane crashed into mountains while en rout...            40
# 3     Both aircraft crashed after a midair collision...            26
# 4     Crashed 10 miles east of Cagliari in the Sinna...            19
# ...                                                 ...           ...
# 5008  The cargo plane crashed into trees on takeoff....             7
# 5009  In heavy fog  the crew continued their descend...            55
# 5010  The survey fllight deviated from the approach ...             8
# 5011  The aircraft crashed into an industrial area d...            53
# 5012  Struck the slope of Mt Pintado located 25 km n...            19
#
#       Fatalities_Total      Operator_vs_Military  \
# 0                   27  British European Airways
# 1                    7         Flying Tiger Line
# 2                   40  Associated Air Transport
# 3                   26                  Military
# 4                   19      Linee Aeree Italiane
# ...                ...                       ...
# 5008                 7                  Aeroflot
# 5009                48                  Aeroflot
# 5010                 8                  Aeroflot
# 5011                53                  EgyptAir
# 5012                19                   Faucett
#
#                                        Country_location Code  \
# 0     {'place_id': 372303099, 'licence': 'Data © Ope...  GBR
# 1     {'place_id': 383391892, 'licence': 'Data © Ope...  USA
# 2     {'place_id': 315821592, 'licence': 'Data © Ope...  USA
# 3     {'place_id': 100666283, 'licence': 'Data © Ope...  ITA
# 4     {'place_id': 78523394, 'licence': 'Data © Open...  ITA
# ...                                                 ...  ...
# 5008  {'place_id': 224774650, 'licence': 'Data © Ope...  RUS
# 5009  {'place_id': 202588741, 'licence': 'Data © Ope...  UKR
# 5010  {'place_id': 173174605, 'licence': 'Data © Ope...  RUS
# 5011  {'place_id': 253308938, 'licence': 'Data © Ope...  THA
# 5012  {'place_id': 35521972, 'licence': 'Data © Open...  PER
#
#                           Country_Geopy
# 0      Northern Ireland, United Kingdom
# 1             Washington, United States
# 2                  Idaho, United States
# 3                                 Italy
# 4                       Sardinia, Italy
# ...                                 ...
# 5008  Siberian Federal District, Russia
# 5009                      Kyiv, Ukraine
# 5010                             Russia
# 5011                           Thailand
# 5012                               Peru
#
# [5013 rows x 20 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5013 entries, 0 to 5012
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Decade                5013 non-null   int64
#  1   Date                  5013 non-null   datetime64[ns]
#  2   Time                  3526 non-null   object
#  3   Location              5013 non-null   object
#  4   Operator              5002 non-null   object
#  5   Flight_Num            1339 non-null   object
#  6   Route                 4267 non-null   object
#  7   Ac_Type               5000 non-null   object
#  8   Registration          4750 non-null   object
#  9   Cn_Ln                 4361 non-null   object
#  10  Aboard                5013 non-null   object
#  11  Fatalities            5013 non-null   object
#  12  Ground                4982 non-null   float64
#  13  Summary               4962 non-null   object
#  14  Aboard_Total          5013 non-null   int64
#  15  Fatalities_Total      5013 non-null   int64
#  16  Operator_vs_Military  5002 non-null   object
#  17  Country_location      5013 non-null   object
#  18  Code                  4926 non-null   object
#  19  Country_Geopy         5013 non-null   object
# dtypes: datetime64[ns](1), float64(1), int64(3), object(15)
# memory usage: 783.4+ KB

# %%
df
# Out:
#       Decade       Date   Time                         Location  \
# 0       1950 1953-01-05   2139        Belfast, Northern Ireland
# 1       1950 1953-01-07   2055             Issaquah, Washington
# 2       1950 1953-01-07   0412                Fish Haven, Idaho
# 3       1950 1953-01-15   0448       25 nm off Agrigento, Italy
# 4       1950 1953-01-26   1144          Sinnai, Sardinia, Italy
# ...      ...        ...    ...                              ...
# 5008    1970 1976-12-17   1940                  Ust-Kut, Russia
# 5009    1970 1976-12-17  21:30                       Kiev, USSR
# 5010    1970 1976-12-18   1656  Nnear Yuzhno-Sakhalinsk, Russia
# 5011    1970 1976-12-25   0345           Near Bangkok, Thailand
# 5012    1970 1976-12-31    NaN              Near Trujillo, Peru
#
#                        Operator Flight_Num  \
# 0      British European Airways        NaN
# 1             Flying Tiger Line        841
# 2      Associated Air Transport     1-6-6A
# 3     Military -Royal Air Force          -
# 4          Linee Aeree Italiane        NaN
# ...                         ...        ...
# 5008                   Aeroflot        NaN
# 5009                   Aeroflot       H-36
# 5010                   Aeroflot        NaN
# 5011                   EgyptAir        864
# 5012                    Faucett        NaN
#
#                                              Route  \
# 0                               Northolt - Belfast
# 1                Seattle - Cheyenne - Fort Jackson
# 2                          Boeing Field - Cheyenne
# 3                                              NaN
# 4                                  Cagliari - Rome
# ...                                            ...
# 5008                             Ust-Kut - Kirensk
# 5009                             Chernivtsi - Kiev
# 5010  Petropavlovsk-Kamchatsky - Yuzhno-Sakhalinsk
# 5011                               Cairo - Bangkok
# 5012                           Trujillo - Tarapoto
#
#                                     Ac_Type   Registration      Cn_Ln  \
# 0                     Vickers Viking 610-1B         G-AJDL        262
# 1                       Douglas C-54B-10-DO         N86574      18350
# 2                              Curtiss C-46         N1648M      22395
# 3     Vickers Valetta Mk1 / Avero Lancaster  VX562 / TX270        NaN
# 4                              Douglas DC-3         I-LAIL       4308
# ...                                     ...            ...        ...
# 5008                            Yakovlev 40     CCCP-88208    9631349
# 5009                        Antonov AN-24RV     CCCP-46672   47309604
# 5010                        Ilyushin IL-14M     CCCP-61752  147001247
# 5011                      Boeing B-707-366C         SU-AXA      20763
# 5012                     Douglas C-54A-1-DO       OB-R-247       7462
#
#                                            Aboard  \
# 0      {'total': 35, 'passengers': 31, 'crew': 4}
# 1        {'total': 7, 'passengers': 3, 'crew': 4}
# 2      {'total': 40, 'passengers': 37, 'crew': 3}
# 3     {'total': 26, 'passengers': 16, 'crew': 10}
# 4      {'total': 19, 'passengers': 15, 'crew': 4}
# ...                                           ...
# 5008     {'total': 7, 'passengers': 4, 'crew': 3}
# 5009   {'total': 55, 'passengers': 50, 'crew': 5}
# 5010     {'total': 8, 'passengers': 3, 'crew': 5}
# 5011   {'total': 53, 'passengers': 44, 'crew': 9}
# 5012   {'total': 19, 'passengers': 14, 'crew': 5}
#
#                                        Fatalities  Ground  \
# 0      {'total': 27, 'passengers': 24, 'crew': 3}     0.0
# 1        {'total': 7, 'passengers': 3, 'crew': 4}     0.0
# 2      {'total': 40, 'passengers': 37, 'crew': 3}     0.0
# 3     {'total': 26, 'passengers': 16, 'crew': 10}     0.0
# 4      {'total': 19, 'passengers': 15, 'crew': 4}     0.0
# ...                                           ...     ...
# 5008     {'total': 7, 'passengers': 4, 'crew': 3}     0.0
# 5009   {'total': 48, 'passengers': 44, 'crew': 4}     0.0
# 5010     {'total': 8, 'passengers': 3, 'crew': 5}     0.0
# 5011   {'total': 53, 'passengers': 44, 'crew': 9}    19.0
# 5012   {'total': 19, 'passengers': 14, 'crew': 5}     0.0
#
#                                                 Summary  Aboard_Total  \
# 0     Crashed into approach lights while attempting ...            35
# 1     The plane struck a tree on a mountain ridge at...             7
# 2     The plane crashed into mountains while en rout...            40
# 3     Both aircraft crashed after a midair collision...            26
# 4     Crashed 10 miles east of Cagliari in the Sinna...            19
# ...                                                 ...           ...
# 5008  The cargo plane crashed into trees on takeoff....             7
# 5009  In heavy fog  the crew continued their descend...            55
# 5010  The survey fllight deviated from the approach ...             8
# 5011  The aircraft crashed into an industrial area d...            53
# 5012  Struck the slope of Mt Pintado located 25 km n...            19
#
#       Fatalities_Total      Operator_vs_Military  \
# 0                   27  British European Airways
# 1                    7         Flying Tiger Line
# 2                   40  Associated Air Transport
# 3                   26                  Military
# 4                   19      Linee Aeree Italiane
# ...                ...                       ...
# 5008                 7                  Aeroflot
# 5009                48                  Aeroflot
# 5010                 8                  Aeroflot
# 5011                53                  EgyptAir
# 5012                19                   Faucett
#
#                                        Country_location Code  \
# 0     {'place_id': 372303099, 'licence': 'Data © Ope...  GBR
# 1     {'place_id': 383391892, 'licence': 'Data © Ope...  USA
# 2     {'place_id': 315821592, 'licence': 'Data © Ope...  USA
# 3     {'place_id': 100666283, 'licence': 'Data © Ope...  ITA
# 4     {'place_id': 78523394, 'licence': 'Data © Open...  ITA
# ...                                                 ...  ...
# 5008  {'place_id': 224774650, 'licence': 'Data © Ope...  RUS
# 5009  {'place_id': 202588741, 'licence': 'Data © Ope...  UKR
# 5010  {'place_id': 173174605, 'licence': 'Data © Ope...  RUS
# 5011  {'place_id': 253308938, 'licence': 'Data © Ope...  THA
# 5012  {'place_id': 35521972, 'licence': 'Data © Open...  PER
#
#                           Country_Geopy
# 0      Northern Ireland, United Kingdom
# 1             Washington, United States
# 2                  Idaho, United States
# 3                                 Italy
# 4                       Sardinia, Italy
# ...                                 ...
# 5008  Siberian Federal District, Russia
# 5009                      Kyiv, Ukraine
# 5010                             Russia
# 5011                           Thailand
# 5012                               Peru
#
# [5013 rows x 20 columns]

# %%
df.groupby(df.Date.dt.to_period('Y'))["Fatalities_Total"].sum()
# Out:
# Date
# 1908      1
# 1909      1
# 1912      5
# 1913     43
# 1915     36
#        ...
# 2020    355
# 2021    185
# 2022    189
# 2023    100
# 2024     12
# Freq: Y-DEC, Name: Fatalities_Total, Length: 114, dtype: int64

# %%
df_grouped =  df.groupby(df.Date.dt.to_period("M"))["Fatalities_Total"].sum()

fig, ax = plt.subplots(figsize=(10, 5))
# Plotting as time series
df_grouped.plot(ax=ax,)
ax.set_xlabel('Date')
ax.set_ylabel('Total Fatalities')
ax.set_title('Fatalities Over Time')

# Adding vertical lines for January
for date in df_grouped.index:
    if date.month == 1:  # Check if the month is January
        ax.axvline(x=date, color='r', linestyle='--', linewidth=2)

# %%
df_grouped
# Out:
# Date
# 1908      1
# 1909      1
# 1912      5
# 1913     43
# 1915     36
#        ...
# 2020    355
# 2021    185
# 2022    189
# 2023    100
# 2024     12
# Freq: 2Y-DEC, Name: Fatalities_Total, Length: 114, dtype: int64

# %%
def to_plot_times_series(df):
    df_grouped =  df.groupby(df.Date.dt.to_period('y'))["Fatalities_Total"].sum()

    fig, ax = plt.subplots(figsize=(20, 5))
    # Plotting as time series
    df_grouped.plot(ax=ax,)
    ax.set_xlabel('Date')
    ax.set_ylabel('Total Fatalities')
    ax.set_title('Fatalities Over Time')

    # Adding vertical lines for January
    for date in df_grouped.index:
        if date == 1:  # Check if the month is January
            ax.axvline(x=date, color='r', linestyle='--', linewidth=2)

# %%
plt.plot(Bernie_tally.index,Bernie_tally.values,label="Bernie")
plt.axvline(pd.to_datetime("17 Jan 2016"), color='r', linestyle='--') 
plt.text(pd.to_datetime("12 Jan 2016"),350000,f"${Bernie_tally[pd.to_datetime("17 Jan 2016")] + Hillary_tally[pd.to_datetime("17 Jan 2016")]}",rotation=90)
plt.axvline(pd.to_datetime("11 Feb 2016"), color='r', linestyle='--') 
plt.text(pd.to_datetime("7 Feb 2016"),350000,f"${Bernie_tally[pd.to_datetime("11 Feb 2016")] + Hillary_tally[pd.to_datetime("11 Feb 2016")]}",rotation=90)
plt.axvline(pd.to_datetime("9 Mar 2016"), color='r', linestyle='--') 
plt.text(pd.to_datetime("4  Mar 2016"),350000,f"${Bernie_tally[pd.to_datetime("9 Mar 2016")] + Hillary_tally[pd.to_datetime("9 Mar 2016")]}",rotation=90)

# %%
df_grouped =  df.groupby(df.Date.dt.to_period('Y'))["Fatalities_Total"].sum()

fig, ax = plt.subplots(figsize=(20, 10))
# Plotting as time series
df_grouped.plot(ax=ax,)
ax.set_xlabel('Date')
ax.set_ylabel('Total Fatalities')
ax.set_title('Fatalities Over Time')
ax.axvline(x='2001', color='r', linestyle='--', linewidth=2)
plt.text('1999',2500,f"{2001}",rotation=90)

# Adding vertical lines for January
# for date in df_grouped.index:
#     if date == '2001':  # Check if the month is January
#         ax.axvline(x=2001, color='r', linestyle='--', linewidth=2)
# Out:
# Text(1999, 2500, '2001')

# %%
df_grouped.index
# Out:
# PeriodIndex(['1908', '1909', '1912', '1913', '1915', '1916', '1917', '1918',
#              '1919', '1920',
#              ...
#              '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#              '2023', '2024'],
#             dtype='period[Y-DEC]', name='Date', length=114)

# %%
to_plot_times_series(df)
# Out:
# /var/folders/sr/32z6khr97xs2g11w52pbkzww0000gn/T/ipykernel_47416/1852915756.py:2: FutureWarning: 'y' is deprecated and will be removed in a future version, please use 'Y' instead.
#   df_grouped =  df.groupby(df.Date.dt.to_period('10y'))["Fatalities_Total"].sum()

# %%
to_plot_times_series(df[df.Code =="USA"])
# Out:
# /var/folders/sr/32z6khr97xs2g11w52pbkzww0000gn/T/ipykernel_47416/2937424617.py:2: FutureWarning: 'y' is deprecated and will be removed in a future version, please use 'Y' instead.
#   df_grouped =  df.groupby(df.Date.dt.to_period('y'))["Fatalities_Total"].sum()

# %%
# Out:
#       Decade       Date  Time                    Location  \
# 1       1950 1953-01-07  2055        Issaquah, Washington
# 2       1950 1953-01-07  0412           Fish Haven, Idaho
# 9       1950 1953-02-14  1710         Off Mobile, Alabama
# 11      1950 1953-03-04  0150  Windsor Locks, Connecticut
# 16      1950 1953-03-20  1838        Alvarado, California
# ...      ...        ...   ...                         ...
# 4971    1970 1976-03-07  1107             Igiugig, Alaska
# 4973    1970 1976-04-05  0819           Ketchikan, Alaska
# 4992    1970 1976-09-02  1715          Hawk Inlet, Alaska
# 4997    1970 1976-09-26  0830       Near Alpena, Michigan
# 5007    1970 1976-12-12  2326        Cape May, New Jersey
#
#                             Operator Flight_Num  \
# 1                  Flying Tiger Line        841
# 2           Associated Air Transport     1-6-6A
# 9                  National Airlines        470
# 11                     Slick Airways        162
# 16              Transocean Air Lines        942
# ...                              ...        ...
# 4971  Kodiak Western Alaska Airlines        NaN
# 4973                 Alaska Airlines         60
# 4992    Temsco Helicopter - Air Taxi        NaN
# 4997       Military - U.S. Air Force        NaN
# 5007          Atlantic City Airlines        977
#
#                                           Route  \
# 1             Seattle - Cheyenne - Fort Jackson
# 2                       Boeing Field - Cheyenne
# 9                 Miami - Orlando - New Orleans
# 11              New York, NY - Winsor Locks, CT
# 16                     Roswell - Oakland - Guam
# ...                                         ...
# 4971           South Nanek, AK - Dillingham, AK
# 4973                         Juneau - Ketchikan
# 4992                                        NaN
# 4997  Kenneth Ingalls Sawyer - Oscoda-Wurtsmith
# 5007                    Atlantic City - Cap May
#
#                                        Ac_Type Registration      Cn_Ln  \
# 1                          Douglas C-54B-10-DO       N86574      18350
# 2                                 Curtiss C-46       N1648M      22395
# 9                                 Douglas DC-6       N90893   43057/73
# 11                               Curtiss C-46F       N4717N      22400
# 16                  Douglas DC-4  (C-54-10-DO)       N88942      36076
# ...                                        ...          ...        ...
# 4971                                Cessna 207       N91142   20700089
# 4973                           Boeing B-727-81       N124AS      18821
# 4992                              Hughes 369HS       N9172F        NaN
# 4997                            Boeing KC-135A      61-0296  18203/518
# 5007  de Havilland Canada DHC-6 Twin Otter 300       N101AC        262
#
#                                           Aboard  \
# 1       {'total': 7, 'passengers': 3, 'crew': 4}
# 2     {'total': 40, 'passengers': 37, 'crew': 3}
# 9     {'total': 46, 'passengers': 41, 'crew': 5}
# 11      {'total': 2, 'passengers': 0, 'crew': 2}
# 16    {'total': 35, 'passengers': 30, 'crew': 5}
# ...                                          ...
# 4971    {'total': 4, 'passengers': 3, 'crew': 1}
# 4973  {'total': 50, 'passengers': 45, 'crew': 5}
# 4992    {'total': 4, 'passengers': 3, 'crew': 1}
# 4997  {'total': 20, 'passengers': 15, 'crew': 5}
# 5007   {'total': 10, 'passengers': 8, 'crew': 2}
#
#                                       Fatalities  Ground  \
# 1       {'total': 7, 'passengers': 3, 'crew': 4}     0.0
# 2     {'total': 40, 'passengers': 37, 'crew': 3}     0.0
# 9     {'total': 46, 'passengers': 41, 'crew': 5}     0.0
# 11      {'total': 2, 'passengers': 0, 'crew': 2}     0.0
# 16    {'total': 35, 'passengers': 30, 'crew': 5}     0.0
# ...                                          ...     ...
# 4971    {'total': 4, 'passengers': 3, 'crew': 1}     0.0
# 4973    {'total': 1, 'passengers': 1, 'crew': 0}     0.0
# 4992    {'total': 3, 'passengers': 2, 'crew': 1}     0.0
# 4997  {'total': 15, 'passengers': 12, 'crew': 3}     0.0
# 5007    {'total': 3, 'passengers': 3, 'crew': 1}     0.0
#
#                                                 Summary  Aboard_Total  \
# 1     The plane struck a tree on a mountain ridge at...             7
# 2     The plane crashed into mountains while en rout...            40
# 9     The aircraft crashed into the Gulf of Mexico o...            46
# 11    After missing his first approach to the airpor...             2
# 16    The aircraft crashed into a flat barley field ...            35
# ...                                                 ...           ...
# 4971        Continued VFR flight in to adverse weather.             4
# 4973  The plane overran the runway after landing at ...            50
# 4992  Crashed while climbing to cruise altitude. Fai...             4
# 4997  Crash-landed in rugged terrain broke up and la...            20
# 5007  The plane crashed short of the runway in rain....            10
#
#       Fatalities_Total            Operator_vs_Military  \
# 1                    7               Flying Tiger Line
# 2                   40        Associated Air Transport
# 9                   46               National Airlines
# 11                   2                   Slick Airways
# 16                  35            Transocean Air Lines
# ...                ...                             ...
# 4971                 4  Kodiak Western Alaska Airlines
# 4973                 1                 Alaska Airlines
# 4992                 3    Temsco Helicopter - Air Taxi
# 4997                15                        Military
# 5007                 3          Atlantic City Airlines
#
#                                        Country_location Code  \
# 1     {'place_id': 383391892, 'licence': 'Data © Ope...  USA
# 2     {'place_id': 315821592, 'licence': 'Data © Ope...  USA
# 9     {'place_id': 293252853, 'licence': 'Data © Ope...  USA
# 11    {'place_id': 11192627, 'licence': 'Data © Open...  USA
# 16    {'place_id': 311607871, 'licence': 'Data © Ope...  USA
# ...                                                 ...  ...
# 4971  {'place_id': 375155709, 'licence': 'Data © Ope...  USA
# 4973  {'place_id': 32595077, 'licence': 'Data © Open...  USA
# 4992  {'place_id': 32778117, 'licence': 'Data © Open...  USA
# 4997  {'place_id': 23457604, 'licence': 'Data © Open...  USA
# 5007  {'place_id': 1881913, 'licence': 'Data © OpenS...  USA
#
#                    Country_Geopy
# 1      Washington, United States
# 2           Idaho, United States
# 9         Alabama, United States
# 11    Connecticut, United States
# 16     California, United States
# ...                          ...
# 4971       Alaska, United States
# 4973       Alaska, United States
# 4992       Alaska, United States
# 4997     Michigan, United States
# 5007   New Jersey, United States
#
# [1052 rows x 20 columns]

# %%
df[df.Operator_vs_Military == 'Military'].groupby(["Decade"])["Fatalities_Total"].sum().plot(x="Decade", y="Fatalities_Total")
pass

# %%
df[(df.Operator_vs_Military == 'Military') & (df.Decade > 2000) & (df.Decade < 2020)][:5]
# Out:
#       Decade       Date  Time                 Location  \
# 2566    2010 2019-06-03  1300         Near Lipo, India
# 2567    2010 2019-07-30   200        Rawalpindi, India
# 2576    2010 2018-03-06  1451           Latakia, Syria
# 2580    2010 2018-04-11  0800     Boufarik AB, Algeria
# 2582    2010 2018-05-02  1130  Port Wentworth, Georgia
#
#                            Operator Flight_Num  \
# 2566    Military - Indian Air Force        NaN
# 2567       Military - Pakistan Army        NaN
# 2576   Military - Russian Air Force        NaN
# 2580  Military - Algerian Air Force        NaN
# 2582        Military - US Air Force        NaN
#
#                                               Route  \
# 2566                       Jorhat-Rowriah - Mechuka
# 2567                                       Training
# 2576  Kuweires Air Base - Latakia-Khmeimim Air Base
# 2580                 Boufarik AB - Bechar - Tindouf
# 2582                              Savannah - Tuscon
#
#                         Ac_Type Registration       Cn_Ln  ...  \
# 2566              Antonov An-32        K2752        1009  ...
# 2567   Beechcraft B300 King Air          766        B766  ...
# 2576              Antonov An-26  RF-92955/52       10107  ...
# 2580             Ilyushin 76-TD       7T-WIP  1043419636  ...
# 2582  Lockheed HC-130H Hercules      65-0968    382-4110  ...
#
#                                          Fatalities Ground  \
# 2566      {'total': 13, 'passengers': 5, 'crew': 8}    0.0
# 2567       {'total': 5, 'passengers': 0, 'crew': 5}   14.0
# 2576     {'total': 39, 'passengers': 33, 'crew': 6}    0.0
# 2580  {'total': 257, 'passengers': 247, 'crew': 10}    0.0
# 2582       {'total': 9, 'passengers': 0, 'crew': 9}    0.0
#
#                                                 Summary Aboard_Total  \
# 2566                 Crashed about 34km WNW of Mechuka.           13
# 2567  The Pakistani military plane, on a training fl...            5
# 2576  While on approach to Latakia-Khmeimim Air Base...           39
# 2580  The Algerian military plane crashed soon after...          257
# 2582  A Porto Rico Air National Guard plane crashed ...            9
#
#       Fatalities_Total  Operator_vs_Military  \
# 2566                13              Military
# 2567                 5              Military
# 2576                39              Military
# 2580               257              Military
# 2582                 9              Military
#
#                                        Country_location Code  \
# 2566  {'place_id': 246884012, 'licence': 'Data © Ope...  IND
# 2567  {'place_id': 243213483, 'licence': 'Data © Ope...  IND
# 2576  {'place_id': 217707803, 'licence': 'Data © Ope...  SYR
# 2580  {'place_id': 77699763, 'licence': 'Data © Open...  DZA
# 2582  {'place_id': 665581, 'licence': 'Data © OpenSt...  USA
#
#                    Country_Geopy Month_Year
# 2566                       India   Jun 2019
# 2567               Punjab, India   Jul 2019
# 2576  Latakia Governorate, Syria   Mar 2018
# 2580              Blida, Algeria   Apr 2018
# 2582      Georgia, United States   May 2018
#
# [5 rows x 21 columns]

# %%
df[df.Operator == 'United Air Lines'].groupby(["Decade"])["Aboard_Total"].count().plot(x="Decade", y="Fatalities_Total")
pass

# %%
df[df.Operator == 'United Air Lines'].groupby(["Decade"])["Fatalities_Total"].sum().plot(x="Decade", y="Fatalities_Total")
pass

# %%
# # Plot for Operator A
# plt.figure(figsize=(10, 6))
# plt.plot(specific_operator[‘Decade’], specific_operator[‘Total Crashes’], marker=‘o’, linestyle=‘-’, color=‘b’, label=‘Operator A’)
# # Add the line for Operator B
# plt.plot(specific_operator_B[‘Decade’], specific_operator_B[‘Total Crashes’], marker=‘x’, linestyle=‘-’, color=‘r’, label=‘Operator B’)
# # Adding details
# plt.title(‘Total Crashes by Decade for Operators A and B’)
# plt.xlabel(‘Decade’)
# plt.ylabel(‘Total Crashes’)
# plt.legend()  # This adds the legend to differentiate the lines
# plt.grid(True)
# plt.xticks(specific_operator[‘Decade’])  # Ensure all decades are shown; adjust if necessary
# plt.show()

# %%
fig, ax = plt.subplots(2,1)
ax[1].plot(df[df.Operator_vs_Military == 'Military'].groupby(["Decade"])["Fatalities_Total"].sum())
ax[0].plot(df[df.Operator_vs_Military == 'Military'].groupby(["Decade"])["Aboard_Total"].count())
pass

# %%
def to_plot_chart(x):
    fig, ax = plt.subplots(2,1)
    ax[1].plot(df[df.Operator_vs_Military == x].groupby(["Decade"])["Fatalities_Total"].sum())
    ax[0].plot(df[df.Operator_vs_Military == x].groupby(["Decade"])["Aboard_Total"].count())

# %%
to_plot_chart('United Air Lines')

# %%
to_plot_chart('United Air Lines')

# %%
to_plot_chart('Air France')

# %%
to_plot_chart('Deutsche Lufthansa')

# %%
df[(df.Operator == 'Deutsche Lufthansa')]
# Out:
#       Decade       Date  Time                        Location  \
# 586     1940 1944-01-15  1345             Belgrad, Yugoslavia
# 590     1940 1944-02-21  1710                  Eubeoa, Greece
# 593     1940 1944-04-17   NaN             Belgrad, Yugoslavia
# 594     1940 1944-04-21   NaN            Frederikstad, Norway
# 616     1940 1944-09-02   NaN             Belgrad, Yugoslavia
# ...      ...        ...   ...                             ...
# 3228    1920 1928-09-06   NaN             Heroldbach, Germany
# 3239    1920 1928-12-11   NaN             Letzlingen, Germany
# 3429    1920 1929-08-24   NaN                    Elm, Germany
# 3442    1920 1929-11-06  1010  Near Godstone, Surrey, England
# 3447    1920 1929-12-19   NaN            Near Berlin, Germany
#
#                 Operator Flight_Num  \
# 586   Deutsche Lufthansa        NaN
# 590   Deutsche Lufthansa        NaN
# 593   Deutsche Lufthansa        NaN
# 594   Deutsche Lufthansa        NaN
# 616   Deutsche Lufthansa        NaN
# ...                  ...        ...
# 3228  Deutsche Lufthansa        NaN
# 3239  Deutsche Lufthansa        NaN
# 3429  Deutsche Lufthansa        NaN
# 3442  Deutsche Lufthansa        NaN
# 3447  Deutsche Lufthansa        NaN
#
#                                                   Route           Ac_Type  \
# 586                             Thessaloniki - Belgrade  Junkers JU-52/3m
# 590                                                 NaN  Junkers JU-52/3m
# 593   Vienna - Belgrade - Sofia - Thessaloniki - Athens  Junkers JU-52/3m
# 594                                   Copenhagen - Oslo      Douglas DC-3
# 616                  Athens - Sofia - Belgrade - Vienna   Junkers JU52/3m
# ...                                                 ...               ...
# 3228                                                NaN     Fokker FG III
# 3239                                  Cologne -  Berlin      Junkers G-31
# 3429                                 Frankfurt - Berlin      Fokker FG II
# 3442                       Croyden - Amsterdam - Berlin      Junkers G-24
# 3447                                 Marseille - Berlin          Arado V1
#
#      Registration   Cn_Ln  ...                                  Fatalities  \
# 586        D-ADQW  640610  ...    {'total': 5, 'passengers': 3, 'crew': 2}
# 590        D-ABAS    6561  ...  {'total': 16, 'passengers': 13, 'crew': 3}
# 593        D-AOCA  640996  ...    {'total': 5, 'passengers': 4, 'crew': 1}
# 594        D-AAIG    2095  ...    {'total': 9, 'passengers': 6, 'crew': 3}
# 616        D-AUAW  641039  ...    {'total': 5, 'passengers': 2, 'crew': 3}
# ...           ...     ...  ...                                         ...
# 3228        D-180    1531  ...    {'total': 3, 'passengers': 2, 'crew': 1}
# 3239       D-1473    3005  ...    {'total': 3, 'passengers': 0, 'crew': 3}
# 3429        D-757    1571  ...    {'total': 4, 'passengers': 3, 'crew': 1}
# 3442        D-903     911  ...    {'total': 7, 'passengers': 3, 'crew': 4}
# 3447       D-1594      47  ...    {'total': 2, 'passengers': 0, 'crew': 2}
#
#      Ground                                            Summary Aboard_Total  \
# 586     0.0  While approaching to land the aircraft was too...            5
# 590     0.0  After radioing they were returning , the plane...           16
# 593     0.0                      Shot down by allied fighters.            7
# 594     0.0  Crashed  50 miles from its destination after a...           20
# 616     0.0                      Shot down by allied fighters.            5
# ...     ...                                                ...          ...
# 3228    0.0                     Crashed due to engine failure.            3
# 3239    0.0  After a fuel line broke in flight, the pilot w...            4
# 3429    0.0  The aorcraft hit a hill in fog and poor visibi...            5
# 3442    0.0  After the plane's antenna wire struck the grou...            8
# 3447    0.0  In fog, the pilot lost his bearing in fog and ...            3
#
#       Fatalities_Total  Operator_vs_Military  \
# 586                  5    Deutsche Lufthansa
# 590                 16    Deutsche Lufthansa
# 593                  5    Deutsche Lufthansa
# 594                  9    Deutsche Lufthansa
# 616                  5    Deutsche Lufthansa
# ...                ...                   ...
# 3228                 3    Deutsche Lufthansa
# 3239                 3    Deutsche Lufthansa
# 3429                 4    Deutsche Lufthansa
# 3442                 7    Deutsche Lufthansa
# 3447                 2    Deutsche Lufthansa
#
#                                        Country_location Code  \
# 586   {'place_id': 86435550, 'licence': 'Data © Open...  SRB
# 590   {'place_id': 80394471, 'licence': 'Data © Open...  GRC
# 593   {'place_id': 86435550, 'licence': 'Data © Open...  SRB
# 594   {'place_id': 175638009, 'licence': 'Data © Ope...  NOR
# 616   {'place_id': 86435550, 'licence': 'Data © Open...  SRB
# ...                                                 ...  ...
# 3228  {'place_id': 150810207, 'licence': 'Data © Ope...  DEU
# 3239  {'place_id': 158856880, 'licence': 'Data © Ope...  DEU
# 3429  {'place_id': 158768968, 'licence': 'Data © Ope...  DEU
# 3442  {'place_id': 270463650, 'licence': 'Data © Ope...  GBR
# 3447  {'place_id': 150810207, 'licence': 'Data © Ope...  DEU
#
#                 Country_Geopy Month_Year
# 586    Central Serbia, Serbia   Jan 1944
# 590                    Greece   Feb 1944
# 593    Central Serbia, Serbia   Apr 1944
# 594             Viken, Norway   Apr 1944
# 616    Central Serbia, Serbia   Sep 1944
# ...                       ...        ...
# 3228                  Germany   Sep 1928
# 3239   Saxony-Anhalt, Germany   Dec 1928
# 3429    Lower Saxony, Germany   Aug 1929
# 3442  England, United Kingdom   Nov 1929
# 3447                  Germany   Dec 1929
#
# [62 rows x 21 columns]

# %%
df[(df.Operator == 'United Air Lines') & (df.Decade > 1990)]
# Out:
#       Decade       Date  Time                   Location          Operator  \
# 2739    2000 2001-09-11  0903    New York City, New York  United Air Lines
# 2740    2000 2001-09-11  1003  Shanksville, Pennsylvania  United Air Lines
#
#      Flight_Num                   Route           Ac_Type Registration  \
# 2739        175    Boston - Los Angeles  Boeing B-767-222       N612UA
# 2740         93  Newark - San Francisco  Boeing B-757-222       N591UA
#
#           Cn_Ln  ...                                  Fatalities  Ground  \
# 2739   21873/41  ...  {'total': 65, 'passengers': 56, 'crew': 9}  2750.0
# 2740  28142/718  ...  {'total': 44, 'passengers': 37, 'crew': 7}     0.0
#
#                                                 Summary Aboard_Total  \
# 2739  The aircraft was hijacked shortly after it lef...           65
# 2740  The aircraft was hijacked after taking off fro...           44
#
#       Fatalities_Total  Operator_vs_Military  \
# 2739                65      United Air Lines
# 2740                44      United Air Lines
#
#                                        Country_location Code  \
# 2739  {'place_id': 371663561, 'licence': 'Data © Ope...  USA
# 2740  {'place_id': 6167425, 'licence': 'Data © OpenS...  USA
#
#                     Country_Geopy Month_Year
# 2739      New York, United States   Sep 2001
# 2740  Pennsylvania, United States   Sep 2001
#
# [2 rows x 21 columns]

# %%
df.Operator.value_counts()[:5]
# Out:
# Operator
# Aeroflot                     251
# Military - U.S. Air Force    141
# Air France                    73
# Deutsche Lufthansa            62
# United Air Lines              44
# Name: count, dtype: int64

# %% [markdown]
# For the two plains in 9/11 the ground was counted twice
# - We split the count into two 2750 / 2

# %%
print(df.iloc[2759].Ground / 2)
df.loc[2758, "Ground"] = 1375
df.loc[2759, "Ground"] = 1375
# Out:
# 0.0

# %% [markdown]
# Compare Data source with wiki to cross reference dates and fatalities

# %%
df[df.Date == "2001-09-11"]
# Out:
#       Decade       Date  Time                   Location           Operator  \
# 2737    2000 2001-09-11  0945       Arlington, Virginia.  American Airlines
# 2738    2000 2001-09-11  0847    New York City, New York  American Airlines
# 2739    2000 2001-09-11  0903    New York City, New York   United Air Lines
# 2740    2000 2001-09-11  1003  Shanksville, Pennsylvania   United Air Lines
#
#      Flight_Num                          Route           Ac_Type Registration  \
# 2737         77  Washington D.C. - Los Angeles  Boeing B-757-223       N644AA
# 2738         11           Boston - Los Angeles  Boeing 767-223ER       N334AA
# 2739        175           Boston - Los Angeles  Boeing B-767-222       N612UA
# 2740         93         Newark - San Francisco  Boeing B-757-222       N591UA
#
#           Cn_Ln  ...                                   Fatalities  Ground  \
# 2737  24602/365  ...   {'total': 64, 'passengers': 58, 'crew': 6}   125.0
# 2738  22332/169  ...  {'total': 92, 'passengers': 81, 'crew': 11}  2750.0
# 2739   21873/41  ...   {'total': 65, 'passengers': 56, 'crew': 9}  2750.0
# 2740  28142/718  ...   {'total': 44, 'passengers': 37, 'crew': 7}     0.0
#
#                                                 Summary Aboard_Total  \
# 2737  The aircraft was hijacked after taking off fro...           64
# 2738  The aircraft was hijacked shortly after it lef...           92
# 2739  The aircraft was hijacked shortly after it lef...           65
# 2740  The aircraft was hijacked after taking off fro...           44
#
#       Fatalities_Total  Operator_vs_Military  \
# 2737                64     American Airlines
# 2738                92     American Airlines
# 2739                65      United Air Lines
# 2740                44      United Air Lines
#
#                                        Country_location Code  \
# 2737  {'place_id': 4249947, 'licence': 'Data © OpenS...  USA
# 2738  {'place_id': 371663561, 'licence': 'Data © Ope...  USA
# 2739  {'place_id': 371663561, 'licence': 'Data © Ope...  USA
# 2740  {'place_id': 6167425, 'licence': 'Data © OpenS...  USA
#
#                     Country_Geopy Month_Year
# 2737      Virginia, United States   Sep 2001
# 2738      New York, United States   Sep 2001
# 2739      New York, United States   Sep 2001
# 2740  Pennsylvania, United States   Sep 2001
#
# [4 rows x 21 columns]

# %%
df[df.Date == "1977-03-27"]
# Out:
#       Decade       Date  Time                  Location  \
# 4616    1970 1977-03-27  1707  Tenerife, Canary Islands
#
#                               Operator Flight_Num  \
# 4616  Pan American World Airways / KLM  1736/4805
#
#                                               Route  \
# 4616  Tenerife - Las Palmas / Tenerife - Las Palmas
#
#                                    Ac_Type   Registration  \
# 4616  Boeing B-747-121 / Boeing B-747-206B  N736PA/PH-BUF
#
#                      Cn_Ln  ...  \
# 4616  19643/11 / 20400/157  ...
#
#                                          Fatalities Ground  \
# 4616  {'total': 583, 'passengers': 560, 'crew': 23}    0.0
#
#                                                 Summary Aboard_Total  \
# 4616  Both aircraft were diverted to Tenerife becaus...          644
#
#       Fatalities_Total              Operator_vs_Military  \
# 4616               583  Pan American World Airways / KLM
#
#                                        Country_location Code  \
# 4616  {'place_id': 288818787, 'licence': 'Data © Ope...  ESP
#
#               Country_Geopy Month_Year
# 4616  Canary Islands, Spain   Mar 1977
#
# [1 rows x 21 columns]

# %%
df.Date.value_counts()[df.Date.value_counts() > 1]
# Good to know that we can have more than one crash in a single day
# Out:
# Date
# 2001-09-11    4
# 1988-08-31    4
# 1944-06-06    3
# 1945-02-23    3
# 1971-07-30    3
#              ..
# 1968-12-26    2
# 1973-09-30    2
# 1984-10-11    2
# 1966-02-16    2
# 1988-10-19    2
# Name: count, Length: 398, dtype: int64
