# %% [markdown]
# ### Preliminary data cleaning:
# - Combine datasets into one
# - Clean data names
# - Make Aboard into dictionaries
# - Replace "?" with nan
# - add Decades column
# - Fix date time column
# - Define data types
# - Assumptions "?" == 0

# %%
import pandas as pd 
import numpy as np
import datetime as dt 
from functions.extraction_and_cleaning import read_bronze

# %%
df = read_bronze()
df.head(5)
# Out:
#                Date  Time                    Location  \
# 0  January 05, 1953  2139   Belfast, Northern Ireland
# 1  January 07, 1953  2055        Issaquah, Washington
# 2  January 07, 1953  0412           Fish Haven, Idaho
# 3  January 15, 1953  0448  25 nm off Agrigento, Italy
# 4  January 26, 1953  1144     Sinnai, Sardinia, Italy
#
#                     Operator Flight #                              Route  \
# 0   British European Airways        ?                 Northolt - Belfast
# 1          Flying Tiger Line      841  Seattle - Cheyenne - Fort Jackson
# 2   Associated Air Transport   1-6-6A            Boeing Field - Cheyenne
# 3  Military -Royal Air Force        -                                  ?
# 4       Linee Aeree Italiane        ?                    Cagliari - Rome
#
#                         AC\n        Type   Registration cn / ln  \
# 0                  Vickers Viking 610-1B         G-AJDL     262
# 1                    Douglas C-54B-10-DO         N86574   18350
# 2                           Curtiss C-46         N1648M   22395
# 3  Vickers Valetta Mk1 / Avero Lancaster  VX562 / TX270       ?
# 4                           Douglas DC-3         I-LAIL    4308
#
#                           Aboard                     Fatalities Ground  \
# 0   35   (passengers:31  crew:4)   27   (passengers:24  crew:3)      0
# 1     7   (passengers:3  crew:4)     7   (passengers:3  crew:4)      0
# 2   40   (passengers:37  crew:3)   40   (passengers:37  crew:3)      0
# 3  26   (passengers:16  crew:10)  26   (passengers:16  crew:10)      0
# 4   19   (passengers:15  crew:4)   19   (passengers:15  crew:4)      0
#
#                                              Summary
# 0  Crashed into approach lights while attempting ...
# 1  The plane struck a tree on a mountain ridge at...
# 2  The plane crashed into mountains while en rout...
# 3  Both aircraft crashed after a midair collision...
# 4  Crashed 10 miles east of Cagliari in the Sinna...

# %% [markdown]
# First lets fix the column names

# %%
new_names = []
for item in df.columns:
    item = item.lower()
    item = item.strip()
    item = item.replace("\n"," ")
    item = item.replace("/"," ")
    item = item.replace("#","num")
    item = item.split()
    item = "_".join(item)
    new_names.append(item.title())

# %%
df.columns = new_names

# %%
def clean_aboard(x):
    x = x.replace("(","").replace(")","").split()
    a, b, c = x[0], x[1].split(":")[-1], x[2].split(":")[-1]
    try: 
        return {"total":int(a),"passengers":int(b),"crew":int(c)}
    except:
        if a == "?":
            a = float("nan")
        else:
            a = int(a)
        if b == "?":
            b = float("nan")
        else: 
            b = int(b)
        if c == "?":
            c = float("nan")
        else: 
            c = int(c)
    return {"total":a,"passengers":b,"crew":c}

# %%
df.Aboard = df.Aboard.apply(clean_aboard)
df.Fatalities = df.Fatalities.apply(clean_aboard)
df.head(3)
# Out:
#                Date  Time                   Location  \
# 0  January 05, 1953  2139  Belfast, Northern Ireland
# 1  January 07, 1953  2055       Issaquah, Washington
# 2  January 07, 1953  0412          Fish Haven, Idaho
#
#                    Operator Flight_Num                              Route  \
# 0  British European Airways          ?                 Northolt - Belfast
# 1         Flying Tiger Line        841  Seattle - Cheyenne - Fort Jackson
# 2  Associated Air Transport     1-6-6A            Boeing Field - Cheyenne
#
#                  Ac_Type Registration  Cn_Ln  \
# 0  Vickers Viking 610-1B       G-AJDL    262
# 1    Douglas C-54B-10-DO       N86574  18350
# 2           Curtiss C-46       N1648M  22395
#
#                                        Aboard  \
# 0  {'total': 35, 'passengers': 31, 'crew': 4}
# 1    {'total': 7, 'passengers': 3, 'crew': 4}
# 2  {'total': 40, 'passengers': 37, 'crew': 3}
#
#                                    Fatalities Ground  \
# 0  {'total': 27, 'passengers': 24, 'crew': 3}      0
# 1    {'total': 7, 'passengers': 3, 'crew': 4}      0
# 2  {'total': 40, 'passengers': 37, 'crew': 3}      0
#
#                                              Summary
# 0  Crashed into approach lights while attempting ...
# 1  The plane struck a tree on a mountain ridge at...
# 2  The plane crashed into mountains while en rout...

# %%
# Example getting flights with total passengers  + crew greater than 500 
df[df.Aboard.apply(lambda x: x["total"] > 500)]
# Out:
#                  Date  Time                               Location  \
# 293   August 12, 1985  1856  Mt. Osutaka, near Ueno Village, Japan
# 3640    July 23, 1999  1125                           Tokyo, Japan
# 4639   March 27, 1977  1707               Tenerife, Canary Islands
#
#                               Operator Flight_Num  \
# 293                    Japan Air Lines        123
# 3640                All Nippon Airways         61
# 4639  Pan American World Airways / KLM  1736/4805
#
#                                               Route  \
# 293                                   Tokyo - Osaka
# 3640                  Tokyo, Japan - Chitose, Japan
# 4639  Tenerife - Las Palmas / Tenerife - Las Palmas
#
#                                    Ac_Type   Registration  \
# 293                      Boeing B-747-SR46         JA8119
# 3640                          Boeing B-747         JA8966
# 4639  Boeing B-747-121 / Boeing B-747-206B  N736PA/PH-BUF
#
#                      Cn_Ln                                         Aboard  \
# 293              20783/230  {'total': 524, 'passengers': 509, 'crew': 15}
# 3640            27442/1066  {'total': 517, 'passengers': 503, 'crew': 14}
# 4639  19643/11 / 20400/157  {'total': 644, 'passengers': 614, 'crew': 30}
#
#                                          Fatalities Ground  \
# 293   {'total': 520, 'passengers': 505, 'crew': 15}      0
# 3640       {'total': 1, 'passengers': 0, 'crew': 1}      0
# 4639  {'total': 583, 'passengers': 560, 'crew': 23}      0
#
#                                                 Summary
# 293   The aircraft suffered an aft pressure bulkhead...
# 3640  Two minutes after taking off from Haneda Airpo...
# 4639  Both aircraft were diverted to Tenerife becaus...

# %%
# df.Ground = df.Ground.astype("Int64")

# %%
df[df == "?"] = float("nan")
df["Date_2"] = pd.to_datetime(df.Date)
# df["Date_2"]= df.Date.apply(lambda x: x.dt.strftime('% B % d, % Y,'))
df.head(3)
# Out:
#                Date  Time                   Location  \
# 0  January 05, 1953  2139  Belfast, Northern Ireland
# 1  January 07, 1953  2055       Issaquah, Washington
# 2  January 07, 1953  0412          Fish Haven, Idaho
#
#                    Operator Flight_Num                              Route  \
# 0  British European Airways        NaN                 Northolt - Belfast
# 1         Flying Tiger Line        841  Seattle - Cheyenne - Fort Jackson
# 2  Associated Air Transport     1-6-6A            Boeing Field - Cheyenne
#
#                  Ac_Type Registration  Cn_Ln  \
# 0  Vickers Viking 610-1B       G-AJDL    262
# 1    Douglas C-54B-10-DO       N86574  18350
# 2           Curtiss C-46       N1648M  22395
#
#                                        Aboard  \
# 0  {'total': 35, 'passengers': 31, 'crew': 4}
# 1    {'total': 7, 'passengers': 3, 'crew': 4}
# 2  {'total': 40, 'passengers': 37, 'crew': 3}
#
#                                    Fatalities Ground  \
# 0  {'total': 27, 'passengers': 24, 'crew': 3}      0
# 1    {'total': 7, 'passengers': 3, 'crew': 4}      0
# 2  {'total': 40, 'passengers': 37, 'crew': 3}      0
#
#                                              Summary     Date_2
# 0  Crashed into approach lights while attempting ... 1953-01-05
# 1  The plane struck a tree on a mountain ridge at... 1953-01-07
# 2  The plane crashed into mountains while en rout... 1953-01-07

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5037 entries, 0 to 5036
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          5037 non-null   object
#  1   Time          3529 non-null   object
#  2   Location      5032 non-null   object
#  3   Operator      5026 non-null   object
#  4   Flight_Num    1341 non-null   object
#  5   Route         4273 non-null   object
#  6   Ac_Type       5022 non-null   object
#  7   Registration  4761 non-null   object
#  8   Cn_Ln         4366 non-null   object
#  9   Aboard        5037 non-null   object
#  10  Fatalities    5037 non-null   object
#  11  Ground        4993 non-null   object
#  12  Summary       4978 non-null   object
#  13  Date_2        5037 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), object(13)
# memory usage: 551.1+ KB

# %%
df["Decade"] = df.Date_2.dt.year // 10 * 10

# %%
df = df[['Decade', 'Date','Time', 'Location', 'Operator', 'Flight_Num', 'Route',
       'Ac_Type', 'Registration', 'Cn_Ln', 'Aboard', 'Fatalities', 'Ground',
       'Summary']]

# %%
df.head(5)
# Out:
#    Decade              Date  Time                    Location  \
# 0    1950  January 05, 1953  2139   Belfast, Northern Ireland
# 1    1950  January 07, 1953  2055        Issaquah, Washington
# 2    1950  January 07, 1953  0412           Fish Haven, Idaho
# 3    1950  January 15, 1953  0448  25 nm off Agrigento, Italy
# 4    1950  January 26, 1953  1144     Sinnai, Sardinia, Italy
#
#                     Operator Flight_Num                              Route  \
# 0   British European Airways        NaN                 Northolt - Belfast
# 1          Flying Tiger Line        841  Seattle - Cheyenne - Fort Jackson
# 2   Associated Air Transport     1-6-6A            Boeing Field - Cheyenne
# 3  Military -Royal Air Force          -                                NaN
# 4       Linee Aeree Italiane        NaN                    Cagliari - Rome
#
#                                  Ac_Type   Registration  Cn_Ln  \
# 0                  Vickers Viking 610-1B         G-AJDL    262
# 1                    Douglas C-54B-10-DO         N86574  18350
# 2                           Curtiss C-46         N1648M  22395
# 3  Vickers Valetta Mk1 / Avero Lancaster  VX562 / TX270    NaN
# 4                           Douglas DC-3         I-LAIL   4308
#
#                                         Aboard  \
# 0   {'total': 35, 'passengers': 31, 'crew': 4}
# 1     {'total': 7, 'passengers': 3, 'crew': 4}
# 2   {'total': 40, 'passengers': 37, 'crew': 3}
# 3  {'total': 26, 'passengers': 16, 'crew': 10}
# 4   {'total': 19, 'passengers': 15, 'crew': 4}
#
#                                     Fatalities Ground  \
# 0   {'total': 27, 'passengers': 24, 'crew': 3}      0
# 1     {'total': 7, 'passengers': 3, 'crew': 4}      0
# 2   {'total': 40, 'passengers': 37, 'crew': 3}      0
# 3  {'total': 26, 'passengers': 16, 'crew': 10}      0
# 4   {'total': 19, 'passengers': 15, 'crew': 4}      0
#
#                                              Summary
# 0  Crashed into approach lights while attempting ...
# 1  The plane struck a tree on a mountain ridge at...
# 2  The plane crashed into mountains while en rout...
# 3  Both aircraft crashed after a midair collision...
# 4  Crashed 10 miles east of Cagliari in the Sinna...

# %%
df[df.Aboard.apply(lambda x: isinstance(x['total'],float))]
# Out:
#       Decade                Date  Time  \
# 20      1950      April 10, 1953   NaN
# 400     1940      March 18, 1946   NaN
# 535     1950   December 22, 1952   NaN
# 635     1940   November 09, 1944   NaN
# 833     1990   February 20, 1992   NaN
# 950     1950    January 20, 1951   NaN
# 1616    1950      March 13, 1954   NaN
# 1710    1950       June 13, 1956   NaN
# 1765    1940    October 01, 1942   NaN
# 2073    1950      April 20, 1957   NaN
# 2084    1950       June 24, 1957   NaN
# 2274    1920  September 07, 1925   NaN
# 2471    1930   December 26, 1936   NaN
# 2545    1930     August 13, 1935   NaN
# 2637    1910       July 21, 1919  1655
# 2679    1930     August 10, 1934   NaN
# 4837    1980        May 09, 1989   NaN
#
#                                      Location  \
# 20               Near Anchieta Island, Brazil
# 400     Between Chungking and Shanghai, China
# 535                           Damascus, Syria
# 635                           Seljord, Norway
# 833   En route from Argentina  to  California
# 950                              Huilyo, Peru
# 1616             Dien Bien Phu, South Vietnam
# 1710                      Over North Carolina
# 1765                           Kunming, China
# 2073                            Jirkouk, Iraq
# 2084       Horn Island, Queensland, Australia
# 2274                             Toul, France
# 2471                           Nanking, China
# 2545                            Hangow, China
# 2637                        Chicago, Illinois
# 2679                            Ningbo, China
# 4837                      Near Tainjin, China
#
#                                  Operator Flight_Num  \
# 20                                   REAL        NaN
# 400   China National Aviation Corporation        NaN
# 535                            Syrian Air        NaN
# 635        Military - U.S. Army Air Corps        NaN
# 833                 Aerolineas Argentinas        386
# 950                        Military - TAM        NaN
# 1616                           Aigle Azur        NaN
# 1710                             Piedmont        NaN
# 1765  China National Aviation Corporation        NaN
# 2073                           Air France        NaN
# 2084                      Adastra Airways        NaN
# 2274                                CIDNA        NaN
# 2471  China National Aviation Corporation        NaN
# 2545  China National Aviation Corporation        NaN
# 2637   Wingfoot Air Express Goodyear Tire        NaN
# 2679  China National Aviation Corporation        NaN
# 4837                           Aero Asahi        NaN
#
#                                 Route                       Ac_Type  \
# 20                                NaN                  Doublas Dc-3
# 400               Chunking - Shanghai                           NaN
# 535                               NaN                  Douglas DC-3
# 635                               NaN                           NaN
# 833                               NaN                  Boeing B-747
# 950                               NaN                  Douglas DC-3
# 1616                              NaN                          C-46
# 1710                              NaN                  Douglas DC-3
# 1765                              NaN                  Douglas C-47
# 2073  Tehran, Iran - Istanbul, Turkey  Lockheed Super Constellation
# 2084                              NaN                      L-Hudson
# 2274                              NaN                       Spad 33
# 2471                              NaN                  Douglas DC-2
# 2545                              NaN                Sikorsky S-38B
# 2637                          Shuttle             FD Type Dirigible
# 2679                              NaN                Sikorsky S-38B
# 4837                              NaN                      Bell 412
#
#      Registration  Cn_Ln                                          Aboard  \
# 20            NaN    NaN  {'total': nan, 'passengers': nan, 'crew': nan}
# 400           139    NaN  {'total': nan, 'passengers': nan, 'crew': nan}
# 535           NaN    NaN  {'total': nan, 'passengers': nan, 'crew': nan}
# 635      42-52196    NaN  {'total': nan, 'passengers': nan, 'crew': nan}
# 833           NaN    NaN  {'total': nan, 'passengers': nan, 'crew': nan}
# 950           NaN    NaN  {'total': nan, 'passengers': nan, 'crew': nan}
# 1616          NaN    NaN  {'total': nan, 'passengers': nan, 'crew': nan}
# 1710          NaN    NaN  {'total': nan, 'passengers': nan, 'crew': nan}
# 1765           69    NaN  {'total': nan, 'passengers': nan, 'crew': nan}
# 2073       F-BGNE   4514  {'total': nan, 'passengers': nan, 'crew': nan}
# 2084          NaN    NaN  {'total': nan, 'passengers': nan, 'crew': nan}
# 2274          NaN    NaN  {'total': nan, 'passengers': nan, 'crew': nan}
# 2471      NC14269    NaN  {'total': nan, 'passengers': nan, 'crew': nan}
# 2545        NV40V    NaN  {'total': nan, 'passengers': nan, 'crew': nan}
# 2637          NaN    NaN  {'total': nan, 'passengers': nan, 'crew': nan}
# 2679          NaN    NaN  {'total': nan, 'passengers': nan, 'crew': nan}
# 4837       JA9596  33070  {'total': nan, 'passengers': nan, 'crew': nan}
#
#                                           Fatalities Ground  \
# 20     {'total': 26, 'passengers': nan, 'crew': nan}    NaN
# 400   {'total': nan, 'passengers': nan, 'crew': nan}    NaN
# 535     {'total': 9, 'passengers': nan, 'crew': nan}    NaN
# 635   {'total': nan, 'passengers': nan, 'crew': nan}    NaN
# 833     {'total': 1, 'passengers': nan, 'crew': nan}      0
# 950    {'total': 16, 'passengers': nan, 'crew': nan}    NaN
# 1616  {'total': nan, 'passengers': nan, 'crew': nan}    NaN
# 1710      {'total': 1, 'passengers': 1, 'crew': nan}      0
# 1765  {'total': nan, 'passengers': nan, 'crew': nan}    NaN
# 2073        {'total': 1, 'passengers': 1, 'crew': 0}      0
# 2084    {'total': 6, 'passengers': nan, 'crew': nan}    NaN
# 2274  {'total': nan, 'passengers': nan, 'crew': nan}    NaN
# 2471  {'total': nan, 'passengers': nan, 'crew': nan}    NaN
# 2545  {'total': nan, 'passengers': nan, 'crew': nan}    NaN
# 2637        {'total': 3, 'passengers': 2, 'crew': 1}     10
# 2679  {'total': nan, 'passengers': nan, 'crew': nan}    NaN
# 4837   {'total': 10, 'passengers': nan, 'crew': nan}      0
#
#                                                 Summary
# 20                                                  NaN
# 400    Disappeared while en route. Plane never located.
# 535                                                 NaN
# 635                                                 NaN
# 833         A passenger died of cholera while en route.
# 950                                                 NaN
# 1616                                         Shot down.
# 1710  A passenger fell to his death after the door o...
# 1765  Crashed while attempting to land after losing ...
# 2073  Explosive decompression. A passenger was sucke...
# 2084                               Crashed on approach.
# 2274                                                NaN
# 2471                                                NaN
# 2545                              Destoryed in a storm.
# 2637  The dirigible, cruising at 1,200 ft. caught fi...
# 2679                                                NaN
# 4837                                                NaN

# %%
# def fix_time_avoid_na(x):
#     if x == np.nan:
#         return x 
#     else:
#          x = str(x)
#          return x[:2] + ":" + x[2:]

# %%
df.to_json('data/silver/1920_2024.json')
