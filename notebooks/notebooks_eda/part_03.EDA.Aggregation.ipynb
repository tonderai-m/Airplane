# %% [markdown]
# ### Exploring fatalities and crashes across time
# - Objective is to find operators with the highest number of crashes
# - Select top 5 and observe across decade

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv("data/bad_data/unknown_country_location.csv")

# %%
df
# Out:
#     Unnamed: 0  Decade        Date     Time  \
# 0           37    1950  1953-06-16      NaN
# 1           40    1950  1953-07-12     0841
# 2           45    1950  1953-08-05      NaN
# 3          112    1940  1947-06-21      NaN
# 4          113    1940  1947-07-01      NaN
# ..         ...     ...         ...      ...
# 92        4455    1940  1949-01-17  c 13:40
# 93        4473    1940  1949-05-07    16:00
# 94        4570    1960  1961-01-22     0304
# 95        4653    1970  1977-06-21     2230
# 96        4871    1980  1989-09-21      NaN
#
#                                             Location  \
# 0                Mount Phou-Lassy, French Indo-China
# 1       Pacific Ocean, 325 miles east of Wake Island
# 2                                    Off Irish coast
# 3                     Black Sea, Gulf of Karkinitsky
# 4                       Near Eaeka, French Cameroons
# ..                                               ...
# 92                       Atlantic Ocean, off Bermuda
# 93  Sibuyan Sea, off the Philippine island of Elalat
# 94                   Midway Island Naval Air Station
# 95                                   Off Wake Island
# 96                 Centeral Afghanistan\nAfghanistan
#
#                                   Operator Flight_Num  \
# 0                               Aigle Azur        NaN
# 1                     Transocean Air Lines        512
# 2                Military - U.S. Air Force        NaN
# 3                                 Aeroflot        NaN
# 4                               Air France        NaN
# ..                                     ...        ...
# 92          British South American Airways        NaN
# 93                    Philippine Air Lines        NaN
# 94                    Military - U.S. Navy        NaN
# 95                    Military - U.S. Navy        NaN
# 96  Military - Afghan Republican Air Force        NaN
#
#                                Route                            Ac_Type  \
# 0                 Vientiane - Saigon                       Douglas DC-3
# 1   Wake Island - Honolulu - Oakland                      Douglas DC-6A
# 2                Travis - Lakenheath                       Convair B-36
# 3                                NaN                               Li-2
# 4          Bangu i- Yaoundé - Douala                   Junkers JU-52/3m
# ..                               ...                                ...
# 92                Bermuda - Kingston                  Avro 688 Tudor 4B
# 93                     Daet - Manila                       Douglas DC-3
# 94                            Survey  Lockheed WV-2 Super Constellation
# 95                        Wake-Agana                   Lockheed EC-130Q
# 96                               NaN              Mil Mi-8 (helicopter)
#
#    Registration        Cn_Ln                                           Aboard  \
# 0        F-BEST        19100       {'total': 34, 'passengers': 31, 'crew': 3}
# 1        N90806    42901/153       {'total': 58, 'passengers': 50, 'crew': 8}
# 2       52-1369          303       {'total': 23, 'passengers': 0, 'crew': 23}
# 3    CCCP-L4138          NaN       {'total': 29, 'passengers': 25, 'crew': 4}
# 4        F-BALF          091       {'total': 13, 'passengers': 10, 'crew': 3}
# ..          ...          ...                                              ...
# 92       G-AGRE         1253       {'total': 20, 'passengers': 13, 'crew': 7}
# 93      PI-C-98  16743/33491       {'total': 13, 'passengers': 10, 'crew': 3}
# 94     BU143193         4467       {'total': 22, 'passengers': 0, 'crew': 22}
# 95       156176         4280       {'total': 16, 'passengers': 0, 'crew': 16}
# 96          NaN          NaN  {'total': 26, 'passengers': None, 'crew': None}
#
#                                          Fatalities  Ground  \
# 0        {'total': 34, 'passengers': 31, 'crew': 3}     0.0
# 1        {'total': 58, 'passengers': 50, 'crew': 8}     0.0
# 2        {'total': 19, 'passengers': 0, 'crew': 19}     0.0
# 3          {'total': 8, 'passengers': 6, 'crew': 2}     0.0
# 4        {'total': 13, 'passengers': 10, 'crew': 3}     0.0
# ..                                              ...     ...
# 92       {'total': 20, 'passengers': 13, 'crew': 7}     0.0
# 93       {'total': 13, 'passengers': 10, 'crew': 3}     0.0
# 94         {'total': 6, 'passengers': 0, 'crew': 6}     3.0
# 95       {'total': 16, 'passengers': 0, 'crew': 16}     0.0
# 96  {'total': 26, 'passengers': None, 'crew': None}     0.0
#
#                                               Summary  Aboard_Total  \
# 0   Crashed after on-board fire.  Possibly shot down.            34
# 1   Lost at sea while en route from Wake Island to...            58
# 2   Crashed into the Atlantic Ocean after two of i...            23
# 3   The plane ditched in the Black Sea. Engine fai...            29
# 4   Crashed into the slope of a mountain while en ...            13
# ..                                                ...           ...
# 92  Lost at sea on a flight from Bermuda to Kingst...            20
# 93  The plane was on a flight from Daet, Camarines...            13
# 94  While returning from an aborted barrier missio...            22
# 95  Crashed into the Pacific Ocean and exploded mo...            16
# 96                                                NaN            26
#
#     Fatalities_Total            Operator_vs_Military  \
# 0                 34                      Aigle Azur
# 1                 58            Transocean Air Lines
# 2                 19                        Military
# 3                  8                        Aeroflot
# 4                 13                      Air France
# ..               ...                             ...
# 92                20  British South American Airways
# 93                13            Philippine Air Lines
# 94                 6                        Military
# 95                16                        Military
# 96                26                        Military
#
#                                     Country_location
# 0                Mount Phou-Lassy, French Indo-China
# 1       Pacific Ocean, 325 miles east of Wake Island
# 2                                    Off Irish coast
# 3                     Black Sea, Gulf of Karkinitsky
# 4                       Near Eaeka, French Cameroons
# ..                                               ...
# 92                       Atlantic Ocean, off Bermuda
# 93  Sibuyan Sea, off the Philippine island of Elalat
# 94                   Midway Island Naval Air Station
# 95                                   Off Wake Island
# 96                 Centeral Afghanistan\nAfghanistan
#
# [97 rows x 19 columns]

# %%
df = pd.read_csv("data/ready_for_plotting/data_plot_map.csv")
df.Date = pd.to_datetime(df.Date)

# %%
df.columns = ['Decade', 'Date', 'Time', 'Location', 'Operator', 'Flight_Num', 'Route',
       'Ac_Type', 'Registration', 'Cn_Ln', 'Aboard', 'Fatalities', 'Ground',
       'Summary', 'Aboard_Total', 'Fatalities_Total', 'Operator_Military_Compiled',
       'Country_location', 'Code', 'Country_Geopy']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5013 entries, 0 to 5012
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Decade                      5013 non-null   int64
#  1   Date                        5013 non-null   datetime64[ns]
#  2   Time                        3526 non-null   object
#  3   Location                    5013 non-null   object
#  4   Operator                    5002 non-null   object
#  5   Flight_Num                  1339 non-null   object
#  6   Route                       4267 non-null   object
#  7   Ac_Type                     5000 non-null   object
#  8   Registration                4750 non-null   object
#  9   Cn_Ln                       4361 non-null   object
#  10  Aboard                      5013 non-null   object
#  11  Fatalities                  5013 non-null   object
#  12  Ground                      4982 non-null   float64
#  13  Summary                     4962 non-null   object
#  14  Aboard_Total                5013 non-null   int64
#  15  Fatalities_Total            5013 non-null   int64
#  16  Operator_Military_Compiled  5002 non-null   object
#  17  Country_location            5013 non-null   object
#  18  Code                        4926 non-null   object
#  19  Country_Geopy               5013 non-null   object
# dtypes: datetime64[ns](1), float64(1), int64(3), object(15)
# memory usage: 783.4+ KB

# %%
df["country"] = df.Country_Geopy.apply(lambda x : x.split(",")[-1].strip())

# %%
group_by_county = df.groupby("country")

# %%
df
# Out:
#       Decade       Date   Time                         Location  \
# 0       1950 1953-01-05   2139        Belfast, Northern Ireland
# 1       1950 1953-01-07   2055             Issaquah, Washington
# 2       1950 1953-01-07   0412                Fish Haven, Idaho
# 3       1950 1953-01-15   0448       25 nm off Agrigento, Italy
# 4       1950 1953-01-26   1144          Sinnai, Sardinia, Italy
# ...      ...        ...    ...                              ...
# 5008    1970 1976-12-17   1940                  Ust-Kut, Russia
# 5009    1970 1976-12-17  21:30                       Kiev, USSR
# 5010    1970 1976-12-18   1656  Nnear Yuzhno-Sakhalinsk, Russia
# 5011    1970 1976-12-25   0345           Near Bangkok, Thailand
# 5012    1970 1976-12-31    NaN              Near Trujillo, Peru
#
#                        Operator Flight_Num  \
# 0      British European Airways        NaN
# 1             Flying Tiger Line        841
# 2      Associated Air Transport     1-6-6A
# 3     Military -Royal Air Force          -
# 4          Linee Aeree Italiane        NaN
# ...                         ...        ...
# 5008                   Aeroflot        NaN
# 5009                   Aeroflot       H-36
# 5010                   Aeroflot        NaN
# 5011                   EgyptAir        864
# 5012                    Faucett        NaN
#
#                                              Route  \
# 0                               Northolt - Belfast
# 1                Seattle - Cheyenne - Fort Jackson
# 2                          Boeing Field - Cheyenne
# 3                                              NaN
# 4                                  Cagliari - Rome
# ...                                            ...
# 5008                             Ust-Kut - Kirensk
# 5009                             Chernivtsi - Kiev
# 5010  Petropavlovsk-Kamchatsky - Yuzhno-Sakhalinsk
# 5011                               Cairo - Bangkok
# 5012                           Trujillo - Tarapoto
#
#                                     Ac_Type   Registration      Cn_Ln  ...  \
# 0                     Vickers Viking 610-1B         G-AJDL        262  ...
# 1                       Douglas C-54B-10-DO         N86574      18350  ...
# 2                              Curtiss C-46         N1648M      22395  ...
# 3     Vickers Valetta Mk1 / Avero Lancaster  VX562 / TX270        NaN  ...
# 4                              Douglas DC-3         I-LAIL       4308  ...
# ...                                     ...            ...        ...  ...
# 5008                            Yakovlev 40     CCCP-88208    9631349  ...
# 5009                        Antonov AN-24RV     CCCP-46672   47309604  ...
# 5010                        Ilyushin IL-14M     CCCP-61752  147001247  ...
# 5011                      Boeing B-707-366C         SU-AXA      20763  ...
# 5012                     Douglas C-54A-1-DO       OB-R-247       7462  ...
#
#                                        Fatalities Ground  \
# 0      {'total': 27, 'passengers': 24, 'crew': 3}    0.0
# 1        {'total': 7, 'passengers': 3, 'crew': 4}    0.0
# 2      {'total': 40, 'passengers': 37, 'crew': 3}    0.0
# 3     {'total': 26, 'passengers': 16, 'crew': 10}    0.0
# 4      {'total': 19, 'passengers': 15, 'crew': 4}    0.0
# ...                                           ...    ...
# 5008     {'total': 7, 'passengers': 4, 'crew': 3}    0.0
# 5009   {'total': 48, 'passengers': 44, 'crew': 4}    0.0
# 5010     {'total': 8, 'passengers': 3, 'crew': 5}    0.0
# 5011   {'total': 53, 'passengers': 44, 'crew': 9}   19.0
# 5012   {'total': 19, 'passengers': 14, 'crew': 5}    0.0
#
#                                                 Summary Aboard_Total  \
# 0     Crashed into approach lights while attempting ...           35
# 1     The plane struck a tree on a mountain ridge at...            7
# 2     The plane crashed into mountains while en rout...           40
# 3     Both aircraft crashed after a midair collision...           26
# 4     Crashed 10 miles east of Cagliari in the Sinna...           19
# ...                                                 ...          ...
# 5008  The cargo plane crashed into trees on takeoff....            7
# 5009  In heavy fog  the crew continued their descend...           55
# 5010  The survey fllight deviated from the approach ...            8
# 5011  The aircraft crashed into an industrial area d...           53
# 5012  Struck the slope of Mt Pintado located 25 km n...           19
#
#       Fatalities_Total  Operator_Military_Compiled  \
# 0                   27    British European Airways
# 1                    7           Flying Tiger Line
# 2                   40    Associated Air Transport
# 3                   26                    Military
# 4                   19        Linee Aeree Italiane
# ...                ...                         ...
# 5008                 7                    Aeroflot
# 5009                48                    Aeroflot
# 5010                 8                    Aeroflot
# 5011                53                    EgyptAir
# 5012                19                     Faucett
#
#                                        Country_location Code  \
# 0     {'place_id': 372303099, 'licence': 'Data © Ope...  GBR
# 1     {'place_id': 383391892, 'licence': 'Data © Ope...  USA
# 2     {'place_id': 315821592, 'licence': 'Data © Ope...  USA
# 3     {'place_id': 100666283, 'licence': 'Data © Ope...  ITA
# 4     {'place_id': 78523394, 'licence': 'Data © Open...  ITA
# ...                                                 ...  ...
# 5008  {'place_id': 224774650, 'licence': 'Data © Ope...  RUS
# 5009  {'place_id': 202588741, 'licence': 'Data © Ope...  UKR
# 5010  {'place_id': 173174605, 'licence': 'Data © Ope...  RUS
# 5011  {'place_id': 253308938, 'licence': 'Data © Ope...  THA
# 5012  {'place_id': 35521972, 'licence': 'Data © Open...  PER
#
#                           Country_Geopy         country
# 0      Northern Ireland, United Kingdom  United Kingdom
# 1             Washington, United States   United States
# 2                  Idaho, United States   United States
# 3                                 Italy           Italy
# 4                       Sardinia, Italy           Italy
# ...                                 ...             ...
# 5008  Siberian Federal District, Russia          Russia
# 5009                      Kyiv, Ukraine         Ukraine
# 5010                             Russia          Russia
# 5011                           Thailand        Thailand
# 5012                               Peru            Peru
#
# [5013 rows x 21 columns]

# %%
agg_me = {'Country_Geopy':'count','Aboard_Total':'sum', 'Fatalities_Total':'sum','Ground':'sum'}
rename_me = {'Country_Geopy': 'Total_Crashes', 'Aboard_Total': 'Total_Aboard', 'Fatalities_Total': 'Fatalities_Plane', 'Ground': 'Fatalities_Ground'}

# %%
group_by_county.agg(agg_me).sort_values('Country_Geopy',ascending=False)[:20].rename(columns=rename_me)
# Out:
#                                   Total_Crashes  Total_Aboard  \
# country
# United States                              1087         26713
# Russia                                      260         10963
# Brazil                                      179          4576
# Canada                                      160          3211
# Colombia                                    157          3524
# United Kingdom                              144          3593
# France                                      138          3787
# Germany                                     129          3408
# India                                       108          3695
# China                                       103          4173
# Indonesia                                   103          3892
# Mexico                                       87          1668
# Italy                                        87          2438
# Philippines                                  74          2675
# Australia                                    71           859
# Tajikistan                                   67          3589
# Spain                                        67          3374
# Venezuela                                    56          1450
# Peru                                         54          1972
# Democratic Republic of the Congo             52          1266
#
#                                   Fatalities_Plane  Fatalities_Ground
# country
# United States                                15663             5929.0
# Russia                                        8563               90.0
# Brazil                                        3205               65.0
# Canada                                        2192               15.0
# Colombia                                      3072               38.0
# United Kingdom                                2614              121.0
# France                                        3077               32.0
# Germany                                       2847               66.0
# India                                         2890              195.0
# China                                         2665               55.0
# Indonesia                                     2722               74.0
# Mexico                                        1269               63.0
# Italy                                         1859               26.0
# Philippines                                   1321               32.0
# Australia                                      741                0.0
# Tajikistan                                    3039                0.0
# Spain                                         2482                2.0
# Venezuela                                     1238               71.0
# Peru                                          1530                6.0
# Democratic Republic of the Congo               922              330.0

# %%
df[df.Date == "2001-09-11"]
# Out:
#       Decade       Date  Time                   Location           Operator  \
# 2737    2000 2001-09-11  0945       Arlington, Virginia.  American Airlines
# 2738    2000 2001-09-11  0847    New York City, New York  American Airlines
# 2739    2000 2001-09-11  0903    New York City, New York   United Air Lines
# 2740    2000 2001-09-11  1003  Shanksville, Pennsylvania   United Air Lines
#
#      Flight_Num                          Route           Ac_Type Registration  \
# 2737         77  Washington D.C. - Los Angeles  Boeing B-757-223       N644AA
# 2738         11           Boston - Los Angeles  Boeing 767-223ER       N334AA
# 2739        175           Boston - Los Angeles  Boeing B-767-222       N612UA
# 2740         93         Newark - San Francisco  Boeing B-757-222       N591UA
#
#           Cn_Ln  ...                                   Fatalities  Ground  \
# 2737  24602/365  ...   {'total': 64, 'passengers': 58, 'crew': 6}   125.0
# 2738  22332/169  ...  {'total': 92, 'passengers': 81, 'crew': 11}  2750.0
# 2739   21873/41  ...   {'total': 65, 'passengers': 56, 'crew': 9}  2750.0
# 2740  28142/718  ...   {'total': 44, 'passengers': 37, 'crew': 7}     0.0
#
#                                                 Summary Aboard_Total  \
# 2737  The aircraft was hijacked after taking off fro...           64
# 2738  The aircraft was hijacked shortly after it lef...           92
# 2739  The aircraft was hijacked shortly after it lef...           65
# 2740  The aircraft was hijacked after taking off fro...           44
#
#       Fatalities_Total  Operator_Military_Compiled  \
# 2737                64           American Airlines
# 2738                92           American Airlines
# 2739                65            United Air Lines
# 2740                44            United Air Lines
#
#                                        Country_location Code  \
# 2737  {'place_id': 4249947, 'licence': 'Data © OpenS...  USA
# 2738  {'place_id': 371663561, 'licence': 'Data © Ope...  USA
# 2739  {'place_id': 371663561, 'licence': 'Data © Ope...  USA
# 2740  {'place_id': 6167425, 'licence': 'Data © OpenS...  USA
#
#                     Country_Geopy        country
# 2737      Virginia, United States  United States
# 2738      New York, United States  United States
# 2739      New York, United States  United States
# 2740  Pennsylvania, United States  United States
#
# [4 rows x 21 columns]

# %%
df.loc[2738, "Ground"] = 1375
df.loc[2739, "Ground"] = 1375

# %%
df[:5]
# Out:
#    Decade       Date  Time                    Location  \
# 0    1950 1953-01-05  2139   Belfast, Northern Ireland
# 1    1950 1953-01-07  2055        Issaquah, Washington
# 2    1950 1953-01-07  0412           Fish Haven, Idaho
# 3    1950 1953-01-15  0448  25 nm off Agrigento, Italy
# 4    1950 1953-01-26  1144     Sinnai, Sardinia, Italy
#
#                     Operator Flight_Num                              Route  \
# 0   British European Airways        NaN                 Northolt - Belfast
# 1          Flying Tiger Line        841  Seattle - Cheyenne - Fort Jackson
# 2   Associated Air Transport     1-6-6A            Boeing Field - Cheyenne
# 3  Military -Royal Air Force          -                                NaN
# 4       Linee Aeree Italiane        NaN                    Cagliari - Rome
#
#                                  Ac_Type   Registration  Cn_Ln  ...  \
# 0                  Vickers Viking 610-1B         G-AJDL    262  ...
# 1                    Douglas C-54B-10-DO         N86574  18350  ...
# 2                           Curtiss C-46         N1648M  22395  ...
# 3  Vickers Valetta Mk1 / Avero Lancaster  VX562 / TX270    NaN  ...
# 4                           Douglas DC-3         I-LAIL   4308  ...
#
#                                     Fatalities Ground  \
# 0   {'total': 27, 'passengers': 24, 'crew': 3}    0.0
# 1     {'total': 7, 'passengers': 3, 'crew': 4}    0.0
# 2   {'total': 40, 'passengers': 37, 'crew': 3}    0.0
# 3  {'total': 26, 'passengers': 16, 'crew': 10}    0.0
# 4   {'total': 19, 'passengers': 15, 'crew': 4}    0.0
#
#                                              Summary Aboard_Total  \
# 0  Crashed into approach lights while attempting ...           35
# 1  The plane struck a tree on a mountain ridge at...            7
# 2  The plane crashed into mountains while en rout...           40
# 3  Both aircraft crashed after a midair collision...           26
# 4  Crashed 10 miles east of Cagliari in the Sinna...           19
#
#    Fatalities_Total  Operator_Military_Compiled  \
# 0                27    British European Airways
# 1                 7           Flying Tiger Line
# 2                40    Associated Air Transport
# 3                26                    Military
# 4                19        Linee Aeree Italiane
#
#                                     Country_location Code  \
# 0  {'place_id': 372303099, 'licence': 'Data © Ope...  GBR
# 1  {'place_id': 383391892, 'licence': 'Data © Ope...  USA
# 2  {'place_id': 315821592, 'licence': 'Data © Ope...  USA
# 3  {'place_id': 100666283, 'licence': 'Data © Ope...  ITA
# 4  {'place_id': 78523394, 'licence': 'Data © Open...  ITA
#
#                       Country_Geopy         country
# 0  Northern Ireland, United Kingdom  United Kingdom
# 1         Washington, United States   United States
# 2              Idaho, United States   United States
# 3                             Italy           Italy
# 4                   Sardinia, Italy           Italy
#
# [5 rows x 21 columns]

# %%
group_by_county.agg(agg_me).sort_values('Country_Geopy',ascending=False)[:20].rename(columns=rename_me)
# Out:
#                                   Total_Crashes  Total_Aboard  \
# country
# United States                              1087         26713
# Russia                                      260         10963
# Brazil                                      179          4576
# Canada                                      160          3211
# Colombia                                    157          3524
# United Kingdom                              144          3593
# France                                      138          3787
# Germany                                     129          3408
# India                                       108          3695
# China                                       103          4173
# Indonesia                                   103          3892
# Mexico                                       87          1668
# Italy                                        87          2438
# Philippines                                  74          2675
# Australia                                    71           859
# Tajikistan                                   67          3589
# Spain                                        67          3374
# Venezuela                                    56          1450
# Peru                                         54          1972
# Democratic Republic of the Congo             52          1266
#
#                                   Fatalities_Plane  Fatalities_Ground
# country
# United States                                15663             3179.0
# Russia                                        8563               90.0
# Brazil                                        3205               65.0
# Canada                                        2192               15.0
# Colombia                                      3072               38.0
# United Kingdom                                2614              121.0
# France                                        3077               32.0
# Germany                                       2847               66.0
# India                                         2890              195.0
# China                                         2665               55.0
# Indonesia                                     2722               74.0
# Mexico                                        1269               63.0
# Italy                                         1859               26.0
# Philippines                                   1321               32.0
# Australia                                      741                0.0
# Tajikistan                                    3039                0.0
# Spain                                         2482                2.0
# Venezuela                                     1238               71.0
# Peru                                          1530                6.0
# Democratic Republic of the Congo               922              330.0

# %%
dfUSA = df[df.Code == "USA"]

# %%
dfUSA["state"]= dfUSA.Country_Geopy.apply(lambda x:x.split(",")[0].strip())
# Out:
# /var/folders/sr/32z6khr97xs2g11w52pbkzww0000gn/T/ipykernel_14633/835723665.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfUSA["state"]= dfUSA.Country_Geopy.apply(lambda x:x.split(",")[0].strip())

# %%
dfUSA[dfUSA.Date == "2001-09-11"]
# Out:
#       Decade       Date  Time                   Location           Operator  \
# 2737    2000 2001-09-11  0945       Arlington, Virginia.  American Airlines
# 2738    2000 2001-09-11  0847    New York City, New York  American Airlines
# 2739    2000 2001-09-11  0903    New York City, New York   United Air Lines
# 2740    2000 2001-09-11  1003  Shanksville, Pennsylvania   United Air Lines
#
#      Flight_Num                          Route           Ac_Type Registration  \
# 2737         77  Washington D.C. - Los Angeles  Boeing B-757-223       N644AA
# 2738         11           Boston - Los Angeles  Boeing 767-223ER       N334AA
# 2739        175           Boston - Los Angeles  Boeing B-767-222       N612UA
# 2740         93         Newark - San Francisco  Boeing B-757-222       N591UA
#
#           Cn_Ln  ...  Ground  \
# 2737  24602/365  ...   125.0
# 2738  22332/169  ...  1375.0
# 2739   21873/41  ...  1375.0
# 2740  28142/718  ...     0.0
#
#                                                 Summary  Aboard_Total  \
# 2737  The aircraft was hijacked after taking off fro...            64
# 2738  The aircraft was hijacked shortly after it lef...            92
# 2739  The aircraft was hijacked shortly after it lef...            65
# 2740  The aircraft was hijacked after taking off fro...            44
#
#      Fatalities_Total  Operator_Military_Compiled  \
# 2737               64           American Airlines
# 2738               92           American Airlines
# 2739               65            United Air Lines
# 2740               44            United Air Lines
#
#                                        Country_location Code  \
# 2737  {'place_id': 4249947, 'licence': 'Data © OpenS...  USA
# 2738  {'place_id': 371663561, 'licence': 'Data © Ope...  USA
# 2739  {'place_id': 371663561, 'licence': 'Data © Ope...  USA
# 2740  {'place_id': 6167425, 'licence': 'Data © OpenS...  USA
#
#                     Country_Geopy        country         state
# 2737      Virginia, United States  United States      Virginia
# 2738      New York, United States  United States      New York
# 2739      New York, United States  United States      New York
# 2740  Pennsylvania, United States  United States  Pennsylvania
#
# [4 rows x 22 columns]

# %%
group_by_USA = dfUSA.groupby("state")

# %%
agg_me_state = {'state':'count','Aboard_Total':'sum','Fatalities_Total':'sum','Ground':'sum'}
rename_me_state = {'state': 'Total_Crashes', 'Aboard_Total': 'Total_Aboard', 'Fatalities_Total': 'Fatalities_Plane', 'Ground': 'Fatalities_Ground'}

# %%
group_by_USA.agg(agg_me_state).rename(columns=rename_me_state).sort_values("Total_Crashes",ascending=False)[:20]
# Out:
#                 Total_Crashes  Total_Aboard  Fatalities_Plane  \
# state
# California                124          3769              1673
# Alaska                    107          1678              1026
# New York                   59          3098              1623
# Texas                      50           942               635
# Ohio                       44           355               229
# New Jersey                 38           735               472
# Florida                    37          1255               607
# Illinois                   35          1089               665
# Pennsylvania               32           745               446
# Colorado                   30           736               308
# Washington                 26           744               419
# Missouri                   26           565               229
# Hawaii                     24          1017               236
# New Mexico                 22           442               157
# North Carolina             21           500               374
# Wyoming                    21           239               200
# Indiana                    21           322               302
# Maryland                   19           338               315
# Virginia                   19           668               570
# Nevada                     18           427               362
#
#                 Fatalities_Ground
# state
# California                   86.0
# Alaska                        0.0
# New York                   2778.0
# Texas                         1.0
# Ohio                          0.0
# New Jersey                   13.0
# Florida                       1.0
# Illinois                     14.0
# Pennsylvania                  2.0
# Colorado                      1.0
# Washington                   26.0
# Missouri                      0.0
# Hawaii                        0.0
# New Mexico                    0.0
# North Carolina                1.0
# Wyoming                       0.0
# Indiana                      22.0
# Maryland                      0.0
# Virginia                    125.0
# Nevada                       10.0

# %%
def change_usa(x):
    if isinstance(x,str) and "Military - U.S" in x:
        return "Military - U.S"
    else: return x

# %%
df["Operator_USA_Combined"] = df.Operator.apply(change_usa)

# %%
group_by_operator = df.groupby("Operator_USA_Combined")

# %%
df[:5]
# Out:
#    Decade       Date  Time                    Location  \
# 0    1950 1953-01-05  2139   Belfast, Northern Ireland
# 1    1950 1953-01-07  2055        Issaquah, Washington
# 2    1950 1953-01-07  0412           Fish Haven, Idaho
# 3    1950 1953-01-15  0448  25 nm off Agrigento, Italy
# 4    1950 1953-01-26  1144     Sinnai, Sardinia, Italy
#
#                     Operator Flight_Num                              Route  \
# 0   British European Airways        NaN                 Northolt - Belfast
# 1          Flying Tiger Line        841  Seattle - Cheyenne - Fort Jackson
# 2   Associated Air Transport     1-6-6A            Boeing Field - Cheyenne
# 3  Military -Royal Air Force          -                                NaN
# 4       Linee Aeree Italiane        NaN                    Cagliari - Rome
#
#                                  Ac_Type   Registration  Cn_Ln  ... Ground  \
# 0                  Vickers Viking 610-1B         G-AJDL    262  ...    0.0
# 1                    Douglas C-54B-10-DO         N86574  18350  ...    0.0
# 2                           Curtiss C-46         N1648M  22395  ...    0.0
# 3  Vickers Valetta Mk1 / Avero Lancaster  VX562 / TX270    NaN  ...    0.0
# 4                           Douglas DC-3         I-LAIL   4308  ...    0.0
#
#                                              Summary  Aboard_Total  \
# 0  Crashed into approach lights while attempting ...            35
# 1  The plane struck a tree on a mountain ridge at...             7
# 2  The plane crashed into mountains while en rout...            40
# 3  Both aircraft crashed after a midair collision...            26
# 4  Crashed 10 miles east of Cagliari in the Sinna...            19
#
#   Fatalities_Total  Operator_Military_Compiled  \
# 0               27    British European Airways
# 1                7           Flying Tiger Line
# 2               40    Associated Air Transport
# 3               26                    Military
# 4               19        Linee Aeree Italiane
#
#                                     Country_location Code  \
# 0  {'place_id': 372303099, 'licence': 'Data © Ope...  GBR
# 1  {'place_id': 383391892, 'licence': 'Data © Ope...  USA
# 2  {'place_id': 315821592, 'licence': 'Data © Ope...  USA
# 3  {'place_id': 100666283, 'licence': 'Data © Ope...  ITA
# 4  {'place_id': 78523394, 'licence': 'Data © Open...  ITA
#
#                       Country_Geopy         country      Operator_USA_Combined
# 0  Northern Ireland, United Kingdom  United Kingdom   British European Airways
# 1         Washington, United States   United States          Flying Tiger Line
# 2              Idaho, United States   United States   Associated Air Transport
# 3                             Italy           Italy  Military -Royal Air Force
# 4                   Sardinia, Italy           Italy       Linee Aeree Italiane
#
# [5 rows x 22 columns]

# %%
agg_me_operator = {'Operator':'count','Aboard_Total':'sum', 'Fatalities_Total':'sum','Ground':'sum'}
rename_me_operator = {'Operator': 'Total_Crashes', 'Aboard_Total': 'Total_Aboard', 'Fatalities_Total': 'Fatalities_Plane', 'Ground': 'Fatalities_Ground'}

# %%
plot_operator_bars_crashes = group_by_operator.agg(agg_me_operator).rename(columns=rename_me_operator).sort_values("Total_Crashes")[-10:]

# %%
plot_operator_bars_crashes
# Out:
#                                      Total_Crashes  Total_Aboard  \
# Operator_USA_Combined
# Indian Airlines                                 34          1451
# US Aerial Mail Service                          35            42
# China National Aviation Corporation             37           417
# American Airlines                               38          2200
# Pan American World Airways                      41          3097
# United Air Lines                                44          2461
# Deutsche Lufthansa                              62           499
# Air France                                      73          2978
# Aeroflot                                       251         11133
# Military - U.S                                 280          7824
#
#                                      Fatalities_Plane  Fatalities_Ground
# Operator_USA_Combined
# Indian Airlines                                   860                7.0
# US Aerial Mail Service                             39                0.0
# China National Aviation Corporation               331                0.0
# American Airlines                                1422             1514.0
# Pan American World Airways                       1303               20.0
# United Air Lines                                 1019             1378.0
# Deutsche Lufthansa                                383                0.0
# Air France                                       1797                8.0
# Aeroflot                                         8704               35.0
# Military - U.S                                   6738              328.0

# %%
def plot_by_operator(plot_operator_bars,label):


    x = np.arange(len(plot_operator_bars)) # the label locations
    width = 0.45 # the width of the bars
    fig, ax = plt.subplots()
    rects1 = ax.barh(x + width/2, plot_operator_bars.Fatalities_Plane, width, label="Fatalities", color="teal")
    rects2 = ax.barh(x - width/2, plot_operator_bars.Total_Crashes, width, label="Crashes",color="orchid")
    ax.set_xscale('log')
    ax.set_yticks(x+width/2)
    ax.set_yticklabels(plot_operator_bars.index)
    ax.set_xlabel("Count")
    ax.set_title(f"By {label}".title())
    ax.legend()

# %%
plot_by_operator(plot_operator_bars_crashes,"crashes")

# %%
rename_me_operator
# Out:
# {'Operator': 'Total_Crashes',
#  'Aboard_Total': 'Total_Aboard',
#  'Fatalities_Total': 'Fatalities_Plane',
#  'Ground': 'Fatalities_Ground'}

# %%
plot_operator_bars_fatalities = group_by_operator.agg(agg_me_operator).rename(columns=rename_me_operator).sort_values("Fatalities_Plane")[-10:]
plot_operator_bars_fatalities
# Out:
#                             Total_Crashes  Total_Aboard  Fatalities_Plane  \
# Operator_USA_Combined
# China Airlines (Taiwan)                14          1590               847
# Indian Airlines                        34          1451               860
# Turkish Airlines (THY)                 13           956               890
# AVIANCA                                24          1067               941
# United Air Lines                       44          2461              1019
# Pan American World Airways             41          3097              1303
# American Airlines                      38          2200              1422
# Air France                             73          2978              1797
# Military - U.S                        280          7824              6738
# Aeroflot                              251         11133              8704
#
#                             Fatalities_Ground
# Operator_USA_Combined
# China Airlines (Taiwan)                   7.0
# Indian Airlines                           7.0
# Turkish Airlines (THY)                    0.0
# AVIANCA                                   3.0
# United Air Lines                       1378.0
# Pan American World Airways               20.0
# American Airlines                      1514.0
# Air France                                8.0
# Military - U.S                          328.0
# Aeroflot                                 35.0

# %%
plot_by_operator(plot_operator_bars_fatalities,"Fatalities")

# %%
df[:5]
# Out:
#    Decade       Date  Time                    Location  \
# 0    1950 1953-01-05  2139   Belfast, Northern Ireland
# 1    1950 1953-01-07  2055        Issaquah, Washington
# 2    1950 1953-01-07  0412           Fish Haven, Idaho
# 3    1950 1953-01-15  0448  25 nm off Agrigento, Italy
# 4    1950 1953-01-26  1144     Sinnai, Sardinia, Italy
#
#                     Operator Flight_Num                              Route  \
# 0   British European Airways        NaN                 Northolt - Belfast
# 1          Flying Tiger Line        841  Seattle - Cheyenne - Fort Jackson
# 2   Associated Air Transport     1-6-6A            Boeing Field - Cheyenne
# 3  Military -Royal Air Force          -                                NaN
# 4       Linee Aeree Italiane        NaN                    Cagliari - Rome
#
#                                  Ac_Type   Registration  Cn_Ln  ... Ground  \
# 0                  Vickers Viking 610-1B         G-AJDL    262  ...    0.0
# 1                    Douglas C-54B-10-DO         N86574  18350  ...    0.0
# 2                           Curtiss C-46         N1648M  22395  ...    0.0
# 3  Vickers Valetta Mk1 / Avero Lancaster  VX562 / TX270    NaN  ...    0.0
# 4                           Douglas DC-3         I-LAIL   4308  ...    0.0
#
#                                              Summary  Aboard_Total  \
# 0  Crashed into approach lights while attempting ...            35
# 1  The plane struck a tree on a mountain ridge at...             7
# 2  The plane crashed into mountains while en rout...            40
# 3  Both aircraft crashed after a midair collision...            26
# 4  Crashed 10 miles east of Cagliari in the Sinna...            19
#
#   Fatalities_Total  Operator_Military_Compiled  \
# 0               27    British European Airways
# 1                7           Flying Tiger Line
# 2               40    Associated Air Transport
# 3               26                    Military
# 4               19        Linee Aeree Italiane
#
#                                     Country_location Code  \
# 0  {'place_id': 372303099, 'licence': 'Data © Ope...  GBR
# 1  {'place_id': 383391892, 'licence': 'Data © Ope...  USA
# 2  {'place_id': 315821592, 'licence': 'Data © Ope...  USA
# 3  {'place_id': 100666283, 'licence': 'Data © Ope...  ITA
# 4  {'place_id': 78523394, 'licence': 'Data © Open...  ITA
#
#                       Country_Geopy         country      Operator_USA_Combined
# 0  Northern Ireland, United Kingdom  United Kingdom   British European Airways
# 1         Washington, United States   United States          Flying Tiger Line
# 2              Idaho, United States   United States   Associated Air Transport
# 3                             Italy           Italy  Military -Royal Air Force
# 4                   Sardinia, Italy           Italy       Linee Aeree Italiane
#
# [5 rows x 22 columns]

# %%
df["Death_Ratio"] = df["Fatalities_Total"] / df["Aboard_Total"]

# %%
df_grouped = df.groupby(df.Date.dt.to_period('y'))
# Out:
# /var/folders/sr/32z6khr97xs2g11w52pbkzww0000gn/T/ipykernel_14633/218152184.py:1: FutureWarning: 'y' is deprecated and will be removed in a future version, please use 'Y' instead.
#   df_grouped = df.groupby(df.Date.dt.to_period('y'))

# %%
df_grouped.agg(agg_me)
# Out:
#       Country_Geopy  Aboard_Total  Fatalities_Total  Ground
# Date
# 1908              1             2                 1     0.0
# 1909              1             1                 1     0.0
# 1912              1             5                 5     0.0
# 1913              3            49                43     0.0
# 1915              2            60                36     0.0
# ...             ...           ...               ...     ...
# 2020              8           703               355     1.0
# 2021              9           247               185     3.0
# 2022              6           321               189     2.0
# 2023              4           100               100     0.0
# 2024              3           396                12     0.0
#
# [114 rows x 4 columns]

# %%
df_grouped = df.groupby(df.Date.dt.to_period('y'))
# Out:
# /var/folders/sr/32z6khr97xs2g11w52pbkzww0000gn/T/ipykernel_14633/218152184.py:1: FutureWarning: 'y' is deprecated and will be removed in a future version, please use 'Y' instead.
#   df_grouped = df.groupby(df.Date.dt.to_period('y'))

# %%
df_grouped_usa = df.groupby(df[df.Code == "USA"].Date.dt.to_period('y'))
# Out:
# /var/folders/sr/32z6khr97xs2g11w52pbkzww0000gn/T/ipykernel_14633/1998572463.py:1: FutureWarning: 'y' is deprecated and will be removed in a future version, please use 'Y' instead.
#   df_grouped_usa = df.groupby(df[df.Code == "USA"].Date.dt.to_period('y'))

# %%
def plot_(df_location,df_fatalities,df_aboard,df_ground):
    fig, ax = plt.subplots(3,1, figsize=(24, 12))
    # Plotting as time series
    df_location.plot(ax=ax[0],label="Fatalities",color="teal") 
    df_location.plot(ax=ax[1],label="Fatalities",color="teal")
    df_fatalities.plot(ax=ax[1],label="Crashes",color='orchid') 
    df_aboard.plot(ax=ax[1],label="Aboard",color='r')
    df_ground.plot(ax=ax[2],label="Ground Fatalities")

    ax[0].set_xlabel('')
    ax[0].set_ylabel("Count")
    ax[0].set_title("Fatalities")
    # plt.legend()

    ax[2].set_ylabel("Count")
    ax[2].set_title("Ground Fatalities")
    # ax[2].set_xlabel("")
    # plt.legend()
    ax[1].set_ylabel("Count")
    ax[1].get_xaxis().set_ticks([])
    ax[1].set_xlabel("")
    ax[1].set_yscale('log')
    # plt.legend()

    for ax in ax:
        ax.axvline(x='2001', color='r', linestyle='--', linewidth=1)  # Add to each axis

    plt.text('2000',10000,f"{2001}", color='r',rotation=90)

    fig.legend(loc="right")

# %%
plot_(df_grouped_usa.agg(agg_me)["Fatalities_Total"],df_grouped_usa.agg(agg_me)["Country_Geopy"],df_grouped_usa.agg(agg_me)["Aboard_Total"],df_grouped_usa.agg(agg_me)["Ground"])

# %%
plot_(df_grouped_usa.agg(agg_me)["Country_Geopy"],df_grouped_usa.agg(agg_me)["Fatalities_Total"],df_grouped_usa.agg(agg_me)["Aboard_Total"],df_grouped_usa.agg(agg_me)["Ground"])

# %%
plot_(df_grouped.agg(agg_me)["Country_Geopy"],df_grouped.agg(agg_me)["Fatalities_Total"],df_grouped.agg(agg_me)["Aboard_Total"],df_grouped.agg(agg_me)["Ground"])

# %%
df_grouped_usa = df.groupby(df[df.Code == "USA"].Date.dt.to_period('Y'))
