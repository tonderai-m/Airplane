# %% [markdown]
# #### After we got the data from Geopy
# - Check column length if we managed to get all the data and the answer is no
# - About 97 records have null in the Country_location column
# - we should have 5015 records

# %%
import pandas as pd

# %% [markdown]
# Read in the 1920_2024_geopy and

# %%
df = pd.read_json("data/silver/1920_2024_geopy.json")
df[:5]
# Out:
#    Decade       Date  Time                    Location  \
# 0    1950 1953-01-05  2139   Belfast, Northern Ireland
# 1    1950 1953-01-07  2055        Issaquah, Washington
# 2    1950 1953-01-07  0412           Fish Haven, Idaho
# 3    1950 1953-01-15  0448  25 nm off Agrigento, Italy
# 4    1950 1953-01-26  1144     Sinnai, Sardinia, Italy
#
#                     Operator Flight_Num                              Route  \
# 0   British European Airways       None                 Northolt - Belfast
# 1          Flying Tiger Line        841  Seattle - Cheyenne - Fort Jackson
# 2   Associated Air Transport     1-6-6A            Boeing Field - Cheyenne
# 3  Military -Royal Air Force          -                               None
# 4       Linee Aeree Italiane       None                    Cagliari - Rome
#
#                                  Ac_Type   Registration  Cn_Ln  \
# 0                  Vickers Viking 610-1B         G-AJDL    262
# ...

# %%
len(df)
# Out:
# 5015

# %%
sum(df.Country_location.apply(lambda x: isinstance(x,dict))), sum(df.Country_location.apply(lambda x: not isinstance(x,dict)))
# Out:
# (4918, 97)

# %%
df[df.Country_location.apply(lambda x: not isinstance(x,dict))]
# Out:
#       Decade       Date     Time  \
# 37      1950 1953-06-16     None
# 40      1950 1953-07-12     0841
# 45      1950 1953-08-05     None
# 112     1940 1947-06-21     None
# 113     1940 1947-07-01     None
# ...      ...        ...      ...
# 4455    1940 1949-01-17  c 13:40
# 4473    1940 1949-05-07    16:00
# 4570    1960 1961-01-22     0304
# 4653    1970 1977-06-21     2230
# 4871    1980 1989-09-21     None
#
#                                               Location  \
# 37                 Mount Phou-Lassy, French Indo-China
# 40        Pacific Ocean, 325 miles east of Wake Island
# 45                                     Off Irish coast
# 112                     Black Sea, Gulf of Karkinitsky
# 113                       Near Eaeka, French Cameroons
# ...                                                ...
# 4455                       Atlantic Ocean, off Bermuda
# 4473  Sibuyan Sea, off the Philippine island of Elalat
# 4570                   Midway Island Naval Air Station
# ...

# %% [markdown]
# We are going to save the bad data for further processing and eda

# %%
df[df.Country_location.apply(lambda x: isinstance(x,str))].to_csv("data/bad_data/unknown_country_location.csv")

# %% [markdown]
# ### Unfortunately After the geopy we have 97 data points that weren't able to be locate
# - We have some additional cleaning maybe some formatting will do that next
