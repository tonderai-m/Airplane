# %%
import pandas as pd

# %%
df = pd.read_csv("data/silver/1920_2024.csv")

# %%
df
# Out:
#             Date   Time                         Location  \
# 0     1953-01-05   2139        Belfast, Northern Ireland
# 1     1953-01-07   2055             Issaquah, Washington
# 2     1953-01-07   0412                Fish Haven, Idaho
# 3     1953-01-15   0448       25 nm off Agrigento, Italy
# 4     1953-01-26   1144          Sinnai, Sardinia, Italy
# ...          ...    ...                              ...
# 5032  1976-12-17   1940                  Ust-Kut, Russia
# 5033  1976-12-17  21:30                       Kiev, USSR
# 5034  1976-12-18   1656  Nnear Yuzhno-Sakhalinsk, Russia
# 5035  1976-12-25   0345           Near Bangkok, Thailand
# 5036  1976-12-31    NaN              Near Trujillo, Peru
#
#                        Operator Flight_Num  \
# 0      British European Airways        NaN
# 1             Flying Tiger Line        841
# 2      Associated Air Transport     1-6-6A
# 3     Military -Royal Air Force          -
# 4          Linee Aeree Italiane        NaN
# ...

# %%
min(df.Date)
# Out:
# '1908-09-17'
