# %%
import pandas as pd
import numpy as np 
import re 
from functions.extraction_and_cleaning import read_bronze

# %%
df = read_bronze()

# %%
df
# Out:
#                    Date   Time                         Location  \
# 0      January 05, 1953   2139        Belfast, Northern Ireland
# 1      January 07, 1953   2055             Issaquah, Washington
# 2      January 07, 1953   0412                Fish Haven, Idaho
# 3      January 15, 1953   0448       25 nm off Agrigento, Italy
# 4      January 26, 1953   1144          Sinnai, Sardinia, Italy
# ...                 ...    ...                              ...
# 5032  December 17, 1976   1940                  Ust-Kut, Russia
# 5033  December 17, 1976  21:30                       Kiev, USSR
# 5034  December 18, 1976   1656  Nnear Yuzhno-Sakhalinsk, Russia
# 5035  December 25, 1976   0345           Near Bangkok, Thailand
# 5036  December 31, 1976      ?              Near Trujillo, Peru
#
#                        Operator Flight #  \
# 0      British European Airways        ?
# 1             Flying Tiger Line      841
# 2      Associated Air Transport   1-6-6A
# 3     Military -Royal Air Force        -
# 4          Linee Aeree Italiane        ?
# ...                         ...      ...
# 5032                   Aeroflot        ?
# 5033                   Aeroflot     H-36
# 5034                   Aeroflot        ?
# 5035                   EgyptAir      864
# 5036                    Faucett        ?
#
#                                              Route  \
# 0                               Northolt - Belfast
# 1                Seattle - Cheyenne - Fort Jackson
# 2                          Boeing Field - Cheyenne
# 3                                                ?
# 4                                  Cagliari - Rome
# ...                                            ...
# 5032                             Ust-Kut - Kirensk
# 5033                             Chernivtsi - Kiev
# 5034  Petropavlovsk-Kamchatsky - Yuzhno-Sakhalinsk
# 5035                               Cairo - Bangkok
# 5036                           Trujillo - Tarapoto
#
#                            AC\n        Type   Registration    cn / ln  \
# 0                     Vickers Viking 610-1B         G-AJDL        262
# 1                       Douglas C-54B-10-DO         N86574      18350
# 2                              Curtiss C-46         N1648M      22395
# 3     Vickers Valetta Mk1 / Avero Lancaster  VX562 / TX270          ?
# 4                              Douglas DC-3         I-LAIL       4308
# ...                                     ...            ...        ...
# 5032                            Yakovlev 40     CCCP-88208    9631349
# 5033                        Antonov AN-24RV     CCCP-46672   47309604
# 5034                        Ilyushin IL-14M     CCCP-61752  147001247
# 5035                      Boeing B-707-366C         SU-AXA      20763
# 5036                     Douglas C-54A-1-DO       OB-R-247       7462
#
#                              Aboard                     Fatalities Ground  \
# 0      35   (passengers:31  crew:4)   27   (passengers:24  crew:3)      0
# 1        7   (passengers:3  crew:4)     7   (passengers:3  crew:4)      0
# 2      40   (passengers:37  crew:3)   40   (passengers:37  crew:3)      0
# 3     26   (passengers:16  crew:10)  26   (passengers:16  crew:10)      0
# 4      19   (passengers:15  crew:4)   19   (passengers:15  crew:4)      0
# ...                             ...                            ...    ...
# 5032     7   (passengers:4  crew:3)     7   (passengers:4  crew:3)      0
# 5033   55   (passengers:50  crew:5)   48   (passengers:44  crew:4)      0
# 5034     8   (passengers:3  crew:5)     8   (passengers:3  crew:5)      0
# 5035   53   (passengers:44  crew:9)   53   (passengers:44  crew:9)     19
# 5036   19   (passengers:14  crew:5)   19   (passengers:14  crew:5)      0
#
#                                                 Summary
# 0     Crashed into approach lights while attempting ...
# 1     The plane struck a tree on a mountain ridge at...
# 2     The plane crashed into mountains while en rout...
# 3     Both aircraft crashed after a midair collision...
# 4     Crashed 10 miles east of Cagliari in the Sinna...
# ...                                                 ...
# 5032  The cargo plane crashed into trees on takeoff....
# 5033  In heavy fog  the crew continued their descend...
# 5034  The survey fllight deviated from the approach ...
# 5035  The aircraft crashed into an industrial area d...
# 5036  Struck the slope of Mt Pintado located 25 km n...
#
# [5037 rows x 13 columns]

# %% [markdown]
# First lets fix the column names

# %%
new_names = []
for item in df.columns:
    item = item.lower()
    item = item.strip()
    item = item.replace("\n"," ")
    item = item.replace("/"," ")
    item = item.replace("#","num")
    item = item.split()
    item = "_".join(item)
    new_names.append(item.title())

# %%
df.columns = new_names

# %%
def clean_aboard(x):
    x = x.replace("(","").replace(")","").split()
    a, b, c = x[0], x[1].split(":")[-1], x[2].split(":")[-1]
    # try: 
    #     return {"total":int(a),"passengers":int(b),"crew":int(c)}
    # except:
    #     if a == "?":
    #         a = float("nan")
    #     if b == "?":
    #         b = float("nan")
    #     if c == "?":
    #         c = float("nan")
    return {"total":a,"passengers":b,"crew":c}

# %%
df.Aboard = df.Aboard.apply(clean_aboard)
df.Fatalities = df.Fatalities.apply(clean_aboard);

# %%
# df.iloc[1000]["Aboard"]

# %%
df.tail(10)
# Out:
#                  Date   Time                         Location  \
# 47  November 04, 1976      ?           Banjarmasin, Indonesia
# 48  November 05, 1976      ?                   Atlantic Ocean
# 49  November 23, 1976   0945                   Kozani, Greece
# 50  November 28, 1976   1856                   Moscow, Russia
# 51  December 12, 1976   2326             Cape May, New Jersey
# 52  December 17, 1976   1940                  Ust-Kut, Russia
# 53  December 17, 1976  21:30                       Kiev, USSR
# 54  December 18, 1976   1656  Nnear Yuzhno-Sakhalinsk, Russia
# 55  December 25, 1976   0345           Near Bangkok, Thailand
# 56  December 31, 1976      ?              Near Trujillo, Peru
#
#                           Operator Flight_Num  \
# 47  Bali International Air Service          ?
# 48                    Inair Panama          ?
# 49                 Olympic Airways          ?
# 50                        Aeroflot       2415
# 51          Atlantic City Airlines        977
# 52                        Aeroflot          ?
# 53                        Aeroflot       H-36
# 54                        Aeroflot          ?
# 55                        EgyptAir        864
# 56                         Faucett          ?
#
#                                                 Route  \
# 47  Manado -Gorontalo - Palu - Balikpapan - Banjar...
# 48                           Curacao - Port-au-Prince
# 49                                    Athens - Larisa
# 50                                 Moscow - Leningrad
# 51                            Atlantic City - Cap May
# 52                                  Ust-Kut - Kirensk
# 53                                  Chernivtsi - Kiev
# 54       Petropavlovsk-Kamchatsky - Yuzhno-Sakhalinsk
# 55                                    Cairo - Bangkok
# 56                                Trujillo - Tarapoto
#
#                                      Ac_Type Registration      Cn_Ln  \
# 47                Fokker F-27 Friendship 100       PK-KFR      10142
# 48                              Douglas DC-3       HP-671      43073
# 49                           NAMC YS-11A-500       SX-BBR       2156
# 50                           Tupolev TU-104B   CCCP-42471     021204
# 51  de Havilland Canada DHC-6 Twin Otter 300       N101AC        262
# 52                               Yakovlev 40   CCCP-88208    9631349
# 53                           Antonov AN-24RV   CCCP-46672   47309604
# 54                           Ilyushin IL-14M   CCCP-61752  147001247
# 55                         Boeing B-707-366C       SU-AXA      20763
# 56                        Douglas C-54A-1-DO     OB-R-247       7462
#
#                                               Aboard  \
# 47  {'total': '38', 'passengers': '33', 'crew': '5'}
# 48    {'total': '2', 'passengers': '0', 'crew': '2'}
# 49  {'total': '50', 'passengers': '46', 'crew': '4'}
# 50  {'total': '73', 'passengers': '67', 'crew': '6'}
# 51   {'total': '10', 'passengers': '8', 'crew': '2'}
# 52    {'total': '7', 'passengers': '4', 'crew': '3'}
# 53  {'total': '55', 'passengers': '50', 'crew': '5'}
# 54    {'total': '8', 'passengers': '3', 'crew': '5'}
# 55  {'total': '53', 'passengers': '44', 'crew': '9'}
# 56  {'total': '19', 'passengers': '14', 'crew': '5'}
#
#                                           Fatalities Ground  \
# 47  {'total': '29', 'passengers': '25', 'crew': '4'}      0
# 48    {'total': '2', 'passengers': '0', 'crew': '2'}      0
# 49  {'total': '50', 'passengers': '46', 'crew': '4'}      0
# 50  {'total': '73', 'passengers': '67', 'crew': '6'}      0
# 51    {'total': '3', 'passengers': '3', 'crew': '1'}      0
# 52    {'total': '7', 'passengers': '4', 'crew': '3'}      0
# 53  {'total': '48', 'passengers': '44', 'crew': '4'}      0
# 54    {'total': '8', 'passengers': '3', 'crew': '5'}      0
# 55  {'total': '53', 'passengers': '44', 'crew': '9'}     19
# 56  {'total': '19', 'passengers': '14', 'crew': '5'}      0
#
#                                               Summary
# 47  After overshooting the runway, a go-around was...
# 48  The cargo plane went missing between Curacao -...
# 49  The airliner crashed into mountainous terrain ...
# 50  After taking off an artificial horizon failure...
# 51  The plane crashed short of the runway in rain....
# 52  The cargo plane crashed into trees on takeoff....
# 53  In heavy fog  the crew continued their descend...
# 54  The survey fllight deviated from the approach ...
# 55  The aircraft crashed into an industrial area d...
# 56  Struck the slope of Mt Pintado located 25 km n...

# %%
# df["Fatalities"][df["Fatalities"]["total"] == 0]
